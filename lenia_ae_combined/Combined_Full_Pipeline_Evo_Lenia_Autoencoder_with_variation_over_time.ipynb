# %% [markdown]
# # 1. Creating 'n' random (using random kernels) lenia images "meaningful" Dataset for AutoEncoder training procedure

# %% [markdown]
# ### For example generating 100 frames each gif, let us just save 10000 images by calling 100 random kernels. As we generate 100 frames each simulation, we just need 100 random simulations for 100 random kernels which produces 100*100=10000 images

# %%
dataset_size = 10
# Imports
# https://chakazul.github.io/Lenia/JavaScript/Lenia.html
import numpy as np
from matplotlib import pyplot as plt
import time
import warnings
warnings.simplefilter("ignore", UserWarning)
#Imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
import scipy.signal
import os.path
import os
from datetime import datetime
from json import JSONEncoder
import json
from pathlib import Path
                

OUTPUT_PATH = './outputs'

mu = 0.31
sigma = 0.057
dt = 0.1


frames = 100



class Lenia:
    def __init__(self, kernel, board):
        self.sigma = sigma
        self.mu = mu
        self.dt = dt
        self.kernel = kernel
        self.normalise_kernel()
        self.frames = frames
        self.anim = None
        self.lenia_board_state = {}
        self.frame_intervals = 10
        # For random initialisation
        self.board = board
        self.cmap = 'viridis'
        self.fig, self.img = self.show_board()
        

    # FLEXIBLITY TO CHANGE GROWTH FUNCTION
    def growth_function1(self, U:np.array):
        gaussian = lambda x, m, s: np.exp(-( (x-m)**2 / (2*s**2) ))
        return gaussian(U, self.mu, self.sigma)*2-1


    def show_board(self, 
                   display:bool=False,
                   ):
        dpi = 50 # Using a higher dpi will result in higher quality graphics but will significantly affect computation

        self.fig = plt.figure(figsize=(10*np.shape(self.board)[1]/dpi, 10*np.shape(self.board)[0]/dpi), dpi=dpi)

        ax = self.fig.add_axes([0, 0, 1, 1])
        ax.axis('off')
        
        self.img = ax.imshow(self.board, cmap=self.cmap, interpolation='none', aspect=1, vmin=0) #  vmax=vmax
        
        if display:
            plt.show()
        else: # Do not show intermediate figures when creating animations (very slow)
            plt.close()

        return self.fig, self.img
    
    
    def animate(self):
        
        self.anim =  matplotlib.animation.FuncAnimation(self.fig, self.animate_step, 
                                            frames=self.frames, interval=self.frame_intervals, blit=True)

    
    def animate_step(self, i:int) -> plt.imshow:
        neighbours = scipy.signal.convolve2d(self.board, self.kernel, mode='same', boundary='wrap')
        self.board = np.clip(self.board + self.dt * self.growth_function1(neighbours), 0, 1)
        if (i+1) % 10 == 0:
            self.record_board_state(i)
        self.img.set_array(self.board) # render the updated state 
        return self.img,

    def save_animation(self, dir, 
                       filename:str,
                       ):
        if not self.anim:
            raise Exception('ERROR: Run animation before attempting to save')
            return 
        output_path = OUTPUT_PATH+"/"+dir
        Path(output_path).mkdir(parents=True, exist_ok=True)
        fmt = os.path.splitext(filename)[1] # isolate the file extension
        
        if fmt == '.gif':
            f = os.path.join(output_path, filename) 
            writer = matplotlib.animation.PillowWriter(fps=30) 
            self.anim.save(f, writer=writer)
        else:
            raise Exception('ERROR: Unknown save format. Must be .gif or .mp4')
        # writer.close()

    
    def normalise_kernel(self) -> np.array:

        kernel_norm = self.kernel / (1*np.sum(self.kernel))
        self.norm_factor = 1/ (1*np.sum(self.kernel))
        self.kernel = kernel_norm 
        return kernel_norm
        
        
    def plot_kernel_info(self,
                         dir,
                         cmap:str='viridis', 
                         bar:bool=False,
                         save:str=None,
                         ) -> None:

        
        k_xsection = self.kernel[self.kernel.shape[0] // 2, :]
        k_sum = np.sum(self.kernel)
        
        fig, ax = plt.subplots(1, 3, figsize=(14,2), gridspec_kw={'width_ratios': [1,1,2]})
        
        # Show kernel as heatmap
        ax[0].imshow(self.kernel, cmap=cmap, vmin=0)
        ax[0].title.set_text('Kernel')
        
        # Show kernel cross-section
        ax[1].title.set_text('Kernel Cross-section')
        if bar==True:
            ax[1].bar(range(0,len(k_xsection)), k_xsection, width=1)
        else:
            ax[1].plot(k_xsection)
        
        # Growth function
        ax[2].title.set_text('Growth Function')
        x = np.linspace(0, k_sum, 1000)
        ax[2].plot(x, self.growth_function1(x))
        
        if save:
            output_path = OUTPUT_PATH+"/"+dir
            Path(output_path).mkdir(parents=True, exist_ok=True)
            print('Saving kernel and growth function info to', os.path.join(output_path, 'kernel_info'))
            
            plt.savefig(os.path.join(output_path, 'kernel_info.png') )


    def run_simulation(self, generation) -> None:
        self.animate()
        sub_dir = generation+"/"+str(datetime.now())
        outfile = "output"+str(datetime.now())+".gif"   
        print('./folder/{}...)'.format(sub_dir))
        
        self.save_animation(sub_dir, outfile)
        self.plot_kernel_info(dir=sub_dir, save=True)
        return self.lenia_board_state


    def record_board_state(self, i):
        board_arr = self.board.flatten()
        board_val_greater_than_point_five = list(board_arr[board_arr > 0.5])
        self.lenia_board_state["frame_"+str(i+1)] = len(board_val_greater_than_point_five)

# %%
kernel_size = 16
board_size = 64
def random_kernel_generator():
    grid = np.random.rand(kernel_size, kernel_size)
    grid = np.round(grid, 3)
    return grid
def random_board_generator():
    board = np.random.rand(board_size, board_size)
    board = np.round(board, 3)
    return board

# %%
# !rm -rf outputs
# !rm -rf sample_data
# !rm *.png
# !rm *.gif
for i in range(dataset_size):
  board = random_board_generator()
  lenia = Lenia(random_kernel_generator(), random_board_generator())
  board_alive_cell = lenia.run_simulation("certain_files")
# Out:
# rm: cannot remove '*.png': No such file or directory
# rm: cannot remove '*.gif': No such file or directory
# ./folder/certain_files/2023-03-26 17:31:02.849719...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-26 17:31:02.849719/kernel_info
# ./folder/certain_files/2023-03-26 17:31:25.691915...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-26 17:31:25.691915/kernel_info
# ./folder/certain_files/2023-03-26 17:31:42.772039...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-26 17:31:42.772039/kernel_info
# ./folder/certain_files/2023-03-26 17:31:50.920306...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-26 17:31:50.920306/kernel_info
# ./folder/certain_files/2023-03-26 17:31:58.161604...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-26 17:31:58.161604/kernel_info
# ./folder/certain_files/2023-03-26 17:32:13.432452...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-26 17:32:13.432452/kernel_info
# ./folder/certain_files/2023-03-26 17:32:27.390948...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-26 17:32:27.390948/kernel_info
# ./folder/certain_files/2023-03-26 17:32:36.869450...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-26 17:32:36.869450/kernel_info
# ./folder/certain_files/2023-03-26 17:32:45.151863...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-26 17:32:45.151863/kernel_info
# ./folder/certain_files/2023-03-26 17:32:53.231278...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-26 17:32:53.231278/kernel_info

# %%
# !mv /content/outputs/*/*/*.gif /content/

# %%
# !rm -rf outputs

# %%
# !i=1; for file in *; do mv "$file" "$(printf '%d' $i).${file##*.}"; ((i++)); done

# %%
# !ffmpeg
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Hyper fast Audio and Video encoder
# usage: ffmpeg [options] [[infile options] -i infile]... {[outfile options] outfile}...
#
# Use -h to get full help or, even better, run 'man ffmpeg'

# %%
# !for file in *.gif; do ffmpeg -i "$file" "${file%.*}-%d.jpg"; done
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '10.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5072 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55d15e6cf900] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '10-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.37x
# video:3586kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '1.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 7515 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x564bf5f23180] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '1-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.37x
# video:3211kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '2.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 7308 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5566df59fb80] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '2-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.48x
# video:3509kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '3.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 6280 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55886358f040] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '3-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.39x
# video:3903kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '4.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5112 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55cb00008380] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '4-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.35x
# video:3626kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '5.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 6350 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5575d6081d00] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '5-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.33x
# video:3845kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '6.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 6557 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5614b8cfe140] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '6-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.35x
# video:3399kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '7.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5290 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x563451318d80] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '7-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.35x
# video:3551kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '8.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5578 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x561a2f6ae040] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '8-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.29x
# video:3656kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '9.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 6847 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x556930b0ac40] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '9-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps= 96 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=2.88x
# video:4010kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !rm *.gif
# !rm *.png
# Out:
# rm: cannot remove '*.png': No such file or directory

# %%
# !i=1; for file in *; do mv "$file" "$(printf '%d' $i).${file##*.}"; ((i++)); done

# %%
# !mkdir dataset
# !mv *.jpg dataset

# %%
# !ls /content/dataset | wc -l
# Out:
# 1000

# %% [markdown]
# # 2. AutoEncoder procedure

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "/content/dataset/"

# Initialize lists to hold the image data and labels
data = []

# Loop over the files in the folder
for filename in os.listdir(folder_path):
    # Load the image using OpenCV
    img = cv2.imread(os.path.join(folder_path, filename))
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Resize the image to a fixed size
    resized = cv2.resize(gray, (28, 28))
    # Add the image data to the list
    data.append(resized)
    # Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)

# Split the data into training and testing sets

# %%
xtrain, xtest = train_test_split(data, test_size=0.3, random_state=2)

     

X_train = xtrain.reshape(xtrain.shape[0], 28, 28, 1)
X_test = xtest.reshape(xtest.shape[0], 28, 28, 1)

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.layers import Layer
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, add
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras import regularizers
from keras.regularizers import l2
from keras.layers.convolutional import Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D
from keras.utils import np_utils

# %%
X_train = X_train.astype("float32")/255.
X_test = X_test.astype("float32")/255.

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (700, 28, 28, 1)
# 700 train samples
# 300 test samples

# %%
X_train = X_train.reshape((len(X_train), np.prod(X_train.shape[1:])))
X_test = X_test.reshape((len(X_test), np.prod(X_test.shape[1:])))

# %%
input_size = 784
hidden_size = 36
output_size = 784

# %%
x = Input(shape=(input_size,))
h = Dense(hidden_size, activation='relu')(x)
r = Dense(output_size, activation='sigmoid')(h)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adam', loss='mse')
     

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(autoencoder).create(prog='dot', format='svg'))

# %%
epochs = 300
batch_size = 128

history = autoencoder.fit(X_train, X_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test, X_test))
# Out:
# Epoch 1/300
# 6/6 [==============================] - 1s 48ms/step - loss: 0.1084 - val_loss: 0.1050
# Epoch 2/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1039 - val_loss: 0.0996
# Epoch 3/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0979 - val_loss: 0.0936
# Epoch 4/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0916 - val_loss: 0.0880
# Epoch 5/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0860 - val_loss: 0.0832
# Epoch 6/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0808 - val_loss: 0.0785
# Epoch 7/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0758 - val_loss: 0.0734
# Epoch 8/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0704 - val_loss: 0.0683
# Epoch 9/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0652 - val_loss: 0.0633
# Epoch 10/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0600 - val_loss: 0.0586
# Epoch 11/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0553 - val_loss: 0.0540
# Epoch 12/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0508 - val_loss: 0.0499
# Epoch 13/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0467 - val_loss: 0.0463
# Epoch 14/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0432 - val_loss: 0.0430
# Epoch 15/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0400 - val_loss: 0.0401
# Epoch 16/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0373 - val_loss: 0.0376
# Epoch 17/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0348 - val_loss: 0.0354
# Epoch 18/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0326 - val_loss: 0.0333
# Epoch 19/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0306 - val_loss: 0.0314
# Epoch 20/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0288 - val_loss: 0.0297
# Epoch 21/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0271 - val_loss: 0.0281
# Epoch 22/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0256 - val_loss: 0.0266
# Epoch 23/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0243 - val_loss: 0.0252
# Epoch 24/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0230 - val_loss: 0.0241
# Epoch 25/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0219 - val_loss: 0.0230
# Epoch 26/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0208 - val_loss: 0.0219
# Epoch 27/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0199 - val_loss: 0.0210
# Epoch 28/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0191 - val_loss: 0.0202
# Epoch 29/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0183 - val_loss: 0.0195
# Epoch 30/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0176 - val_loss: 0.0188
# Epoch 31/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0170 - val_loss: 0.0181
# Epoch 32/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0165 - val_loss: 0.0176
# Epoch 33/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0160 - val_loss: 0.0171
# Epoch 34/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0155 - val_loss: 0.0167
# Epoch 35/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0151 - val_loss: 0.0162
# Epoch 36/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 37/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0144 - val_loss: 0.0155
# Epoch 38/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0141 - val_loss: 0.0151
# Epoch 39/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0138 - val_loss: 0.0149
# Epoch 40/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0135 - val_loss: 0.0146
# Epoch 41/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0133 - val_loss: 0.0143
# Epoch 42/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0130 - val_loss: 0.0141
# Epoch 43/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0128 - val_loss: 0.0139
# Epoch 44/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 45/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 46/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0122 - val_loss: 0.0132
# Epoch 47/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0121 - val_loss: 0.0131
# Epoch 48/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0119 - val_loss: 0.0129
# Epoch 49/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 0.0127
# Epoch 50/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0116 - val_loss: 0.0126
# Epoch 51/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0114 - val_loss: 0.0124
# Epoch 52/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0113 - val_loss: 0.0123
# Epoch 53/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0111 - val_loss: 0.0121
# Epoch 54/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0110 - val_loss: 0.0120
# Epoch 55/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0109 - val_loss: 0.0118
# Epoch
300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 257/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 258/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 259/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 260/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 261/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 262/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 263/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 264/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 265/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 266/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 267/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 268/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 269/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 270/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 271/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 272/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 273/300
# 6/6 [==============================] - 0s 55ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 274/300
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 275/300
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 276/300
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 277/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 278/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 279/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 280/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 281/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 282/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 283/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 284/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 285/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 286/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 287/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 288/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 289/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 290/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 291/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 292/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 293/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 294/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 295/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0067
# Epoch 296/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 297/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 298/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 299/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 300/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0066

# %%
conv_encoder = Model(x, h)
encoded_imgs = conv_encoder.predict(X_test)

n = 1
plt.figure(figsize=(28, 10))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(encoded_imgs[i].reshape(6, 6).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
decoded_imgs = autoencoder.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
n = 1
plt.figure(figsize=(28, 28))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i+1)
    plt.imshow(X_test[i].reshape(28, 28),cmap="gist_earth")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
plt.figure(figsize=(28,28))
for i in range(n):    
    # display reconstruction
    ax = plt.subplot(3, n, i+n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap="gist_earth")
    # plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %%
print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
import tensorflow as tf
i=99
print("Error or loss for the image "+str(i))
print(tf.math.reduce_mean(tf.square(decoded_imgs[i].reshape(28, 28)-X_test[i].reshape(28, 28))))
print("------------------------------------------------------------------")
# Out:
# Error or loss for the image 99
# tf.Tensor(0.0066238157, shape=(), dtype=float32)
# ------------------------------------------------------------------

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 36)                28260
#
#  dense_1 (Dense)             (None, 784)               29008
#
# =================================================================
# Total params: 57,268
# Trainable params: 57,268
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Test the model with any random lenia board state

# %%
# Check for orderly image reconstruction loss
# !wget https://dl3.pushbulletusercontent.com/pVIOI0eH0xLUqrczqileIhK0fUO5n0OL/order.jpg
# !wget https://dl3.pushbulletusercontent.com/r8r00OkVim4UwQEyqEG5diLnZWNni1e4/order.jpg
from IPython.display import Image
Image("order.jpg",width = 256, height = 256)
# Out:
# --2023-03-26 17:34:13--  https://dl3.pushbulletusercontent.com/r8r00OkVim4UwQEyqEG5diLnZWNni1e4/order.jpg
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71152 (69K) [image/jpeg]
# Saving to: ‘order.jpg’
#
# order.jpg           100%[===================>]  69.48K  --.-KB/s    in 0.08s
#
# 2023-03-26 17:34:14 (872 KB/s) - ‘order.jpg’ saved [71152/71152]

# %%
# Check for orderly image reconstruction loss
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "./"

# Initialize lists to hold the image data and labels
data = []

filename = "order.jpg"
# Load the image using OpenCV
img = cv2.imread(os.path.join(folder_path, filename))
# Resize the image to a fixed size
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
# Add the image data to the list
data.append(resized)
# Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)
data.shape
# Out:
# (1, 28, 28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_order_image = autoencoder.predict(data[0].reshape(1,784))
print(predicted_order_image.shape)
# Out:
# 1/1 [==============================] - 0s 58ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_order_image.reshape(28,28))

# %%
# # RECONSTRUCTION LOSS
# import tensorflow as tf
# print(tf.math.reduce_mean(predicted_order_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
import tensorflow as tf
print("recon loss MSE")
import numpy as np

# assuming original_img and reconstructed_img are numpy arrays of shape (28, 28)
mse = np.mean((-data[0].reshape(28,28) + predicted_order_image.reshape(28,28))**2)
print(mse)
# Out:
# recon loss MSE
# 28314.01

# %%
# Check for chaotic image reconstruction loss
# !wget https://dl3.pushbulletusercontent.com/JMja0JFwu2M2r1A2XFKJUhj2d049mh28/chaotic.jpg
# !wget https://dl3.pushbulletusercontent.com/HiHs0WSO0K8cEiYGfeWPeW0Q5MDGkmCs/chaotic.jpg
from IPython.display import Image
Image("chaotic.jpg",width = 256, height = 256)
# Out:
# --2023-03-26 17:34:14--  https://dl3.pushbulletusercontent.com/HiHs0WSO0K8cEiYGfeWPeW0Q5MDGkmCs/chaotic.jpg
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 202671 (198K) [image/jpeg]
# Saving to: ‘chaotic.jpg’
#
# chaotic.jpg         100%[===================>] 197.92K  --.-KB/s    in 0.1s
#
# 2023-03-26 17:34:15 (1.45 MB/s) - ‘chaotic.jpg’ saved [202671/202671]

# %%
# Check for orderly image reconstruction loss
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "./"

# Initialize lists to hold the image data and labels
data = []

filename = "chaotic.jpg"
# Load the image using OpenCV
img = cv2.imread(os.path.join(folder_path, filename))
# Resize the image to a fixed size
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
# Add the image data to the list
data.append(resized)
# Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)

# %%
data.shape
# Out:
# (1, 28, 28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_chaotic_image = autoencoder.predict(data[0].reshape(1,784))
print(predicted_chaotic_image.shape)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_chaotic_image.reshape(28,28))

# %%
# # RECONSTRUCTION LOSS
# import tensorflow as tf
# print(tf.math.reduce_mean(predicted_chaotic_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
import tensorflow as tf
print("recon loss MSE")
import numpy as np

# assuming original_img and reconstructed_img are numpy arrays of shape (28, 28)
mse = np.mean((-data[0].reshape(28,28) + predicted_chaotic_image.reshape(28,28))**2)
print(mse)
# Out:
# recon loss MSE
# 26432.531

# %% [markdown]
# # 4. Picking random image from test dataset and result reconstructed loss

# %%
import random
data = X_test[random.randint(1,len(X_test))].reshape(1,28,28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_chaotic_image = autoencoder.predict(data[0].reshape(1,784))
print(predicted_chaotic_image.shape)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_chaotic_image.reshape(28,28))

# %%
# # RECONSTRUCTION LOSS
# import tensorflow as tf
# print(tf.math.reduce_mean(predicted_chaotic_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
import tensorflow as tf
print("recon loss MSE")
import numpy as np

# assuming original_img and reconstructed_img are numpy arrays of shape (28, 28)
mse = np.mean((-data[0].reshape(28,28) + predicted_chaotic_image.reshape(28,28))**2)
print(mse)
# Out:
# recon loss MSE
# 0.0093886405

# %% [markdown]
# # 4. Picking 10 random images from test dataset and result reconstructed loss

# %%
import random

images_10 = []
for i in range(10):
  data = X_test[random.randint(1,len(X_test))].reshape(1,28,28)
  # plt.imshow(data[0])
  images_10.append(data[0])
fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(20, 4))

# display each image in a separate subplot

for i in range(10):
  axes[i].imshow(images_10[i].reshape(28,28))
  axes[i].axis('off')
# plt.title("Ground Truth Images",fontsize=16, loc='center')
fig.suptitle('Ground Truth Images', fontsize=16, fontweight='bold')
fig.tight_layout()

plt.show()

# %%
predicted_images = []
for i in range(10):
  predicted_chaotic_image = autoencoder.predict(images_10[i].reshape(1,784))
  predicted_images.append(predicted_chaotic_image)
fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(20, 4))

# display each image in a separate subplot

for i in range(10):
  axes[i].imshow(predicted_images[i].reshape(28,28))
  axes[i].axis('off')
# plt.title("Ground Truth Images",fontsize=16, loc='center')
fig.suptitle('Predicted Images', fontsize=16, fontweight='bold')
fig.tight_layout()

plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
predicted_images = []
for i in range(10):
  predicted_chaotic_image = autoencoder.predict(images_10[i].reshape(1,784))
  predicted_images.append(predicted_chaotic_image)
fig, axes = plt.subplots(nrows=2, ncols=10, figsize=(40, 8))

# display each image in a separate subplot
for j in range(2):
  for i in range(10):
    if(j==1):
      axes[j][i].imshow(predicted_images[i].reshape(28,28))
      axes[j][i].axis('off')
      # axes[j].set_title('Predicted Images')
      axes[j][i].set_title('Predicted Image '+str(i))
      mse = np.mean((-images_10[i].reshape(28,28) + predicted_images[i].reshape(28,28))**2)
      # print(mse)
      string = "Reconstruction Loss: "+str(round(mse,8))
      axes[j][i].text(0.5, -0.1,string, fontsize=10, ha='center',transform=axes[j][i].transAxes)
    else:
      axes[j][i].imshow(images_10[i].reshape(28,28))
      axes[j][i].axis('off')
      axes[j][i].set_title('Ground Truth Image '+str(i))
      # axes[j].set_title('Ground Truth Images')
# plt.title("Ground Truth Images",fontsize=16, loc='center')
fig.suptitle('Ground Truth Images 1st row, Predicted Images 2nd row', fontsize=16, fontweight='bold')
fig.tight_layout()

plt.show()
# Out:
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step

# %% [markdown]
# #From the last meeting Stefano suggested to use:
#
# ### ⛳Bottleneck = Shrink Size (have shrinked from 64 to 32)
#
# ### ⛳Meaningful Dataset = As of now I am generating 'n' random gifs and saving their frames and putting them as dataset
#
# ### ⛳ Stefano suggested to use deviation as measure of emerging pattern rather than reconstruction loss.
# ##### ==> so the idea is to maximise the deviation of reconstruction. The more the pixels are deviated over time in a reconstructed animation (so let say we have 100 frames of original rule set. those 100 frames vs same frames reconstructed through Autoencoder. The hypothesis is, if we have deviation in reconstruction of those 100 frames, that means there should be some non-boring behaviour)
#
# ✅
# Theory: Autoencoder is a type of neural network that can be used for dimensionality reduction and feature extraction. One way it can help in measuring complexity is by using reconstruction error.
#
# The basic idea of an autoencoder is to learn a compressed representation of the input data, and then use that representation to reconstruct the original data. The input data is first encoded into a compressed representation, which is then decoded back into the original data. The goal is to minimize the difference between the input data and the reconstructed output.
#
# If the autoencoder is successful in reconstructing the input data accurately, then the reconstruction error will be low. However, if the input data is complex and has a lot of variability, it may be difficult for the autoencoder to reconstruct the data accurately, resulting in a higher reconstruction error.
#
# Therefore, the reconstruction error can be used as a measure of complexity, where higher reconstruction error indicates higher complexity. This is because complex data is more difficult to accurately represent and reconstruct using a compressed representation.
#
# In summary, autoencoder can help in measuring complexity using reconstruction error, where the higher reconstruction error indicates higher complexity of the input data.

# %% [markdown]
# ### ⭐ How variation over time can be thought:
# To use an autoencoder for time series data, you can treat each time step as a separate input and train the autoencoder to reconstruct the original sequence of data. The reconstruction loss, which is the difference between the input and the reconstructed output, can then be used to measure the complexity of the time series data.
#
# By analyzing the variation in the reconstruction loss over time, you can gain insights into the complexity of the time series. For example, if the reconstruction loss is relatively constant over time, it may indicate that the time series is relatively simple or predictable. However, if the reconstruction loss varies widely over time, it may indicate that the time series is more complex and difficult to predict.
#
# Additionally, you can use techniques such as spectral analysis or wavelet analysis to further analyze the variation in the reconstruction loss over time. These techniques can help identify patterns and correlations in the data that may not be immediately apparent from the reconstruction loss alone.
#
# In summary, using an autoencoder for time series data and analyzing the variation over time in the reconstruction loss can be a useful approach for measuring the complexity of the time series data.

# %% [markdown]
# # Let us analyse for one case:
# ### step1: generate one random pattern, save first 100 frames
# ### step2: generate reconstruction of those 100 frames using trained auto-encoder
# ### step3: check for variation in reconstruction loss over time between both the frame-sets.

# %%
lenia.run_simulation("outputs") # saving one animation
# Out:
# ./folder/outputs/2023-03-26 17:35:11.482614...)
# Saving kernel and growth function info to ./outputs/outputs/2023-03-26 17:35:11.482614/kernel_info
# {'frame_10': 1658,
#  'frame_20': 1659,
#  'frame_30': 1658,
#  'frame_40': 1654,
#  'frame_50': 1662,
#  'frame_60': 1659,
#  'frame_70': 1661,
#  'frame_80': 1657,
#  'frame_90': 1654,
#  'frame_100': 1663}

# %%
# !mv /content/outputs/outputs/*/*.gif /content/

# %%
# !rm -rf /content/outputs

# %%
# !mkdir original100
# !mv *.gif original100
# %cd original100
# !for file in *.gif; do ffmpeg -i "$file" "${file%.*}-%d.jpg"; done
# %cd /content/
# Out:
# /content/original100
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from 'output2023-03-26 17:35:11.482634.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 2337 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55be63d724c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'output2023-03-26 17:35:11.482634-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.98x
# video:2217kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content

# %%
# %cd /content/original100
# !i=1; for file in *; do mv "$file" "$(printf '%d' $i).${file##*.}"; ((i++)); done
# %cd /content/
# Out:
# /content/original100
# /content

# %%
# %cd /content/original100/
# !rm *.gif
# %cd /content/
# Out:
# /content/original100
# /content

# %%
# !mkdir recon100
# %cd recon100
# Out:
# /content/recon100

# %%
reconloss_list = []

# Loop over the files in the folder and save predicted outputs as image in another folder recon100
for filename in os.listdir("/content/original100/"):
    print("saving ",filename)
    data = []
    # Load the image using OpenCV
    img = cv2.imread(os.path.join("/content/original100/", filename))
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Resize the image to a fixed size
    resized = cv2.resize(gray, (28, 28))
    # Add the image data to the list
    data.append(resized)
    # Add the label to the list
    data = np.array(data)
    predicted_data = autoencoder.predict(data.reshape(1,784))
    plt.imshow(predicted_data.reshape(28,28), cmap='gist_earth')
    plt.savefig("/content/recon100/"+str(filename))
    mse = np.mean((-data.reshape(28,28) + predicted_data.reshape(28,28))**2)
    reconloss_list.append(mse)
    # plt.show()
# Out:
# saving  95.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  34.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  32.jpg
# 1/1 [==============================] - 0s 28ms/step
# saving  26.jpg
# 1/1 [==============================] - 0s 28ms/step
# saving  39.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  28.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  58.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  12.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  31.jpg
# 1/1 [==============================] - 0s 29ms/step
# saving  37.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  98.jpg
# 1/1 [==============================] - 0s 39ms/step
# saving  83.jpg
# 1/1 [==============================] - 0s 49ms/step
# saving  23.jpg
# 1/1 [==============================] - 0s 31ms/step
# saving  100.jpg
# 1/1 [==============================] - 0s 34ms/step
# saving  65.jpg
# 1/1 [==============================] - 0s 33ms/step
# saving  76.jpg
# 1/1 [==============================] - 0s 31ms/step
# saving  7.jpg
# 1/1 [==============================] - 0s 50ms/step
# saving  90.jpg
# 1/1 [==============================] - 0s 31ms/step
# saving  9.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  68.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  59.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  67.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  64.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  82.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  42.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  5.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  87.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  77.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  8.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  91.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  40.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  11.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  63.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  94.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  36.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  73.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  1.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  45.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  75.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  89.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  2.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  41.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  74.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  53.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  81.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  47.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  54.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  88.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  56.jpg
# 1/1 [==============================] - 0s 35ms/step
# saving  61.jpg
# 1/1 [==============================] - 0s 34ms/step
# saving  4.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  44.jpg
# 1/1 [==============================] - 0s 28ms/step
# saving  22.jpg
# 1/1 [==============================] - 0s 27ms/step
# saving  18.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  3.jpg
# 1/1 [==============================] - 0s 28ms/step
# saving  50.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  27.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  78.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  46.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  99.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  30.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  52.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  79.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  85.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  57.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  17.jpg
# 1/1 [==============================] - 0s 28ms/step
# saving  72.jpg
# 1/1 [==============================] - 0s 27ms/step
# saving  29.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  92.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  71.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  55.jpg
# 1/1 [==============================] - 0s 40ms/step
# saving  13.jpg
# 1/1 [==============================] - 0s 34ms/step
# saving  66.jpg
# 1/1 [==============================] - 0s 34ms/step
# saving  84.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  19.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  25.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  51.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  97.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  10.jpg
# 1/1 [==============================] - 0s 27ms/step
# saving  48.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  15.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  86.jpg
# 1/1 [==============================] - 0s 29ms/step
# saving  20.jpg
# 1/1 [==============================] - 0s 27ms/step
# saving  38.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  6.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  69.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  21.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  96.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  43.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  60.jpg
# 1/1 [==============================] - 0s 36ms/step
# saving  35.jpg
# 1/1 [==============================] - 0s 32ms/step
# saving  80.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  70.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  49.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  16.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  14.jpg
# 1/1 [==============================] - 0s 28ms/step
# saving  24.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  33.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  93.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  62.jpg
# 1/1 [==============================] - 0s 28ms/step

# %%
print("The reconstruction loss between original data and the predicted or reconstructued data for 100 frames is:")
print(reconloss_list)
# Out:
# The reconstruction loss between original data and the predicted or reconstructued data for 100 frames is:
# [31116.02, 31251.31, 29545.45, 28892.5, 30694.299, 29072.203, 31299.178, 31257.291, 29436.275, 30333.414, 31977.277, 28338.12, 31230.852, 30889.902, 29753.697, 28031.389, 30246.102, 29581.291, 29919.725, 29288.51, 31051.576, 31154.498, 29987.219, 28167.59, 31145.703, 30539.916, 29075.27, 27919.928, 30075.361, 29857.936, 30835.799, 29644.89, 30157.816, 30708.725, 30114.367, 28249.611, 32397.984, 31233.402, 28066.414, 30948.635, 30848.111, 31042.5, 28135.367, 31755.615, 28058.691, 31786.434, 31667.873, 29331.803, 31195.527, 30641.352, 30630.566, 31475.533, 28751.607, 29017.09, 30710.824, 31878.73, 28967.168, 31101.05, 31627.424, 32229.564, 29293.465, 31781.098, 27924.158, 28736.414, 31438.95, 29069.918, 28431.307, 29143.89, 30111.693, 28609.717, 31602.947, 29527.744, 29524.094, 28532.268, 28911.934, 28853.516, 31830.24, 31737.125, 29806.893, 31881.135, 29310.023, 28851.75, 28852.922, 30511.426, 30366.861, 29026.91, 28778.848, 31442.87, 31345.13, 30851.602, 29929.242, 27944.873, 28730.39, 31865.297, 29210.215, 29393.994, 28797.73, 29708.307, 30356.54, 30434.41]

# %% [markdown]
# # By analyzing the variation in the reconstruction loss over time, you can gain insights into the complexity of the time series. For example, if the reconstruction loss is relatively constant over time, it may indicate that the time series is relatively simple or predictable. However, if the reconstruction loss varies widely over time, it may indicate that the time series is more complex and difficult to predict.

# %%
import numpy as np
std_dev = np.std(reconloss_list)

# Print the standard deviation of the list
print("Standard Deviation of the Reconstruction list is % s" % (std_dev))
# Out:
# Standard Deviation of the Reconstruction list is 1220.0215

# %%
# def reconstruct_and_error(board):
#     data = []
#     # Load the image using OpenCV
#     img = np.array(board)
#     # Convert the image to grayscale
#     # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     # Resize the image to a fixed size
#     resized = cv2.resize(img, (28, 28))
#     # Add the image data to the list
#     data.append(resized)
#     # Add the label to the list
#     data = np.array(data)
#     predicted_data = autoencoder.predict(data.reshape(1,784), verbose=0)
#     plt.ioff()
#     # plt.imshow(predicted_data.reshape(28,28), cmap='gist_earth')
#     # plt.savefig("/content/recon100/"+str(filename))
#     mse = np.mean((-data.reshape(28,28) + predicted_data.reshape(28,28))**2)
#     # reconloss_list.append(mse)
#     # std_dev = np.std(reconloss_list)
#     return mse
#     # plt.show()

# # board = np.random.rand(100, 100)
# # # print(board.shape)
# # # print(board)
# # reco_loss = reconstruct_and_error(board)

# %%
# def calc_fitness(self, boards_list, gen):
#   errors = []
#   for i in range(len(boards_list)):
#     board_error = reconstruct_and_error(boards_list[i])
#     errors.append(board_error)
#   board_stddev = np.std(errors)
#   self.fitness = board_stddev
#   return self.fitness

# %%
# %cd /content/
# Out:
# /content

# %%
# Imports
# https://chakazul.github.io/Lenia/JavaScript/Lenia.html
import numpy as np
from matplotlib import pyplot as plt
import time
import warnings
warnings.simplefilter("ignore", UserWarning)
#Imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
import scipy.signal
import os.path
import os
from datetime import datetime
from json import JSONEncoder
import json
from pathlib import Path
                

OUTPUT_PATH = './outputs'
MAX_FRAMES = 3000

mu = 0.31
sigma = 0.057
dt = 0.1


frames = 100
frame_intervals = float(50)



class Lenia:
    def __init__(self, kernel, board):
        self.sigma = sigma
        self.mu = mu
        self.dt = dt
        self.kernel = kernel
        self.normalise_kernel()
        self.frames = frames
        self.frame_intervals = frame_intervals
        self.anim = None
        self.lenia_board_state = {}
        # For random initialisation
        self.board = board
        self.cmap = 'viridis'
        self.fig, self.img = self.show_board()
        

    # FLEXIBLITY TO CHANGE GROWTH FUNCTION
    def growth_function1(self, U:np.array):
        gaussian = lambda x, m, s: np.exp(-( (x-m)**2 / (2*s**2) ))
        return gaussian(U, self.mu, self.sigma)*2-1


    def show_board(self, 
                   display:bool=False,
                   ):
        dpi = 50 # Using a higher dpi will result in higher quality graphics but will significantly affect computation

        self.fig = plt.figure(figsize=(10*np.shape(self.board)[1]/dpi, 10*np.shape(self.board)[0]/dpi), dpi=dpi)

        ax = self.fig.add_axes([0, 0, 1, 1])
        ax.axis('off')
        
        self.img = ax.imshow(self.board, cmap=self.cmap, interpolation='none', aspect=1, vmin=0) #  vmax=vmax
        
        if display:
            plt.show()
        else: # Do not show intermediate figures when creating animations (very slow)
            plt.close()

        return self.fig, self.img
    
    
    def animate(self):
        self.anim =  matplotlib.animation.FuncAnimation(self.fig, self.animate_step, 
                                            frames=self.frames, interval=self.frame_intervals, save_count=MAX_FRAMES, blit=True)

    
    def animate_step(self, i:int) -> plt.imshow:
        neighbours = scipy.signal.convolve2d(self.board, self.kernel, mode='same', boundary='wrap')
        self.board = np.clip(self.board + self.dt * self.growth_function1(neighbours), 0, 1)
        # if (i+1) % 10 == 0:
        self.record_board_state(i)
        self.img.set_array(self.board) # render the updated state 
        return self.img,
    
    
    def save_animation(self, dir, 
                       filename:str,
                       ):
        if not self.anim:
            raise Exception('ERROR: Run animation before attempting to save')
            return 
        output_path = OUTPUT_PATH+"/"+dir
        Path(output_path).mkdir(parents=True, exist_ok=True)
        fmt = os.path.splitext(filename)[1] # isolate the file extension
        
        if fmt == '.gif':
            f = os.path.join(output_path, filename) 
            writer = matplotlib.animation.PillowWriter(fps=30) 
            self.anim.save(f, writer=writer)
        else:
            raise Exception('ERROR: Unknown save format. Must be .gif or .mp4')
        # writer.close()

    
    def normalise_kernel(self) -> np.array:

        kernel_norm = self.kernel / (1*np.sum(self.kernel))
        self.norm_factor = 1/ (1*np.sum(self.kernel))
        self.kernel = kernel_norm 
        return kernel_norm
        
        
    def plot_kernel_info(self,
                         dir,
                         cmap:str='viridis', 
                         bar:bool=False,
                         save:str=None,
                         ) -> None:

        
        k_xsection = self.kernel[self.kernel.shape[0] // 2, :]
        k_sum = np.sum(self.kernel)
        
        fig, ax = plt.subplots(1, 3, figsize=(14,2), gridspec_kw={'width_ratios': [1,1,2]})
        
        # Show kernel as heatmap
        ax[0].imshow(self.kernel, cmap=cmap, vmin=0)
        ax[0].title.set_text('Kernel')
        
        # Show kernel cross-section
        ax[1].title.set_text('Kernel Cross-section')
        if bar==True:
            ax[1].bar(range(0,len(k_xsection)), k_xsection, width=1)
        else:
            ax[1].plot(k_xsection)
        
        # Growth function
        ax[2].title.set_text('Growth Function')
        x = np.linspace(0, k_sum, 1000)
        ax[2].plot(x, self.growth_function1(x))
        
        if save:
            output_path = OUTPUT_PATH+"/"+dir
            Path(output_path).mkdir(parents=True, exist_ok=True)
            # print('Saving kernel and growth function info to', os.path.join(output_path, 'kernel_info'))
            
            plt.savefig(os.path.join(output_path, 'kernel_info.png') )


    def run_simulation(self, generation) -> None:
        self.animate()
        sub_dir = generation+"/"+str(datetime.now())
        outfile = 'output.gif'   
        # print('./folder/{}...)'.format(sub_dir))
        
        self.save_animation(sub_dir, outfile)
        self.plot_kernel_info(dir=sub_dir, save=True)
        return self.lenia_board_state


    def record_board_state(self, i):
        # board_arr = self.board.flatten()
        # board_val_greater_than_point_five = list(board_arr[board_arr > 0.5])
        self.lenia_board_state["frame_"+str(i+1)] = self.board




# # ###### DELETE CODE AFTER THIS LINE AFTER TESTING#####################
# def random_kernel_generator():
#     grid = np.random.rand(2, 2)
#     grid = np.round(grid, 3)
#     return grid

# def random_board_generator():
#     board = np.random.rand(6, 6)
#     board = np.round(board, 3)
#     return board


# if __name__ == "__main__":
#     lenia = Lenia(random_kernel_generator(), random_board_generator())
#     board_frames = lenia.run_simulation("gen_"+str(1))
#     boards_list = list(board_frames.values())
#     # for k,v in board_frames.items():
#       # print(v.shape)

# %%
# import random
# import numpy as np
# import shutil
# import os
# import statistics
# from matplotlib import pyplot as plt
# import sys
# import copy
# import multiprocessing


# kernel_size = 16
# board_size = 64
# mutation_rate = 0.1
# population_size = 10
# generation = 30
# gen_best_fitness = {}
# gen_average_fitness = {}
# each_gen_fitness = []
# no_of_elites = 1

# def random_kernel_generator():
#   grid = np.random.rand(kernel_size, kernel_size)
#   grid = np.round(grid, 3)
#   return grid

# def random_board_generator():
#   board = np.random.rand(board_size, board_size)
#   board = np.round(board, 3)
#   return board

# class Individual(multiprocessing.Process):

#   def __init__(self):
#     self.genes = random_kernel_generator()
#     self.fitness = 0

#   def calc_fitness(self, board, gen):
#     lenia = Lenia(self.genes, board)
#     board_frames_dict = lenia.run_simulation("gen_"+str(gen))
#     board_frames_val = list(board_frames_dict.values())
#     errors = []
#     for i in range(len(board_frames_val)):
#       board_error = reconstruct_and_error(board_frames_val[i])
#       errors.append(board_error)
#     board_stddev = np.std(errors)
#     self.fitness = board_stddev
#     return self.fitness


# class Population:
#   def __init__(self, size):
#     self.individuals = []
#     self.board = random_board_generator()
#     for _ in range(0, size):
#         self.individuals.append(Individual())


# class GeneticAlgorithm:

#   #@staticmethod
#   def mutate_individuals(individuals):
#     mutated_individuals = []
#     for ind in individuals:
#         mutated_ind = GeneticAlgorithm._mutate_individual(ind)
#         mutated_individuals.append(mutated_ind)
#     return mutated_individuals

#   #@staticmethod
#   def _mutate_individual(ind):
#     kernel = ind.genes
#     for i in range(kernel.shape[0]):
#         for j in range(kernel.shape[1]):
#             if random.random() < mutation_rate:
#                 kernel[i][j] = np.round(np.random.rand(), 3)
#     ind.genes = kernel
#     return ind
    
#   #@staticmethod
#   def select_roulette_wheel(individuals):
#     original_individuals = individuals
#     individual_length = len(original_individuals)
#     new_individuals = []
#     total_sum = 0
#     total_sum = sum([(total_sum + ind.fitness) for ind in individuals])
#     print("total sum: ", total_sum)
#     # random_num = random.randrange(0,int(round(total_sum)))
#     random_num = random.uniform(0,total_sum)
#     partial_sum = 0
#     while len(new_individuals) != individual_length - no_of_elites:
#         for c in original_individuals:
#             partial_sum += c.fitness
#             if(partial_sum >= random_num):
#                 new_individuals.append(c)
#                 # random_num = random.randrange(0,int(round(total_sum)))
#                 random_num = random.uniform(0,total_sum)
#                 partial_sum = 0
#                 break
#     print("Roulette - Selected Individuals Fitness: ",  [ind.fitness for ind in new_individuals])
#     return new_individuals

# def run_ga(pop_size, generation):
#   population = Population(pop_size)
#   board = population.board
#   population.individuals.sort(key=lambda x: x.calc_fitness(board=board, gen=1), reverse= True)
#   for gen in range(1, generation+1):
#       print("Generation: ", gen, " started")
#       gen_fitness_dict = {}
#       gen_best_fitness["gen_"+str(gen)] = population.individuals[0].fitness
#       all_fitness = [ind.fitness for ind in population.individuals]
#       gen_fitness_dict["gen_"+str(gen)] = all_fitness
#       print("Fitness of this generation: ", all_fitness)
#       each_gen_fitness.append(gen_fitness_dict)
#       gen_average_fitness["gen_"+str(gen)] = sum(all_fitness)/len(all_fitness)
#       elite_individuals = [copy.deepcopy(population.individuals[i]) for i in range(0,no_of_elites)]
#       selected_individuals = GeneticAlgorithm.select_roulette_wheel(population.individuals)
#       mutated_individuals = GeneticAlgorithm.mutate_individuals(selected_individuals)
#       for ind in mutated_individuals:
#         ind.calc_fitness(board, gen)
#       print("Mutated population fitness: ",  [ind.fitness for ind in mutated_individuals])
#       population.individuals = elite_individuals + mutated_individuals    
#       population.individuals.sort(key=lambda x: x.fitness, reverse= True)
#       print("elite fitness: ", [ind.fitness for ind in elite_individuals])
#       print("Next generation fitness : ", [ind.fitness for ind in population.individuals])
#       print("Generation ",gen, " completed")
#       print("----------------------------------")
#       print("----------------------------------")

#   print("gen_best_fitness: ", gen_best_fitness)
#   plot_figures(gen_best_fitness, "gen_best_fitness.png")
#   print("gen_average_fitness: ", gen_average_fitness)
#   plot_figures(gen_average_fitness, "gen_average_fitness.png")


# def plot_figures(data, name):
#   plt.clf()
#   labels = list(data.keys())
#   values = list(data.values())
#   plt.plot(labels, values)
#   plt.xlabel('Generation')
#   plt.ylabel('Fitness')
#   plt.title('Fitness of Generations')
#   plt.savefig(name) 

# if __name__ == "__main__":
    
#   if os.path.exists('outputs'):
#     shutil.rmtree('outputs')
#   run_ga(population_size, generation)

# %% [markdown]
# # Merged VoT and AE

# %%
def reconstruct_and_error(board):
    data = []
    # Load the image using OpenCV
    img = np.array(board)
    # Convert the image to grayscale
    # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Resize the image to a fixed size
    resized = cv2.resize(img, (28, 28))
    # Add the image data to the list
    data.append(resized)
    # Add the label to the list
    data = np.array(data)
    predicted_data = autoencoder.predict(data.reshape(1,784), verbose=0)
    plt.ioff()
    # plt.imshow(predicted_data.reshape(28,28), cmap='gist_earth')
    # plt.savefig("/content/recon100/"+str(filename))
    mse = np.mean((-data.reshape(28,28) + predicted_data.reshape(28,28))**2)
    # reconloss_list.append(mse)
    # std_dev = np.std(reconloss_list)
    return predicted_data.reshape(28,28), mse
    # plt.show()

# board = np.random.rand(100, 100)
# # print(board.shape)
# # print(board)
# reco_loss = reconstruct_and_error(board)

# %%
# Updated with merged lenia-ae and vot

import random
import numpy as np
import shutil
import os
import statistics
from matplotlib import pyplot as plt
import sys
import copy
import multiprocessing


kernel_size = 16
board_size = 64
mutation_rate = 0.1
population_size = 10
generation = 10
gen_best_fitness = {}
gen_average_fitness = {}
each_gen_fitness = []
no_of_elites = 1

def random_kernel_generator():
  grid = np.random.rand(kernel_size, kernel_size)
  grid = np.round(grid, 3)
  return grid

def random_board_generator():
  board = np.random.rand(board_size, board_size)
  board = np.round(board, 3)
  return board

class Individual(multiprocessing.Process):

  def __init__(self):
    self.genes = random_kernel_generator()
    self.fitness = 0

  def calc_fitness(self, board, gen):
    lenia = Lenia(self.genes, board)
    board_frames_dict = lenia.run_simulation("gen_"+str(gen))
    board_frames_val = list(board_frames_dict.values())
    errors = []
    frame_alive_cell_count_list = []
    for i in range(len(board_frames_val)):
      frame, board_error = reconstruct_and_error(board_frames_val[i])
      errors.append(board_error)
      board_arr = frame.flatten()
      alive_cell_count = list(board_arr[board_arr > 0.5])
      frame_alive_cell_count_list.append(len(alive_cell_count))

    every_10th_frames = frame_alive_cell_count_list[9::10]
    self.fitness = statistics.pstdev(every_10th_frames)
    # board_stddev = np.std(errors)
    # self.fitness = board_stddev
    return self.fitness


class Population:
  def __init__(self, size):
    self.individuals = []
    self.board = random_board_generator()
    for _ in range(0, size):
        self.individuals.append(Individual())


class GeneticAlgorithm:

  @staticmethod
  def mutate_individuals(individuals):
    mutated_individuals = []
    for ind in individuals:
        mutated_ind = GeneticAlgorithm._mutate_individual(ind)
        mutated_individuals.append(mutated_ind)
    return mutated_individuals

  @staticmethod
  def _mutate_individual(ind):
    kernel = ind.genes
    for i in range(kernel.shape[0]):
        for j in range(kernel.shape[1]):
            if random.random() < mutation_rate:
                kernel[i][j] = np.round(np.random.rand(), 3)
    ind.genes = kernel
    return ind
    
  @staticmethod
  def select_roulette_wheel(individuals):
    original_individuals = individuals
    individual_length = len(original_individuals)
    new_individuals = []
    total_sum = 0
    total_sum = sum([(total_sum + ind.fitness) for ind in individuals])
    print("total sum: ", total_sum)
    # random_num = random.randrange(0,int(round(total_sum)))
    random_num = random.uniform(0,total_sum)
    partial_sum = 0
    while len(new_individuals) != individual_length - no_of_elites:
        for c in original_individuals:
            partial_sum += c.fitness
            if(partial_sum >= random_num):
                new_individuals.append(c)
                # random_num = random.randrange(0,int(round(total_sum)))
                random_num = random.uniform(0,total_sum)
                partial_sum = 0
                break
    print("Roulette - Selected Individuals Fitness: ",  [ind.fitness for ind in new_individuals])
    return new_individuals

def run_ga(pop_size, generation):
  population = Population(pop_size)
  board = population.board
  population.individuals.sort(key=lambda x: x.calc_fitness(board=board, gen=1), reverse= True)
  for gen in range(1, generation+1):
      print("Generation: ", gen, " started")
      gen_fitness_dict = {}
      gen_best_fitness["gen_"+str(gen)] = population.individuals[0].fitness
      all_fitness = [ind.fitness for ind in population.individuals]
      gen_fitness_dict["gen_"+str(gen)] = all_fitness
      print("Fitness of this generation: ", all_fitness)
      each_gen_fitness.append(gen_fitness_dict)
      gen_average_fitness["gen_"+str(gen)] = sum(all_fitness)/len(all_fitness)
      elite_individuals = [copy.deepcopy(population.individuals[i]) for i in range(0,no_of_elites)]
      selected_individuals = GeneticAlgorithm.select_roulette_wheel(population.individuals)
      mutated_individuals = GeneticAlgorithm.mutate_individuals(selected_individuals)
      for ind in mutated_individuals:
        ind.calc_fitness(board, gen)
      print("Mutated population fitness: ",  [ind.fitness for ind in mutated_individuals])
      population.individuals = elite_individuals + mutated_individuals    
      population.individuals.sort(key=lambda x: x.fitness, reverse= True)
      print("elite fitness: ", [ind.fitness for ind in elite_individuals])
      print("Next generation fitness : ", [ind.fitness for ind in population.individuals])
      print("Generation ",gen, " completed")
      print("----------------------------------")
      print("----------------------------------")

  print("gen_best_fitness: ", gen_best_fitness)
  plot_figures(gen_best_fitness, "gen_best_fitness.png")
  print("gen_average_fitness: ", gen_average_fitness)
  plot_figures(gen_average_fitness, "gen_average_fitness.png")


def plot_figures(data, name):
  plt.clf()
  labels = list(data.keys())
  values = list(data.values())
  plt.plot(labels, values)
  plt.xlabel('Generation')
  plt.ylabel('Fitness')
  plt.title('Fitness of Generations')
  plt.savefig(name) 

if __name__ == "__main__":
    
  if os.path.exists('outputs'):
    shutil.rmtree('outputs')
