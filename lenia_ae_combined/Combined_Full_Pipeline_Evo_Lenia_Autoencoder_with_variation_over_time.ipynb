# %% [markdown]
# # 1. Creating 'n' random (using random kernels) lenia images "meaningful" Dataset for AutoEncoder training procedure

# %% [markdown]
# ### For example generating 100 frames each gif, let us just save 10000 images by calling 100 random kernels. As we generate 100 frames each simulation, we just need 100 random simulations for 100 random kernels which produces 100*100=10000 images

# %%
dataset_size = 10
# Imports
# https://chakazul.github.io/Lenia/JavaScript/Lenia.html
import numpy as np
from matplotlib import pyplot as plt
import time
import warnings
warnings.simplefilter("ignore", UserWarning)
#Imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
import scipy.signal
import os.path
import os
from datetime import datetime
from json import JSONEncoder
import json
from pathlib import Path
                

OUTPUT_PATH = './outputs'

mu = 0.31
sigma = 0.057
dt = 0.1


frames = 100



class Lenia:
    def __init__(self, kernel, board):
        self.sigma = sigma
        self.mu = mu
        self.dt = dt
        self.kernel = kernel
        self.normalise_kernel()
        self.frames = frames
        self.anim = None
        self.lenia_board_state = {}
        self.frame_intervals = 10
        # For random initialisation
        self.board = board
        self.cmap = 'viridis'
        self.fig, self.img = self.show_board()
        

    # FLEXIBLITY TO CHANGE GROWTH FUNCTION
    def growth_function1(self, U:np.array):
        gaussian = lambda x, m, s: np.exp(-( (x-m)**2 / (2*s**2) ))
        return gaussian(U, self.mu, self.sigma)*2-1


    def show_board(self, 
                   display:bool=False,
                   ):
        dpi = 50 # Using a higher dpi will result in higher quality graphics but will significantly affect computation

        self.fig = plt.figure(figsize=(10*np.shape(self.board)[1]/dpi, 10*np.shape(self.board)[0]/dpi), dpi=dpi)

        ax = self.fig.add_axes([0, 0, 1, 1])
        ax.axis('off')
        
        self.img = ax.imshow(self.board, cmap=self.cmap, interpolation='none', aspect=1, vmin=0) #  vmax=vmax
        
        if display:
            plt.show()
        else: # Do not show intermediate figures when creating animations (very slow)
            plt.close()

        return self.fig, self.img
    
    
    def animate(self):
        
        self.anim =  matplotlib.animation.FuncAnimation(self.fig, self.animate_step, 
                                            frames=self.frames, interval=self.frame_intervals, blit=True)

    
    def animate_step(self, i:int) -> plt.imshow:
        neighbours = scipy.signal.convolve2d(self.board, self.kernel, mode='same', boundary='wrap')
        self.board = np.clip(self.board + self.dt * self.growth_function1(neighbours), 0, 1)
        if (i+1) % 10 == 0:
            self.record_board_state(i)
        self.img.set_array(self.board) # render the updated state 
        return self.img,

    def save_animation(self, dir, 
                       filename:str,
                       ):
        if not self.anim:
            raise Exception('ERROR: Run animation before attempting to save')
            return 
        output_path = OUTPUT_PATH+"/"+dir
        Path(output_path).mkdir(parents=True, exist_ok=True)
        fmt = os.path.splitext(filename)[1] # isolate the file extension
        
        if fmt == '.gif':
            f = os.path.join(output_path, filename) 
            writer = matplotlib.animation.PillowWriter(fps=30) 
            self.anim.save(f, writer=writer)
        else:
            raise Exception('ERROR: Unknown save format. Must be .gif or .mp4')
        # writer.close()

    
    def normalise_kernel(self) -> np.array:

        kernel_norm = self.kernel / (1*np.sum(self.kernel))
        self.norm_factor = 1/ (1*np.sum(self.kernel))
        self.kernel = kernel_norm 
        return kernel_norm
        
        
    def plot_kernel_info(self,
                         dir,
                         cmap:str='viridis', 
                         bar:bool=False,
                         save:str=None,
                         ) -> None:

        
        k_xsection = self.kernel[self.kernel.shape[0] // 2, :]
        k_sum = np.sum(self.kernel)
        
        fig, ax = plt.subplots(1, 3, figsize=(14,2), gridspec_kw={'width_ratios': [1,1,2]})
        
        # Show kernel as heatmap
        ax[0].imshow(self.kernel, cmap=cmap, vmin=0)
        ax[0].title.set_text('Kernel')
        
        # Show kernel cross-section
        ax[1].title.set_text('Kernel Cross-section')
        if bar==True:
            ax[1].bar(range(0,len(k_xsection)), k_xsection, width=1)
        else:
            ax[1].plot(k_xsection)
        
        # Growth function
        ax[2].title.set_text('Growth Function')
        x = np.linspace(0, k_sum, 1000)
        ax[2].plot(x, self.growth_function1(x))
        
        if save:
            output_path = OUTPUT_PATH+"/"+dir
            Path(output_path).mkdir(parents=True, exist_ok=True)
            print('Saving kernel and growth function info to', os.path.join(output_path, 'kernel_info'))
            
            plt.savefig(os.path.join(output_path, 'kernel_info.png') )


    def run_simulation(self, generation) -> None:
        self.animate()
        sub_dir = generation+"/"+str(datetime.now())
        outfile = "output"+str(datetime.now())+".gif"   
        print('./folder/{}...)'.format(sub_dir))
        
        self.save_animation(sub_dir, outfile)
        self.plot_kernel_info(dir=sub_dir, save=True)
        return self.lenia_board_state


    def record_board_state(self, i):
        board_arr = self.board.flatten()
        board_val_greater_than_point_five = list(board_arr[board_arr > 0.5])
        self.lenia_board_state["frame_"+str(i+1)] = len(board_val_greater_than_point_five)

# %%
kernel_size = 16
board_size = 64
def random_kernel_generator():
    grid = np.random.rand(kernel_size, kernel_size)
    grid = np.round(grid, 3)
    return grid
def random_board_generator():
    board = np.random.rand(board_size, board_size)
    board = np.round(board, 3)
    return board

# %%
# !rm -rf outputs
# !rm -rf sample_data
# !rm *.png
# !rm *.gif
for i in range(dataset_size):
  board = random_board_generator()
  lenia = Lenia(random_kernel_generator(), random_board_generator())
  board_alive_cell = lenia.run_simulation("certain_files")
# Out:
# rm: cannot remove '*.png': No such file or directory
# rm: cannot remove '*.gif': No such file or directory
# ./folder/certain_files/2023-03-30 08:02:48.497333...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-30 08:02:48.497333/kernel_info
# ./folder/certain_files/2023-03-30 08:03:01.183373...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-30 08:03:01.183373/kernel_info
# ./folder/certain_files/2023-03-30 08:03:08.077789...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-30 08:03:08.077789/kernel_info
# ./folder/certain_files/2023-03-30 08:03:15.848814...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-30 08:03:15.848814/kernel_info
# ./folder/certain_files/2023-03-30 08:03:22.616720...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-30 08:03:22.616720/kernel_info
# ./folder/certain_files/2023-03-30 08:03:30.418533...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-30 08:03:30.418533/kernel_info
# ./folder/certain_files/2023-03-30 08:03:38.295445...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-30 08:03:38.295445/kernel_info
# ./folder/certain_files/2023-03-30 08:03:45.073925...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-30 08:03:45.073925/kernel_info
# ./folder/certain_files/2023-03-30 08:03:52.909387...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-30 08:03:52.909387/kernel_info
# ./folder/certain_files/2023-03-30 08:04:00.325664...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-03-30 08:04:00.325664/kernel_info

# %%
# !mv /content/outputs/*/*/*.gif /content/

# %%
# !rm -rf outputs

# %%
# !i=1; for file in *; do mv "$file" "$(printf '%d' $i).${file##*.}"; ((i++)); done

# %%
# !ffmpeg
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Hyper fast Audio and Video encoder
# usage: ffmpeg [options] [[infile options] -i infile]... {[outfile options] outfile}...
#
# Use -h to get full help or, even better, run 'man ffmpeg'

# %%
# !for file in *.gif; do ffmpeg -i "$file" "${file%.*}-%d.jpg"; done
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '10.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5198 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5564ba1bcf80] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '10-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps= 72 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=2.16x
# video:3566kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '1.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 4837 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55d409d58b80] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '1-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.05x
# video:3437kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '2.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 6998 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5568409f89c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '2-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.49x
# video:3460kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '3.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 6272 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x561e6411ccc0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '3-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed= 3.4x
# video:3967kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '4.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5062 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x560d72743f80] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '4-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed= 3.5x
# video:3572kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '5.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5490 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55abed10e600] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '5-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed= 3.5x
# video:3582kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '6.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5595 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x557dd4fa1400] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '6-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.45x
# video:3754kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '7.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 6248 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x56013d5ed6c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '7-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.47x
# video:3800kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '8.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 6099 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5653ae938080] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '8-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed= 3.4x
# video:3786kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '9.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 6594 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x556dacb75ec0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '9-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed= 3.4x
# video:3838kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !rm *.gif
# !rm *.png
# Out:
# rm: cannot remove '*.png': No such file or directory

# %%
# !i=1; for file in *; do mv "$file" "$(printf '%d' $i).${file##*.}"; ((i++)); done

# %%
# !mkdir dataset
# !mv *.jpg dataset

# %%
# !ls /content/dataset | wc -l
# Out:
# 1000

# %% [markdown]
# # 2. AutoEncoder procedure

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "/content/dataset/"

# Initialize lists to hold the image data and labels
data = []

# Loop over the files in the folder
for filename in os.listdir(folder_path):
    # Load the image using OpenCV
    img = cv2.imread(os.path.join(folder_path, filename))
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Resize the image to a fixed size
    resized = cv2.resize(gray, (28, 28))
    # Add the image data to the list
    data.append(resized)
    # Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)

# Split the data into training and testing sets

# %%
xtrain, xtest = train_test_split(data, test_size=0.3, random_state=2)

     

X_train = xtrain.reshape(xtrain.shape[0], 28, 28, 1)
X_test = xtest.reshape(xtest.shape[0], 28, 28, 1)

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.layers import Layer
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, add
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras import regularizers
from keras.regularizers import l2
from keras.layers.convolutional import Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D
from keras.utils import np_utils

# %%
X_train = X_train.astype("float32")/255.
X_test = X_test.astype("float32")/255.

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (700, 28, 28, 1)
# 700 train samples
# 300 test samples

# %%
X_train = X_train.reshape((len(X_train), np.prod(X_train.shape[1:])))
X_test = X_test.reshape((len(X_test), np.prod(X_test.shape[1:])))

# %%
input_size = 784
hidden_size = 36
output_size = 784

# %%
x = Input(shape=(input_size,))
h = Dense(hidden_size, activation='relu')(x)
r = Dense(output_size, activation='sigmoid')(h)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adam', loss='mse')
     

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(autoencoder).create(prog='dot', format='svg'))

# %%
epochs = 300
batch_size = 128

history = autoencoder.fit(X_train, X_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test, X_test))
# Out:
# Epoch 1/300
# 6/6 [==============================] - 1s 43ms/step - loss: 0.1089 - val_loss: 0.1066
# Epoch 2/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1048 - val_loss: 0.1007
# Epoch 3/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0978 - val_loss: 0.0924
# Epoch 4/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0891 - val_loss: 0.0836
# Epoch 5/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0804 - val_loss: 0.0758
# Epoch 6/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0730 - val_loss: 0.0693
# Epoch 7/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0666 - val_loss: 0.0635
# Epoch 8/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0608 - val_loss: 0.0580
# Epoch 9/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0554 - val_loss: 0.0528
# Epoch 10/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0504 - val_loss: 0.0482
# Epoch 11/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0460 - val_loss: 0.0442
# Epoch 12/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0423 - val_loss: 0.0408
# Epoch 13/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0392 - val_loss: 0.0380
# Epoch 14/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0365 - val_loss: 0.0355
# Epoch 15/300
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0341 - val_loss: 0.0332
# Epoch 16/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0319 - val_loss: 0.0311
# Epoch 17/300
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0299 - val_loss: 0.0291
# Epoch 18/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0279 - val_loss: 0.0273
# Epoch 19/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0261 - val_loss: 0.0255
# Epoch 20/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0245 - val_loss: 0.0240
# Epoch 21/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0231 - val_loss: 0.0226
# Epoch 22/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0217 - val_loss: 0.0214
# Epoch 23/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0206 - val_loss: 0.0203
# Epoch 24/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0196 - val_loss: 0.0193
# Epoch 25/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0186 - val_loss: 0.0184
# Epoch 26/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0178 - val_loss: 0.0176
# Epoch 27/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0171 - val_loss: 0.0169
# Epoch 28/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0164 - val_loss: 0.0163
# Epoch 29/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0158 - val_loss: 0.0157
# Epoch 30/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 31/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0148 - val_loss: 0.0148
# Epoch 32/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0144 - val_loss: 0.0144
# Epoch 33/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0141 - val_loss: 0.0141
# Epoch 34/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0137 - val_loss: 0.0138
# Epoch 35/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0134 - val_loss: 0.0135
# Epoch 36/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0131 - val_loss: 0.0132
# Epoch 37/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0129 - val_loss: 0.0130
# Epoch 38/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0127 - val_loss: 0.0128
# Epoch 39/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0126
# Epoch 40/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0122 - val_loss: 0.0124
# Epoch 41/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 0.0122
# Epoch 42/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0118 - val_loss: 0.0120
# Epoch 43/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0117 - val_loss: 0.0118
# Epoch 44/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0115 - val_loss: 0.0117
# Epoch 45/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0113 - val_loss: 0.0115
# Epoch 46/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0112 - val_loss: 0.0114
# Epoch 47/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 48/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0108 - val_loss: 0.0111
# Epoch 49/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 50/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 51/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 52/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 53/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0102 - val_loss: 0.0104
# Epoch 54/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0100 - val_loss: 0.0103
# Epoch 55/300
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0099 - val_loss: 0.0102
# Epoch 56/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 57/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 58/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0095 - val_loss: 0.0098
# Epoch 59/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0094 - val_loss: 0.0097
# Epoch 60/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0093 - val_loss: 0.0096
# Epoch 61/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0093 - val_loss: 0.0096
# Epoch 62/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0091 - val_loss: 0.0094
# Epoch 63/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0090 - val_loss: 0.0093
# Epoch 64/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0089 - val_loss: 0.0093
# Epoch 65/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0089 - val_loss: 0.0092
# Epoch 66/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0088 - val_loss: 0.0091
# Epoch 67/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 68/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0086 - val_loss: 0.0089
# Epoch 69/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 70/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0084 - val_loss: 0.0088
# Epoch 71/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0084 - val_loss: 0.0087
# Epoch 72/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0083 - val_loss: 0.0086
# Epoch 73/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0082 - val_loss: 0.0085
# Epoch 74/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0085
# Epoch 75/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 76/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 77/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 78/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 0.0082
# Epoch 79/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 80/300
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0077 - val_loss: 0.0081
# Epoch 81/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0077 - val_loss: 0.0080
# Epoch 82/300
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0076 - val_loss: 0.0080
# Epoch 83/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0079
# Epoch 84/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0079
# Epoch 85/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0078
# Epoch 86/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0074 - val_loss: 0.0078
# Epoch 87/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0073 - val_loss: 0.0077
# Epoch 88/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0077
# Epoch 89/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 90/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0076
# Epoch 91/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0076
# Epoch 92/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0075
# Epoch 93/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0070 - val_loss: 0.0075
# Epoch 94/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0070 - val_loss: 0.0074
# Epoch 95/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0070 - val_loss: 0.0074
# Epoch 96/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0069 - val_loss: 0.0074
# Epoch 97/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0069 - val_loss: 0.0073
# Epoch 98/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 99/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 100/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 101/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 102/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 103/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 104/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 105/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 106/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 107/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 108/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 109/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0069
# Epoch 110/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0069
# Epoch 111/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0064 - val_loss: 0.0069
# Epoch 112/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 113/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 114/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 115/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 116/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 117/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 118/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 119/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 120/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 121/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 122/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 123/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 124/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 125/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 126/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 127/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 128/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0065
# Epoch 129/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0064
# Epoch 130/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0064
# Epoch 131/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0059 - val_loss: 0.0064
# Epoch 132/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0064
# Epoch 133/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 134/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 135/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 136/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 137/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0057 - val_loss: 0.0063
# Epoch 138/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 139/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 140/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 141/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 142/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 143/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 144/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 145/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 146/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 147/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 148/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 149/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 150/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 151/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 152/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 153/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 154/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 155/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 156/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 157/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 158/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 159/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 160/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 161/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 162/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 163/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 164/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 165/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 166/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 167/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 168/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 169/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 170/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 171/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0058
# Epoch 172/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 173/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 174/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 175/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 176/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 177/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 178/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 179/300
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 180/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 181/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 182/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 183/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 184/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 185/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0057
# Epoch 186/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 187/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 188/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 189/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 190/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 191/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 192/300
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 193/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 194/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 195/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 196/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 197/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 198/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 199/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 200/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 201/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 202/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 203/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 204/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 205/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 206/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 207/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 208/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 209/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 210/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 211/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 212/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 213/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 214/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 215/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 216/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 217/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 218/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 219/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 220/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 221/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 222/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 223/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 224/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 225/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 226/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 227/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 228/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 229/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 230/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 231/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 232/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 233/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 234/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 235/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 236/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 237/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 238/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 239/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 240/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 241/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 242/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 243/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 244/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 245/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 246/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 247/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 248/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 249/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 250/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 251/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 252/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 253/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 254/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 255/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 256/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 257/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 258/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 259/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 260/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 261/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 262/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 263/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 264/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 265/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 266/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 267/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 268/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 269/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 270/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 271/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 272/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 273/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 274/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 275/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 276/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 277/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 278/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 279/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 280/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 281/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 282/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 283/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 284/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 285/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 286/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 287/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 288/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 289/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 290/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 291/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 292/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 293/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 294/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 295/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 296/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 297/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 298/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 299/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 300/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0052

# %%
conv_encoder = Model(x, h)
encoded_imgs = conv_encoder.predict(X_test)

n = 1
plt.figure(figsize=(28, 10))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(encoded_imgs[i].reshape(6, 6).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
decoded_imgs = autoencoder.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
n = 1
plt.figure(figsize=(28, 28))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i+1)
    plt.imshow(X_test[i].reshape(28, 28),cmap="gist_earth")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
plt.figure(figsize=(28,28))
for i in range(n):    
    # display reconstruction
    ax = plt.subplot(3, n, i+n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap="gist_earth")
    # plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %%
print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
import tensorflow as tf
i=99
print("Error or loss for the image "+str(i))
print(tf.math.reduce_mean(tf.square(decoded_imgs[i].reshape(28, 28)-X_test[i].reshape(28, 28))))
print("------------------------------------------------------------------")
# Out:
# Error or loss for the image 99
# tf.Tensor(0.004764496, shape=(), dtype=float32)
# ------------------------------------------------------------------

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 36)                28260
#
#  dense_1 (Dense)             (None, 784)               29008
#
# =================================================================
# Total params: 57,268
# Trainable params: 57,268
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Test the model with any random lenia board state

# %%
# Check for orderly image reconstruction loss
# !wget https://dl3.pushbulletusercontent.com/pVIOI0eH0xLUqrczqileIhK0fUO5n0OL/order.jpg
# !wget https://dl3.pushbulletusercontent.com/r8r00OkVim4UwQEyqEG5diLnZWNni1e4/order.jpg
from IPython.display import Image
Image("order.jpg",width = 256, height = 256)
# Out:
# --2023-03-30 08:05:19--  https://dl3.pushbulletusercontent.com/r8r00OkVim4UwQEyqEG5diLnZWNni1e4/order.jpg
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71152 (69K) [image/jpeg]
# Saving to: ‘order.jpg’
#
# order.jpg           100%[===================>]  69.48K  --.-KB/s    in 0.09s
#
# 2023-03-30 08:05:20 (767 KB/s) - ‘order.jpg’ saved [71152/71152]

# %%
# Check for orderly image reconstruction loss
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "./"

# Initialize lists to hold the image data and labels
data = []

filename = "order.jpg"
# Load the image using OpenCV
img = cv2.imread(os.path.join(folder_path, filename))
# Resize the image to a fixed size
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
# Add the image data to the list
data.append(resized)
# Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)
data.shape
# Out:
# (1, 28, 28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_order_image = autoencoder.predict(data[0].reshape(1,784))
print(predicted_order_image.shape)
# Out:
# 1/1 [==============================] - 0s 50ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_order_image.reshape(28,28))

# %%
# # RECONSTRUCTION LOSS
# import tensorflow as tf
# print(tf.math.reduce_mean(predicted_order_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
import tensorflow as tf
print("recon loss MSE")
import numpy as np

# assuming original_img and reconstructed_img are numpy arrays of shape (28, 28)
mse = np.mean((-data[0].reshape(28,28) + predicted_order_image.reshape(28,28))**2)
print(mse)
# Out:
# recon loss MSE
# 28314.484

# %%
# Check for chaotic image reconstruction loss
# !wget https://dl3.pushbulletusercontent.com/JMja0JFwu2M2r1A2XFKJUhj2d049mh28/chaotic.jpg
# !wget https://dl3.pushbulletusercontent.com/HiHs0WSO0K8cEiYGfeWPeW0Q5MDGkmCs/chaotic.jpg
from IPython.display import Image
Image("chaotic.jpg",width = 256, height = 256)
# Out:
# --2023-03-30 08:05:20--  https://dl3.pushbulletusercontent.com/HiHs0WSO0K8cEiYGfeWPeW0Q5MDGkmCs/chaotic.jpg
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 202671 (198K) [image/jpeg]
# Saving to: ‘chaotic.jpg’
#
# chaotic.jpg         100%[===================>] 197.92K  --.-KB/s    in 0.1s
#
# 2023-03-30 08:05:21 (1.30 MB/s) - ‘chaotic.jpg’ saved [202671/202671]

# %%
# Check for orderly image reconstruction loss
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "./"

# Initialize lists to hold the image data and labels
data = []

filename = "chaotic.jpg"
# Load the image using OpenCV
img = cv2.imread(os.path.join(folder_path, filename))
# Resize the image to a fixed size
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
# Add the image data to the list
data.append(resized)
# Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)

# %%
data.shape
# Out:
# (1, 28, 28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_chaotic_image = autoencoder.predict(data[0].reshape(1,784))
print(predicted_chaotic_image.shape)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_chaotic_image.reshape(28,28))

# %%
# # RECONSTRUCTION LOSS
# import tensorflow as tf
# print(tf.math.reduce_mean(predicted_chaotic_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
import tensorflow as tf
print("recon loss MSE")
import numpy as np

# assuming original_img and reconstructed_img are numpy arrays of shape (28, 28)
mse = np.mean((-data[0].reshape(28,28) + predicted_chaotic_image.reshape(28,28))**2)
print(mse)
# Out:
# recon loss MSE
# 26433.74

# %% [markdown]
# # 4. Picking random image from test dataset and result reconstructed loss

# %%
import random
data = X_test[random.randint(1,len(X_test))].reshape(1,28,28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_chaotic_image = autoencoder.predict(data[0].reshape(1,784))
print(predicted_chaotic_image.shape)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_chaotic_image.reshape(28,28))

# %%
# # RECONSTRUCTION LOSS
# import tensorflow as tf
# print(tf.math.reduce_mean(predicted_chaotic_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
import tensorflow as tf
print("recon loss MSE")
import numpy as np

# assuming original_img and reconstructed_img are numpy arrays of shape (28, 28)
mse = np.mean((-data[0].reshape(28,28) + predicted_chaotic_image.reshape(28,28))**2)
print(mse)
# Out:
# recon loss MSE
# 0.003963402

# %% [markdown]
# # 4. Picking 10 random images from test dataset and result reconstructed loss

# %%
import random

images_10 = []
for i in range(10):
  data = X_test[random.randint(1,len(X_test))].reshape(1,28,28)
  # plt.imshow(data[0])
  images_10.append(data[0])
fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(20, 4))

# display each image in a separate subplot

for i in range(10):
  axes[i].imshow(images_10[i].reshape(28,28))
  axes[i].axis('off')
# plt.title("Ground Truth Images",fontsize=16, loc='center')
fig.suptitle('Ground Truth Images', fontsize=16, fontweight='bold')
fig.tight_layout()

plt.show()

# %%
predicted_images = []
for i in range(10):
  predicted_chaotic_image = autoencoder.predict(images_10[i].reshape(1,784))
  predicted_images.append(predicted_chaotic_image)
fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(20, 4))

# display each image in a separate subplot

for i in range(10):
  axes[i].imshow(predicted_images[i].reshape(28,28))
  axes[i].axis('off')
# plt.title("Ground Truth Images",fontsize=16, loc='center')
fig.suptitle('Predicted Images', fontsize=16, fontweight='bold')
fig.tight_layout()

plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
predicted_images = []
for i in range(10):
  predicted_chaotic_image = autoencoder.predict(images_10[i].reshape(1,784))
  predicted_images.append(predicted_chaotic_image)
fig, axes = plt.subplots(nrows=2, ncols=10, figsize=(40, 8))

# display each image in a separate subplot
for j in range(2):
  for i in range(10):
    if(j==1):
      axes[j][i].imshow(predicted_images[i].reshape(28,28))
      axes[j][i].axis('off')
      # axes[j].set_title('Predicted Images')
      axes[j][i].set_title('Predicted Image '+str(i))
      mse = np.mean((-images_10[i].reshape(28,28) + predicted_images[i].reshape(28,28))**2)
      # print(mse)
      string = "Reconstruction Loss: "+str(round(mse,8))
      axes[j][i].text(0.5, -0.1,string, fontsize=10, ha='center',transform=axes[j][i].transAxes)
    else:
      axes[j][i].imshow(images_10[i].reshape(28,28))
      axes[j][i].axis('off')
      axes[j][i].set_title('Ground Truth Image '+str(i))
      # axes[j].set_title('Ground Truth Images')
# plt.title("Ground Truth Images",fontsize=16, loc='center')
fig.suptitle('Ground Truth Images 1st row, Predicted Images 2nd row', fontsize=16, fontweight='bold')
fig.tight_layout()

plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step

# %% [markdown]
# #From the last meeting Stefano suggested to use:
#
# ### ⛳Bottleneck = Shrink Size (have shrinked from 64 to 32)
#
# ### ⛳Meaningful Dataset = As of now I am generating 'n' random gifs and saving their frames and putting them as dataset
#
# ### ⛳ Stefano suggested to use deviation as measure of emerging pattern rather than reconstruction loss.
# ##### ==> so the idea is to maximise the deviation of reconstruction. The more the pixels are deviated over time in a reconstructed animation (so let say we have 100 frames of original rule set. those 100 frames vs same frames reconstructed through Autoencoder. The hypothesis is, if we have deviation in reconstruction of those 100 frames, that means there should be some non-boring behaviour)
#
# ✅
# Theory: Autoencoder is a type of neural network that can be used for dimensionality reduction and feature extraction. One way it can help in measuring complexity is by using reconstruction error.
#
# The basic idea of an autoencoder is to learn a compressed representation of the input data, and then use that representation to reconstruct the original data. The input data is first encoded into a compressed representation, which is then decoded back into the original data. The goal is to minimize the difference between the input data and the reconstructed output.
#
# If the autoencoder is successful in reconstructing the input data accurately, then the reconstruction error will be low. However, if the input data is complex and has a lot of variability, it may be difficult for the autoencoder to reconstruct the data accurately, resulting in a higher reconstruction error.
#
# Therefore, the reconstruction error can be used as a measure of complexity, where higher reconstruction error indicates higher complexity. This is because complex data is more difficult to accurately represent and reconstruct using a compressed representation.
#
# In summary, autoencoder can help in measuring complexity using reconstruction error, where the higher reconstruction error indicates higher complexity of the input data.

# %% [markdown]
# ### ⭐ How variation over time can be thought:
# To use an autoencoder for time series data, you can treat each time step as a separate input and train the autoencoder to reconstruct the original sequence of data. The reconstruction loss, which is the difference between the input and the reconstructed output, can then be used to measure the complexity of the time series data.
#
# By analyzing the variation in the reconstruction loss over time, you can gain insights into the complexity of the time series. For example, if the reconstruction loss is relatively constant over time, it may indicate that the time series is relatively simple or predictable. However, if the reconstruction loss varies widely over time, it may indicate that the time series is more complex and difficult to predict.
#
# Additionally, you can use techniques such as spectral analysis or wavelet analysis to further analyze the variation in the reconstruction loss over time. These techniques can help identify patterns and correlations in the data that may not be immediately apparent from the reconstruction loss alone.
#
# In summary, using an autoencoder for time series data and analyzing the variation over time in the reconstruction loss can be a useful approach for measuring the complexity of the time series data.

# %% [markdown]
# # Let us analyse for one case:
# ### step1: generate one random pattern, save first 100 frames
# ### step2: generate reconstruction of those 100 frames using trained auto-encoder
# ### step3: check for variation in reconstruction loss over time between both the frame-sets.

# %%
lenia.run_simulation("outputs") # saving one animation
# Out:
# ./folder/outputs/2023-03-30 08:05:26.919820...)
# Saving kernel and growth function info to ./outputs/outputs/2023-03-30 08:05:26.919820/kernel_info
# {'frame_10': 1714,
#  'frame_20': 1684,
#  'frame_30': 1686,
#  'frame_40': 1733,
#  'frame_50': 1713,
#  'frame_60': 1698,
#  'frame_70': 1714,
#  'frame_80': 1664,
#  'frame_90': 1726,
#  'frame_100': 1740}

# %%
# !mv /content/outputs/outputs/*/*.gif /content/

# %%
# !rm -rf /content/outputs

# %%
# !mkdir original100
# !mv *.gif original100
# %cd original100
# !for file in *.gif; do ffmpeg -i "$file" "${file%.*}-%d.jpg"; done
# %cd /content/
# Out:
# /content/original100
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from 'output2023-03-30 08:05:26.919834.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 1953 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55caaca14b00] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'output2023-03-30 08:05:26.919834-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.92x
# video:2409kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content

# %%
# %cd /content/original100
# !i=1; for file in *; do mv "$file" "$(printf '%d' $i).${file##*.}"; ((i++)); done
# %cd /content/
# Out:
# /content/original100
# /content

# %%
# %cd /content/original100/
# !rm *.gif
# %cd /content/
# Out:
# /content/original100
# /content

# %%
# !mkdir recon100
# %cd recon100
# Out:
# /content/recon100

# %%
reconloss_list = []

# Loop over the files in the folder and save predicted outputs as image in another folder recon100
for filename in os.listdir("/content/original100/"):
    print("saving ",filename)
    data = []
    # Load the image using OpenCV
    img = cv2.imread(os.path.join("/content/original100/", filename))
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Resize the image to a fixed size
    resized = cv2.resize(gray, (28, 28))
    # Add the image data to the list
    data.append(resized)
    # Add the label to the list
    data = np.array(data)
    predicted_data = autoencoder.predict(data.reshape(1,784))
    plt.imshow(predicted_data.reshape(28,28), cmap='gist_earth')
    plt.savefig("/content/recon100/"+str(filename))
    mse = np.mean((-data.reshape(28,28) + predicted_data.reshape(28,28))**2)
    reconloss_list.append(mse)
    # plt.show()
# Out:
# saving  84.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  56.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  18.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  6.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  69.jpg
# 1/1 [==============================] - 0s 27ms/step
# saving  62.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  25.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  86.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  33.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  37.jpg
# 1/1 [==============================] - 0s 34ms/step
# saving  98.jpg
# 1/1 [==============================] - 0s 35ms/step
# saving  91.jpg
# 1/1 [==============================] - 0s 35ms/step
# saving  36.jpg
# 1/1 [==============================] - 0s 36ms/step
# saving  48.jpg
# 1/1 [==============================] - 0s 31ms/step
# saving  92.jpg
# 1/1 [==============================] - 0s 30ms/step
# saving  74.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  34.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  47.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  41.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  42.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  8.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  30.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  83.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  87.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  38.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  77.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  16.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  68.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  80.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  31.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  81.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  88.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  73.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  89.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  2.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  67.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  45.jpg
# 1/1 [==============================] - 0s 32ms/step
# saving  22.jpg
# 1/1 [==============================] - 0s 33ms/step
# saving  29.jpg
# 1/1 [==============================] - 0s 30ms/step
# saving  71.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  51.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  7.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  76.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  72.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  13.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  20.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  58.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  99.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  19.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  65.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  49.jpg
# 1/1 [==============================] - 0s 19ms/step
# saving  15.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  82.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  90.jpg
# 1/1 [==============================] - 0s 40ms/step
# saving  10.jpg
# 1/1 [==============================] - 0s 35ms/step
# saving  94.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  9.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  95.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  52.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  44.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  3.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  17.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  1.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  78.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  26.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  61.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  93.jpg
# 1/1 [==============================] - 0s 32ms/step
# saving  54.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  100.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  66.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  46.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  23.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  96.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  32.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  27.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  5.jpg
# 1/1 [==============================] - 0s 36ms/step
# saving  21.jpg
# 1/1 [==============================] - 0s 31ms/step
# saving  64.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  60.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  97.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  85.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  53.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  57.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  11.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  43.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  79.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  35.jpg
# 1/1 [==============================] - 0s 38ms/step
# saving  75.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  14.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  4.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  39.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  24.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  28.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  59.jpg
# 1/1 [==============================] - 0s 27ms/step
# saving  40.jpg
# 1/1 [==============================] - 0s 31ms/step
# saving  50.jpg
# 1/1 [==============================] - 0s 32ms/step
# saving  55.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  63.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  70.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  12.jpg
# 1/1 [==============================] - 0s 21ms/step

# %%
print("The reconstruction loss between original data and the predicted or reconstructued data for 100 frames is:")
print(reconloss_list)
# Out:
# The reconstruction loss between original data and the predicted or reconstructued data for 100 frames is:
# [31800.178, 28217.77, 27927.607, 31388.467, 27867.05, 30631.234, 28719.957, 31758.068, 31186.611, 30202.078, 27545.402, 29991.492, 30581.395, 28237.035, 29296.98, 27975.219, 27962.309, 27914.117, 28209.605, 27901.768, 31515.14, 30853.639, 31690.05, 31533.082, 29650.408, 29390.533, 28681.691, 28125.158, 30510.486, 31161.734, 30963.12, 31165.234, 27809.457, 29132.342, 30106.69, 28472.39, 28016.842, 28048.082, 30538.215, 27669.66, 29872.936, 31558.686, 28823.361, 27700.076, 30167.703, 27754.393, 31862.44, 27699.81, 27781.19, 28952.133, 28609.186, 29174.96, 31521.322, 30621.875, 31066.127, 28301.547, 31344.234, 27871.678, 30504.098, 27550.133, 30541.041, 28267.95, 28001.291, 28773.893, 29206.49, 31060.139, 28560.973, 31351.164, 29578.361, 28482.848, 27722.844, 28009.88, 27683.756, 31355.592, 29789.389, 31176.19, 27794.484, 29464.066, 31546.88, 27485.3, 31735.643, 30961.719, 31869.703, 30593.592, 27733.852, 29933.008, 30899.031, 28322.902, 29667.908, 30921.0, 29089.627, 28338.674, 30244.668, 31662.285, 28621.4, 29224.3, 31638.453, 30042.477, 27718.016, 28164.244]

# %% [markdown]
# # By analyzing the variation in the reconstruction loss over time, you can gain insights into the complexity of the time series. For example, if the reconstruction loss is relatively constant over time, it may indicate that the time series is relatively simple or predictable. However, if the reconstruction loss varies widely over time, it may indicate that the time series is more complex and difficult to predict.

# %%
import numpy as np
std_dev = np.std(reconloss_list)

# Print the standard deviation of the list
print("Standard Deviation of the Reconstruction list is % s" % (std_dev))
# Out:
# Standard Deviation of the Reconstruction list is 1440.8027

# %%
# def reconstruct_and_error(board):
#     data = []
#     # Load the image using OpenCV
#     img = np.array(board)
#     # Convert the image to grayscale
#     # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     # Resize the image to a fixed size
#     resized = cv2.resize(img, (28, 28))
#     # Add the image data to the list
#     data.append(resized)
#     # Add the label to the list
#     data = np.array(data)
#     predicted_data = autoencoder.predict(data.reshape(1,784), verbose=0)
#     plt.ioff()
#     # plt.imshow(predicted_data.reshape(28,28), cmap='gist_earth')
#     # plt.savefig("/content/recon100/"+str(filename))
#     mse = np.mean((-data.reshape(28,28) + predicted_data.reshape(28,28))**2)
#     # reconloss_list.append(mse)
#     # std_dev = np.std(reconloss_list)
#     return mse
#     # plt.show()

# # board = np.random.rand(100, 100)
# # # print(board.shape)
# # # print(board)
# # reco_loss = reconstruct_and_error(board)

# %%
# def calc_fitness(self, boards_list, gen):
#   errors = []
#   for i in range(len(boards_list)):
#     board_error = reconstruct_and_error(boards_list[i])
#     errors.append(board_error)
#   board_stddev = np.std(errors)
#   self.fitness = board_stddev
#   return self.fitness

# %%
# %cd /content/
# Out:
# /content

# %%
# Imports
# https://chakazul.github.io/Lenia/JavaScript/Lenia.html
import numpy as np
from matplotlib import pyplot as plt
import time
import warnings
warnings.simplefilter("ignore", UserWarning)
#Imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
import scipy.signal
import os.path
import os
from datetime import datetime
from json import JSONEncoder
import json
from pathlib import Path
                

OUTPUT_PATH = './outputs'
MAX_FRAMES = 3000

mu = 0.31
sigma = 0.057
dt = 0.1


frames = 100
frame_intervals = float(50)



class Lenia:
    def __init__(self, kernel, board):
        self.sigma = sigma
        self.mu = mu
        self.dt = dt
        self.kernel = kernel
        self.normalise_kernel()
        self.frames = frames
        self.frame_intervals = frame_intervals
        self.anim = None
        self.lenia_board_state = {}
        # For random initialisation
        self.board = board
        self.cmap = 'viridis'
        self.fig, self.img = self.show_board()
        

    # FLEXIBLITY TO CHANGE GROWTH FUNCTION
    def growth_function1(self, U:np.array):
        gaussian = lambda x, m, s: np.exp(-( (x-m)**2 / (2*s**2) ))
        return gaussian(U, self.mu, self.sigma)*2-1


    def show_board(self, 
                   display:bool=False,
                   ):
        dpi = 50 # Using a higher dpi will result in higher quality graphics but will significantly affect computation

        self.fig = plt.figure(figsize=(10*np.shape(self.board)[1]/dpi, 10*np.shape(self.board)[0]/dpi), dpi=dpi)

        ax = self.fig.add_axes([0, 0, 1, 1])
        ax.axis('off')
        
        self.img = ax.imshow(self.board, cmap=self.cmap, interpolation='none', aspect=1, vmin=0) #  vmax=vmax
        
        if display:
            plt.show()
        else: # Do not show intermediate figures when creating animations (very slow)
            plt.close()

        return self.fig, self.img
    
    
    def animate(self):
        self.anim =  matplotlib.animation.FuncAnimation(self.fig, self.animate_step, 
                                            frames=self.frames, interval=self.frame_intervals, save_count=MAX_FRAMES, blit=True)

    
    def animate_step(self, i:int) -> plt.imshow:
        neighbours = scipy.signal.convolve2d(self.board, self.kernel, mode='same', boundary='wrap')
        self.board = np.clip(self.board + self.dt * self.growth_function1(neighbours), 0, 1)
        # if (i+1) % 10 == 0:
        self.record_board_state(i)
        self.img.set_array(self.board) # render the updated state 
        return self.img,
    
    
    def save_animation(self, dir, 
                       filename:str,
                       ):
        if not self.anim:
            raise Exception('ERROR: Run animation before attempting to save')
            return 
        output_path = OUTPUT_PATH+"/"+dir
        Path(output_path).mkdir(parents=True, exist_ok=True)
        fmt = os.path.splitext(filename)[1] # isolate the file extension
        
        if fmt == '.gif':
            f = os.path.join(output_path, filename) 
            writer = matplotlib.animation.PillowWriter(fps=30) 
            self.anim.save(f, writer=writer)
        else:
            raise Exception('ERROR: Unknown save format. Must be .gif or .mp4')
        # writer.close()

    
    def normalise_kernel(self) -> np.array:

        kernel_norm = self.kernel / (1*np.sum(self.kernel))
        self.norm_factor = 1/ (1*np.sum(self.kernel))
        self.kernel = kernel_norm 
        return kernel_norm
        
        
    def plot_kernel_info(self,
                         dir,
                         cmap:str='viridis', 
                         bar:bool=False,
                         save:str=None,
                         ) -> None:

        
        k_xsection = self.kernel[self.kernel.shape[0] // 2, :]
        k_sum = np.sum(self.kernel)
        
        fig, ax = plt.subplots(1, 3, figsize=(14,2), gridspec_kw={'width_ratios': [1,1,2]})
        
        # Show kernel as heatmap
        ax[0].imshow(self.kernel, cmap=cmap, vmin=0)
        ax[0].title.set_text('Kernel')
        
        # Show kernel cross-section
        ax[1].title.set_text('Kernel Cross-section')
        if bar==True:
            ax[1].bar(range(0,len(k_xsection)), k_xsection, width=1)
        else:
            ax[1].plot(k_xsection)
        
        # Growth function
        ax[2].title.set_text('Growth Function')
        x = np.linspace(0, k_sum, 1000)
        ax[2].plot(x, self.growth_function1(x))
        
        if save:
            output_path = OUTPUT_PATH+"/"+dir
            Path(output_path).mkdir(parents=True, exist_ok=True)
            # print('Saving kernel and growth function info to', os.path.join(output_path, 'kernel_info'))
            
            plt.savefig(os.path.join(output_path, 'kernel_info.png') )


    def run_simulation(self, generation) -> None:
        self.animate()
        sub_dir = generation+"/"+str(datetime.now())
        outfile = 'output.gif'   
        # print('./folder/{}...)'.format(sub_dir))
        
        self.save_animation(sub_dir, outfile)
        self.plot_kernel_info(dir=sub_dir, save=True)
        return self.lenia_board_state


    def record_board_state(self, i):
        # board_arr = self.board.flatten()
        # board_val_greater_than_point_five = list(board_arr[board_arr > 0.5])
        self.lenia_board_state["frame_"+str(i+1)] = self.board




# # ###### DELETE CODE AFTER THIS LINE AFTER TESTING#####################
# def random_kernel_generator():
#     grid = np.random.rand(2, 2)
#     grid = np.round(grid, 3)
#     return grid

# def random_board_generator():
#     board = np.random.rand(6, 6)
#     board = np.round(board, 3)
#     return board


# if __name__ == "__main__":
#     lenia = Lenia(random_kernel_generator(), random_board_generator())
#     board_frames = lenia.run_simulation("gen_"+str(1))
#     boards_list = list(board_frames.values())
#     # for k,v in board_frames.items():
#       # print(v.shape)

# %%
# import random
# import numpy as np
# import shutil
# import os
# import statistics
# from matplotlib import pyplot as plt
# import sys
# import copy
# import multiprocessing


# kernel_size = 16
# board_size = 64
# mutation_rate = 0.1
# population_size = 10
# generation = 30
# gen_best_fitness = {}
# gen_average_fitness = {}
# each_gen_fitness = []
# no_of_elites = 1

# def random_kernel_generator():
#   grid = np.random.rand(kernel_size, kernel_size)
#   grid = np.round(grid, 3)
#   return grid

# def random_board_generator():
#   board = np.random.rand(board_size, board_size)
#   board = np.round(board, 3)
#   return board

# class Individual(multiprocessing.Process):

#   def __init__(self):
#     self.genes = random_kernel_generator()
#     self.fitness = 0

#   def calc_fitness(self, board, gen):
#     lenia = Lenia(self.genes, board)
#     board_frames_dict = lenia.run_simulation("gen_"+str(gen))
#     board_frames_val = list(board_frames_dict.values())
#     errors = []
#     for i in range(len(board_frames_val)):
#       board_error = reconstruct_and_error(board_frames_val[i])
#       errors.append(board_error)
#     board_stddev = np.std(errors)
#     self.fitness = board_stddev
#     return self.fitness


# class Population:
#   def __init__(self, size):
#     self.individuals = []
#     self.board = random_board_generator()
#     for _ in range(0, size):
#         self.individuals.append(Individual())


# class GeneticAlgorithm:

#   #@staticmethod
#   def mutate_individuals(individuals):
#     mutated_individuals = []
#     for ind in individuals:
#         mutated_ind = GeneticAlgorithm._mutate_individual(ind)
#         mutated_individuals.append(mutated_ind)
#     return mutated_individuals

#   #@staticmethod
#   def _mutate_individual(ind):
#     kernel = ind.genes
#     for i in range(kernel.shape[0]):
#         for j in range(kernel.shape[1]):
#             if random.random() < mutation_rate:
#                 kernel[i][j] = np.round(np.random.rand(), 3)
#     ind.genes = kernel
#     return ind
    
#   #@staticmethod
#   def select_roulette_wheel(individuals):
#     original_individuals = individuals
#     individual_length = len(original_individuals)
#     new_individuals = []
#     total_sum = 0
#     total_sum = sum([(total_sum + ind.fitness) for ind in individuals])
#     print("total sum: ", total_sum)
#     # random_num = random.randrange(0,int(round(total_sum)))
#     random_num = random.uniform(0,total_sum)
#     partial_sum = 0
#     while len(new_individuals) != individual_length - no_of_elites:
#         for c in original_individuals:
#             partial_sum += c.fitness
#             if(partial_sum >= random_num):
#                 new_individuals.append(c)
#                 # random_num = random.randrange(0,int(round(total_sum)))
#                 random_num = random.uniform(0,total_sum)
#                 partial_sum = 0
#                 break
#     print("Roulette - Selected Individuals Fitness: ",  [ind.fitness for ind in new_individuals])
#     return new_individuals

# def run_ga(pop_size, generation):
#   population = Population(pop_size)
#   board = population.board
#   population.individuals.sort(key=lambda x: x.calc_fitness(board=board, gen=1), reverse= True)
#   for gen in range(1, generation+1):
#       print("Generation: ", gen, " started")
#       gen_fitness_dict = {}
#       gen_best_fitness["gen_"+str(gen)] = population.individuals[0].fitness
#       all_fitness = [ind.fitness for ind in population.individuals]
#       gen_fitness_dict["gen_"+str(gen)] = all_fitness
#       print("Fitness of this generation: ", all_fitness)
#       each_gen_fitness.append(gen_fitness_dict)
#       gen_average_fitness["gen_"+str(gen)] = sum(all_fitness)/len(all_fitness)
#       elite_individuals = [copy.deepcopy(population.individuals[i]) for i in range(0,no_of_elites)]
#       selected_individuals = GeneticAlgorithm.select_roulette_wheel(population.individuals)
#       mutated_individuals = GeneticAlgorithm.mutate_individuals(selected_individuals)
#       for ind in mutated_individuals:
#         ind.calc_fitness(board, gen)
#       print("Mutated population fitness: ",  [ind.fitness for ind in mutated_individuals])
#       population.individuals = elite_individuals + mutated_individuals    
#       population.individuals.sort(key=lambda x: x.fitness, reverse= True)
#       print("elite fitness: ", [ind.fitness for ind in elite_individuals])
#       print("Next generation fitness : ", [ind.fitness for ind in population.individuals])
#       print("Generation ",gen, " completed")
#       print("----------------------------------")
#       print("----------------------------------")

#   print("gen_best_fitness: ", gen_best_fitness)
#   plot_figures(gen_best_fitness, "gen_best_fitness.png")
#   print("gen_average_fitness: ", gen_average_fitness)
#   plot_figures(gen_average_fitness, "gen_average_fitness.png")


# def plot_figures(data, name):
#   plt.clf()
#   labels = list(data.keys())
#   values = list(data.values())
#   plt.plot(labels, values)
#   plt.xlabel('Generation')
#   plt.ylabel('Fitness')
#   plt.title('Fitness of Generations')
#   plt.savefig(name) 

# if __name__ == "__main__":
    
#   if os.path.exists('outputs'):
#     shutil.rmtree('outputs')
#   run_ga(population_size, generation)

# %% [markdown]
# # Merged VoT and AE

# %%
def reconstruct_and_error(board):
    data = []
    # Load the image using OpenCV
    img = np.array(board)
    # Convert the image to grayscale
    # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Resize the image to a fixed size
    resized = cv2.resize(img, (28, 28))
    # Add the image data to the list
    data.append(resized)
    # Add the label to the list
    data = np.array(data)
    predicted_data = autoencoder.predict(data.reshape(1,784), verbose=0)
    plt.ioff()
    # plt.imshow(predicted_data.reshape(28,28), cmap='gist_earth')
    # plt.savefig("/content/recon100/"+str(filename))
    mse = np.mean((-data.reshape(28,28) + predicted_data.reshape(28,28))**2)
    # reconloss_list.append(mse)
    # std_dev = np.std(reconloss_list)
    return predicted_data.reshape(28,28), mse
    # plt.show()

# board = np.random.rand(100, 100)
# # print(board.shape)
# # print(board)
# reco_loss = reconstruct_and_error(board)

# %%
# Updated with merged lenia-ae and vot

import random
import numpy as np
import shutil
import os
import statistics
from matplotlib import pyplot as plt
import sys
import copy
import multiprocessing


kernel_size = 16
board_size = 64
mutation_rate = 0.1
population_size = 10
generation = 50
gen_best_fitness = {}
gen_average_fitness = {}
each_gen_fitness = []
no_of_elites = 1

def random_kernel_generator():
  grid = np.random.rand(kernel_size, kernel_size)
  grid = np.round(grid, 3)
  return grid

def random_board_generator():
  board = np.random.rand(board_size, board_size)
  board = np.round(board, 3)
  return board

class Individual(multiprocessing.Process):

  def __init__(self):
    self.genes = random_kernel_generator()
    self.fitness = 0

  def calc_fitness(self, board, gen):
    lenia = Lenia(self.genes, board)
    board_frames_dict = lenia.run_simulation("gen_"+str(gen))
    board_frames_val = list(board_frames_dict.values())
    errors = []
    frame_alive_cell_count_list = []
    for i in range(len(board_frames_val)):
      frame, board_error = reconstruct_and_error(board_frames_val[i])
      errors.append(board_error)
      board_arr = frame.flatten()
      alive_cell_count = list(board_arr[board_arr > 0.5])
      frame_alive_cell_count_list.append(len(alive_cell_count))

    every_10th_frames = frame_alive_cell_count_list[9::10]
    self.fitness = statistics.pstdev(every_10th_frames)
    # board_stddev = np.std(errors)
    # self.fitness = board_stddev
    return self.fitness


class Population:
  def __init__(self, size):
    self.individuals = []
    self.board = random_board_generator()
    for _ in range(0, size):
        self.individuals.append(Individual())


class GeneticAlgorithm:

  @staticmethod
  def mutate_individuals(individuals):
    mutated_individuals = []
    for ind in individuals:
        mutated_ind = GeneticAlgorithm._mutate_individual(ind)
        mutated_individuals.append(mutated_ind)
    return mutated_individuals

  @staticmethod
  def _mutate_individual(ind):
    kernel = ind.genes
    for i in range(kernel.shape[0]):
        for j in range(kernel.shape[1]):
            if random.random() < mutation_rate:
                kernel[i][j] = np.round(np.random.rand(), 3)
    ind.genes = kernel
    return ind
    
  @staticmethod
  def select_roulette_wheel(individuals):
    original_individuals = individuals
    individual_length = len(original_individuals)
    new_individuals = []
    total_sum = 0
    total_sum = sum([(total_sum + ind.fitness) for ind in individuals])
    print("total sum: ", total_sum)
    # random_num = random.randrange(0,int(round(total_sum)))
    random_num = random.uniform(0,total_sum)
    partial_sum = 0
    while len(new_individuals) != individual_length - no_of_elites:
        for c in original_individuals:
            partial_sum += c.fitness
            if(partial_sum >= random_num):
                new_individuals.append(c)
                # random_num = random.randrange(0,int(round(total_sum)))
                random_num = random.uniform(0,total_sum)
                partial_sum = 0
                break
    print("Roulette - Selected Individuals Fitness: ",  [ind.fitness for ind in new_individuals])
    return new_individuals

def run_ga(pop_size, generation):
  population = Population(pop_size)
  board = population.board
  population.individuals.sort(key=lambda x: x.calc_fitness(board=board, gen=1), reverse= True)
  for gen in range(1, generation+1):
      print("Generation: ", gen, " started")
      gen_fitness_dict = {}
      gen_best_fitness["gen_"+str(gen)] = population.individuals[0].fitness
      all_fitness = [ind.fitness for ind in population.individuals]
      gen_fitness_dict["gen_"+str(gen)] = all_fitness
      print("Fitness of this generation: ", all_fitness)
      each_gen_fitness.append(gen_fitness_dict)
      gen_average_fitness["gen_"+str(gen)] = sum(all_fitness)/len(all_fitness)
      elite_individuals = [copy.deepcopy(population.individuals[i]) for i in range(0,no_of_elites)]
      selected_individuals = GeneticAlgorithm.select_roulette_wheel(population.individuals)
      mutated_individuals = GeneticAlgorithm.mutate_individuals(selected_individuals)
      for ind in mutated_individuals:
        ind.calc_fitness(board, gen)
      print("Mutated population fitness: ",  [ind.fitness for ind in mutated_individuals])
      population.individuals = elite_individuals + mutated_individuals    
      population.individuals.sort(key=lambda x: x.fitness, reverse= True)
      print("elite fitness: ", [ind.fitness for ind in elite_individuals])
      print("Next generation fitness : ", [ind.fitness for ind in population.individuals])
      print("Generation ",gen, " completed")
      print("----------------------------------")
      print("----------------------------------")
      plot_figures(gen_best_fitness, "gen_best_fitness"+str(gen)+".png")

  print("gen_best_fitness: ", gen_best_fitness)
  plot_figures(gen_best_fitness, "gen_best_fitness.png")
  print("gen_average_fitness: ", gen_average_fitness)
  plot_figures(gen_average_fitness, "gen_average_fitness.png")


def plot_figures(data, name):
  plt.clf()
  labels = list(data.keys())
  values = list(data.values())
  plt.plot(labels, values)
  plt.xlabel('Generation')
  plt.ylabel('Fitness')
  plt.title('Fitness of Generations')
  plt.savefig(name) 

if __name__ == "__main__":
    
  if os.path.exists('outputs'):
    shutil.rmtree('outputs')
  run_ga(population_size, generation)
# Out:
# Generation:  1  started
# Fitness of this generation:  [19.656042327996754, 16.4851448279959, 16.00624877977348, 15.651198037211081, 15.37172729396407, 15.02031957050182, 14.404513181638594, 14.098226838861686, 14.084033513166604, 11.09459327780879]
# total sum:  151.8720476489188
# Roulette - Selected Individuals Fitness:  [19.656042327996754, 15.37172729396407, 15.651198037211081, 14.084033513166604, 16.4851448279959, 11.09459327780879, 15.37172729396407, 14.084033513166604, 14.098226838861686]
# Mutated population fitness:  [12.531959144523254, 23.39850422569785, 9.233092656309694, 15.402597183592123, 8.734414691323053, 16.740669042783207, 23.39850422569785, 15.402597183592123, 8.7]
# elite fitness:  [19.656042327996754]
# Next generation fitness :  [23.39850422569785, 23.39850422569785, 19.656042327996754, 16.740669042783207, 15.402597183592123, 15.402597183592123, 12.531959144523254, 9.233092656309694, 8.734414691323053, 8.7]
# Generation  1  completed
# ----------------------------------
# ----------------------------------
# Generation:  2  started
# Fitness of this generation:  [23.39850422569785, 23.39850422569785, 19.656042327996754, 16.740669042783207, 15.402597183592123, 15.402597183592123, 12.531959144523254, 9.233092656309694, 8.734414691323053, 8.7]
# total sum:  153.19838068151589
# Roulette - Selected Individuals Fitness:  [8.7, 19.656042327996754, 8.7, 19.656042327996754, 23.39850422569785, 23.39850422569785, 23.39850422569785, 15.402597183592123, 8.7]
# <ipython-input-62-a0c535efe915>:62: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   self.fig = plt.figure(figsize=(10*np.shape(self.board)[1]/dpi, 10*np.shape(self.board)[0]/dpi), dpi=dpi)
# <ipython-input-62-a0c535efe915>:129: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(1, 3, figsize=(14,2), gridspec_kw={'width_ratios': [1,1,2]})
# Mutated population fitness:  [21.4478437144623, 16.396341055247664, 21.4478437144623, 16.396341055247664, 15.640971836813723, 15.640971836813723, 15.640971836813723, 10.602358228243375, 21.4478437144623]
# elite fitness:  [23.39850422569785]
# Next generation fitness :  [23.39850422569785, 21.4478437144623, 21.4478437144623, 21.4478437144623, 16.396341055247664, 16.396341055247664, 15.640971836813723, 15.640971836813723, 15.640971836813723, 10.602358228243375]
# Generation  2  completed
# ----------------------------------
# ----------------------------------
# Generation:  3  started
# Fitness of this generation:  [23.39850422569785, 21.4478437144623, 21.4478437144623, 21.4478437144623, 16.396341055247664, 16.396341055247664, 15.640971836813723, 15.640971836813723, 15.640971836813723, 10.602358228243375]
# total sum:  178.0599912182646
# Roulette - Selected Individuals Fitness:  [21.4478437144623, 16.396341055247664, 16.396341055247664, 10.602358228243375, 16.396341055247664, 16.396341055247664, 21.4478437144623, 21.4478437144623, 15.640971836813723]
# Mutated population fitness:  [28.79583303188154, 10.188228501560022, 10.188228501560022, 16.051168181786643, 10.188228501560022, 10.188228501560022, 28.79583303188154, 28.79583303188154, 13.284953895290716]
# elite fitness:  [23.39850422569785]
# Next generation fitness :  [28.79583303188154, 28.79583303188154, 28.79583303188154, 23.39850422569785, 16.051168181786643, 13.284953895290716, 10.188228501560022, 10.188228501560022, 10.188228501560022, 10.188228501560022]
# Generation  3  completed
# ----------------------------------
# ----------------------------------
# Generation:  4  started
# Fitness of this generation:  [28.79583303188154, 28.79583303188154, 28.79583303188154, 23.39850422569785, 16.051168181786643, 13.284953895290716, 10.188228501560022, 10.188228501560022, 10.188228501560022, 10.188228501560022]
# total sum:  179.8750394046599
# Roulette - Selected Individuals Fitness:  [28.79583303188154, 13.284953895290716, 23.39850422569785, 10.188228501560022, 10.188228501560022, 28.79583303188154, 28.79583303188154, 23.39850422569785, 23.39850422569785]
# Mutated population fitness:  [25.401771591761076, 8.899438184514796, 28.197340300106323, 9.434511116109833, 9.434511116109833, 25.401771591761076, 25.401771591761076, 28.197340300106323, 28.197340300106323]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 28.197340300106323, 28.197340300106323, 28.197340300106323, 25.401771591761076, 25.401771591761076, 25.401771591761076, 9.434511116109833, 9.434511116109833, 8.899438184514796]
# Generation  4  completed
# ----------------------------------
# ----------------------------------
# Generation:  5  started
# Fitness of this generation:  [28.79583303188154, 28.197340300106323, 28.197340300106323, 28.197340300106323, 25.401771591761076, 25.401771591761076, 25.401771591761076, 9.434511116109833, 9.434511116109833, 8.899438184514796]
# total sum:  217.36162912421818
# Roulette - Selected Individuals Fitness:  [25.401771591761076, 28.79583303188154, 28.197340300106323, 25.401771591761076, 25.401771591761076, 8.899438184514796, 28.197340300106323, 25.401771591761076, 25.401771591761076]
# Mutated population fitness:  [24.383601046605072, 20.406861591141347, 22.503555274667157, 24.383601046605072, 24.383601046605072, 11.768177428981941, 22.503555274667157, 24.383601046605072, 24.383601046605072]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 24.383601046605072, 24.383601046605072, 24.383601046605072, 24.383601046605072, 24.383601046605072, 22.503555274667157, 22.503555274667157, 20.406861591141347, 11.768177428981941]
# Generation  5  completed
# ----------------------------------
# ----------------------------------
# Generation:  6  started
# Fitness of this generation:  [28.79583303188154, 24.383601046605072, 24.383601046605072, 24.383601046605072, 24.383601046605072, 24.383601046605072, 22.503555274667157, 22.503555274667157, 20.406861591141347, 11.768177428981941]
# total sum:  227.89598783436446
# Roulette - Selected Individuals Fitness:  [22.503555274667157, 24.383601046605072, 24.383601046605072, 24.383601046605072, 28.79583303188154, 24.383601046605072, 24.383601046605072, 11.768177428981941, 24.383601046605072]
# Mutated population fitness:  [17.392239648762892, 17.061359852016484, 17.061359852016484, 17.061359852016484, 20.92008604188807, 17.061359852016484, 17.061359852016484, 6.241794613730894, 17.061359852016484]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 20.92008604188807, 17.392239648762892, 17.061359852016484, 17.061359852016484, 17.061359852016484, 17.061359852016484, 17.061359852016484, 17.061359852016484, 6.241794613730894]
# Generation  6  completed
# ----------------------------------
# ----------------------------------
# Generation:  7  started
# Fitness of this generation:  [28.79583303188154, 20.92008604188807, 17.392239648762892, 17.061359852016484, 17.061359852016484, 17.061359852016484, 17.061359852016484, 17.061359852016484, 17.061359852016484, 6.241794613730894]
# total sum:  175.71811244836232
# Roulette - Selected Individuals Fitness:  [28.79583303188154, 17.061359852016484, 17.061359852016484, 17.392239648762892, 20.92008604188807, 17.061359852016484, 17.061359852016484, 28.79583303188154, 20.92008604188807]
# Mutated population fitness:  [27.012774755659592, 12.37739875741264, 12.37739875741264, 20.00099997500125, 13.572030061858838, 12.37739875741264, 12.37739875741264, 27.012774755659592, 13.572030061858838]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 27.012774755659592, 27.012774755659592, 20.00099997500125, 13.572030061858838, 13.572030061858838, 12.37739875741264, 12.37739875741264, 12.37739875741264, 12.37739875741264]
# Generation  7  completed
# ----------------------------------
# ----------------------------------
# Generation:  8  started
# Fitness of this generation:  [28.79583303188154, 27.012774755659592, 27.012774755659592, 20.00099997500125, 13.572030061858838, 13.572030061858838, 12.37739875741264, 12.37739875741264, 12.37739875741264, 12.37739875741264]
# total sum:  179.4760376715702
# Roulette - Selected Individuals Fitness:  [27.012774755659592, 12.37739875741264, 13.572030061858838, 27.012774755659592, 28.79583303188154, 27.012774755659592, 13.572030061858838, 27.012774755659592, 20.00099997500125]
# Mutated population fitness:  [23.23122898169617, 12.69212354178764, 9.213576938409968, 23.23122898169617, 22.395535269334378, 23.23122898169617, 9.213576938409968, 23.23122898169617, 24.364728605096342]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 24.364728605096342, 23.23122898169617, 23.23122898169617, 23.23122898169617, 23.23122898169617, 22.395535269334378, 12.69212354178764, 9.213576938409968, 9.213576938409968]
# Generation  8  completed
# ----------------------------------
# ----------------------------------
# Generation:  9  started
# Fitness of this generation:  [28.79583303188154, 24.364728605096342, 23.23122898169617, 23.23122898169617, 23.23122898169617, 23.23122898169617, 22.395535269334378, 12.69212354178764, 9.213576938409968, 9.213576938409968]
# total sum:  199.60029025170454
# Roulette - Selected Individuals Fitness:  [23.23122898169617, 12.69212354178764, 28.79583303188154, 23.23122898169617, 23.23122898169617, 9.213576938409968, 23.23122898169617, 28.79583303188154, 23.23122898169617]
# Mutated population fitness:  [22.875532780680757, 14.684685900624501, 16.851112722903494, 22.875532780680757, 22.875532780680757, 12.009995836801943, 22.875532780680757, 16.851112722903494, 22.875532780680757]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 22.875532780680757, 22.875532780680757, 22.875532780680757, 22.875532780680757, 22.875532780680757, 16.851112722903494, 16.851112722903494, 14.684685900624501, 12.009995836801943]
# Generation  9  completed
# ----------------------------------
# ----------------------------------
# Generation:  10  started
# Fitness of this generation:  [28.79583303188154, 22.875532780680757, 22.875532780680757, 22.875532780680757, 22.875532780680757, 22.875532780680757, 16.851112722903494, 16.851112722903494, 14.684685900624501, 12.009995836801943]
# total sum:  203.57040411851878
# Roulette - Selected Individuals Fitness:  [22.875532780680757, 16.851112722903494, 22.875532780680757, 22.875532780680757, 22.875532780680757, 22.875532780680757, 28.79583303188154, 16.851112722903494, 22.875532780680757]
# Mutated population fitness:  [13.251792331605563, 22.53197727675048, 13.251792331605563, 13.251792331605563, 13.251792331605563, 13.251792331605563, 24.518564395168, 22.53197727675048, 13.251792331605563]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 24.518564395168, 22.53197727675048, 22.53197727675048, 13.251792331605563, 13.251792331605563, 13.251792331605563, 13.251792331605563, 13.251792331605563, 13.251792331605563]
# Generation  10  completed
# ----------------------------------
# ----------------------------------
# Generation:  11  started
# Fitness of this generation:  [28.79583303188154, 24.518564395168, 22.53197727675048, 22.53197727675048, 13.251792331605563, 13.251792331605563, 13.251792331605563, 13.251792331605563, 13.251792331605563, 13.251792331605563]
# total sum:  177.8891059701839
# Roulette - Selected Individuals Fitness:  [13.251792331605563, 24.518564395168, 13.251792331605563, 22.53197727675048, 13.251792331605563, 22.53197727675048, 24.518564395168, 28.79583303188154, 28.79583303188154]
# Mutated population fitness:  [21.96269564511606, 28.559411758647972, 21.96269564511606, 19.985995096566995, 21.96269564511606, 19.985995096566995, 28.559411758647972, 19.08114252344445, 19.08114252344445]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 28.559411758647972, 28.559411758647972, 21.96269564511606, 21.96269564511606, 21.96269564511606, 19.985995096566995, 19.985995096566995, 19.08114252344445, 19.08114252344445]
# Generation  11  completed
# ----------------------------------
# ----------------------------------
# Generation:  12  started
# Fitness of this generation:  [28.79583303188154, 28.559411758647972, 28.559411758647972, 21.96269564511606, 21.96269564511606, 21.96269564511606, 19.985995096566995, 19.985995096566995, 19.08114252344445, 19.08114252344445]
# total sum:  229.93701872454855
# Roulette - Selected Individuals Fitness:  [19.08114252344445, 19.08114252344445, 19.985995096566995, 28.559411758647972, 19.985995096566995, 21.96269564511606, 19.985995096566995, 21.96269564511606, 28.559411758647972]
# Mutated population fitness:  [26.009421369957465, 26.009421369957465, 20.96210867255487, 17.9055857206627, 20.96210867255487, 25.072096043211065, 20.96210867255487, 25.072096043211065, 17.9055857206627]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 26.009421369957465, 26.009421369957465, 25.072096043211065, 25.072096043211065, 20.96210867255487, 20.96210867255487, 20.96210867255487, 17.9055857206627, 17.9055857206627]
# Generation  12  completed
# ----------------------------------
# ----------------------------------
# Generation:  13  started
# Fitness of this generation:  [28.79583303188154, 26.009421369957465, 26.009421369957465, 25.072096043211065, 25.072096043211065, 20.96210867255487, 20.96210867255487, 20.96210867255487, 17.9055857206627, 17.9055857206627]
# total sum:  229.65636531720867
# Roulette - Selected Individuals Fitness:  [26.009421369957465, 28.79583303188154, 25.072096043211065, 17.9055857206627, 26.009421369957465, 17.9055857206627, 20.96210867255487, 20.96210867255487, 26.009421369957465]
# Mutated population fitness:  [11.983738982471206, 18.37824801225623, 22.90873195966988, 15.231874474272693, 11.983738982471206, 15.231874474272693, 22.447494292236716, 22.447494292236716, 11.983738982471206]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 22.90873195966988, 22.447494292236716, 22.447494292236716, 18.37824801225623, 15.231874474272693, 15.231874474272693, 11.983738982471206, 11.983738982471206, 11.983738982471206]
# Generation  13  completed
# ----------------------------------
# ----------------------------------
# Generation:  14  started
# Fitness of this generation:  [28.79583303188154, 22.90873195966988, 22.447494292236716, 22.447494292236716, 18.37824801225623, 15.231874474272693, 15.231874474272693, 11.983738982471206, 11.983738982471206, 11.983738982471206]
# total sum:  181.3927674842401
# Roulette - Selected Individuals Fitness:  [22.447494292236716, 18.37824801225623, 15.231874474272693, 22.447494292236716, 22.90873195966988, 28.79583303188154, 11.983738982471206, 18.37824801225623, 22.90873195966988]
# Mutated population fitness:  [26.563320575560578, 6.7, 11.7285975291166, 26.563320575560578, 20.6920274502041, 27.360738294132343, 20.09975124224178, 6.7, 20.6920274502041]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [28.79583303188154, 27.360738294132343, 26.563320575560578, 26.563320575560578, 20.6920274502041, 20.6920274502041, 20.09975124224178, 11.7285975291166, 6.7, 6.7]
# Generation  14  completed
# ----------------------------------
# ----------------------------------
# Generation:  15  started
# Fitness of this generation:  [28.79583303188154, 27.360738294132343, 26.563320575560578, 26.563320575560578, 20.6920274502041, 20.6920274502041, 20.09975124224178, 11.7285975291166, 6.7, 6.7]
# total sum:  195.8956161489016
# Roulette - Selected Individuals Fitness:  [20.09975124224178, 20.09975124224178, 27.360738294132343, 26.563320575560578, 20.09975124224178, 20.6920274502041, 6.7, 20.09975124224178, 20.6920274502041]
# Mutated population fitness:  [13.145721737508367, 13.145721737508367, 27.957110008010485, 22.697136383253284, 13.145721737508367, 31.363035567368154, 7.864477096412704, 13.145721737508367, 31.363035567368154]
# elite fitness:  [28.79583303188154]
# Next generation fitness :  [31.363035567368154, 31.363035567368154, 28.79583303188154, 27.957110008010485, 22.697136383253284, 13.145721737508367, 13.145721737508367, 13.145721737508367, 13.145721737508367, 7.864477096412704]
# Generation  15  completed
# ----------------------------------
# ----------------------------------
# Generation:  16  started
# Fitness of this generation:  [31.363035567368154, 31.363035567368154, 28.79583303188154, 27.957110008010485, 22.697136383253284, 13.145721737508367, 13.145721737508367, 13.145721737508367, 13.145721737508367, 7.864477096412704]
# total sum:  202.62351460432785
# Roulette - Selected Individuals Fitness:  [22.697136383253284, 31.363035567368154, 22.697136383253284, 13.145721737508367, 27.957110008010485, 31.363035567368154, 31.363035567368154, 27.957110008010485, 22.697136383253284]
# Mutated population fitness:  [18.868227261722282, 26.870801997707474, 18.868227261722282, 11.153923076657827, 17.356554957709783, 26.870801997707474, 26.870801997707474, 17.356554957709783, 18.868227261722282]
# elite fitness:  [31.363035567368154]
# Next generation fitness :  [31.363035567368154, 26.870801997707474, 26.870801997707474, 26.870801997707474, 18.868227261722282, 18.868227261722282, 18.868227261722282, 17.356554957709783, 17.356554957709783, 11.153923076657827]
# Generation  16  completed
# ----------------------------------
# ----------------------------------
# Generation:  17  started
# Fitness of this generation:  [31.363035567368154, 26.870801997707474, 26.870801997707474, 26.870801997707474, 18.868227261722282, 18.868227261722282, 18.868227261722282, 17.356554957709783, 17.356554957709783, 11.153923076657827]
# total sum:  214.4471563377348
# Roulette - Selected Individuals Fitness:  [26.870801997707474, 26.870801997707474, 18.868227261722282, 18.868227261722282, 26.870801997707474, 26.870801997707474, 18.868227261722282, 17.356554957709783, 26.870801997707474]
# Mutated population fitness:  [27.55648743943974, 27.55648743943974, 15.0136604464068, 15.0136604464068, 27.55648743943974, 27.55648743943974, 15.0136604464068, 18.932511719262184, 27.55648743943974]
# elite fitness:  [31.363035567368154]
# Next generation fitness :  [31.363035567368154, 27.55648743943974, 27.55648743943974, 27.55648743943974, 27.55648743943974, 27.55648743943974, 18.932511719262184, 15.0136604464068, 15.0136604464068, 15.0136604464068]
# Generation  17  completed
# ----------------------------------
# ----------------------------------
# Generation:  18  started
# Fitness of this generation:  [31.363035567368154, 27.55648743943974, 27.55648743943974, 27.55648743943974, 27.55648743943974, 27.55648743943974, 18.932511719262184, 15.0136604464068, 15.0136604464068, 15.0136604464068]
# total sum:  233.1189658230494
# Roulette - Selected Individuals Fitness:  [15.0136604464068, 27.55648743943974, 27.55648743943974, 15.0136604464068, 27.55648743943974, 27.55648743943974, 31.363035567368154, 15.0136604464068, 15.0136604464068]
# Mutated population fitness:  [14.264992113562489, 14.469277798148738, 14.469277798148738, 14.264992113562489, 14.469277798148738, 14.469277798148738, 31.90987308028661, 14.264992113562489, 14.264992113562489]
# elite fitness:  [31.363035567368154]
# Next generation fitness :  [31.90987308028661, 31.363035567368154, 14.469277798148738, 14.469277798148738, 14.469277798148738, 14.469277798148738, 14.264992113562489, 14.264992113562489, 14.264992113562489, 14.264992113562489]
# Generation  18  completed
# ----------------------------------
# ----------------------------------
# Generation:  19  started
# Fitness of this generation:  [31.90987308028661, 31.363035567368154, 14.469277798148738, 14.469277798148738, 14.469277798148738, 14.469277798148738, 14.264992113562489, 14.264992113562489, 14.264992113562489, 14.264992113562489]
# total sum:  178.2099882944997
# Roulette - Selected Individuals Fitness:  [14.264992113562489, 31.90987308028661, 31.363035567368154, 14.469277798148738, 14.469277798148738, 14.264992113562489, 14.469277798148738, 14.469277798148738, 14.264992113562489]
# Mutated population fitness:  [14.430869689661812, 37.64850594645158, 33.218819967000634, 13.159027319676785, 13.159027319676785, 14.430869689661812, 13.159027319676785, 13.159027319676785, 14.430869689661812]
# elite fitness:  [31.90987308028661]
# Next generation fitness :  [37.64850594645158, 33.218819967000634, 31.90987308028661, 14.430869689661812, 14.430869689661812, 14.430869689661812, 13.159027319676785, 13.159027319676785, 13.159027319676785, 13.159027319676785]
# Generation  19  completed
# ----------------------------------
# ----------------------------------
# Generation:  20  started
# Fitness of this generation:  [37.64850594645158, 33.218819967000634, 31.90987308028661, 14.430869689661812, 14.430869689661812, 14.430869689661812, 13.159027319676785, 13.159027319676785, 13.159027319676785, 13.159027319676785]
# total sum:  198.70591734143147
# Roulette - Selected Individuals Fitness:  [13.159027319676785, 37.64850594645158, 13.159027319676785, 37.64850594645158, 37.64850594645158, 14.430869689661812, 14.430869689661812, 37.64850594645158, 33.218819967000634]
# Mutated population fitness:  [12.568213874691981, 34.00823429700519, 12.568213874691981, 34.00823429700519, 34.00823429700519, 24.54811601732402, 24.54811601732402, 34.00823429700519, 29.985996731807997]
# elite fitness:  [37.64850594645158]
# Next generation fitness :  [37.64850594645158, 34.00823429700519, 34.00823429700519, 34.00823429700519, 34.00823429700519, 29.985996731807997, 24.54811601732402, 24.54811601732402, 12.568213874691981, 12.568213874691981]
# Generation  20  completed
# ----------------------------------
# ----------------------------------
# Generation:  21  started
# Fitness of this generation:  [37.64850594645158, 34.00823429700519, 34.00823429700519, 34.00823429700519, 34.00823429700519, 29.985996731807997, 24.54811601732402, 24.54811601732402, 12.568213874691981, 12.568213874691981]
# total sum:  277.9000996503123
# Roulette - Selected Individuals Fitness:  [12.568213874691981, 37.64850594645158, 12.568213874691981, 24.54811601732402, 34.00823429700519, 24.54811601732402, 34.00823429700519, 24.54811601732402, 24.54811601732402]
# Mutated population fitness:  [13.807244475274565, 26.762100067072463, 13.807244475274565, 20.659138413786767, 30.341390871217488, 20.659138413786767, 30.341390871217488, 20.659138413786767, 20.659138413786767]
# elite fitness:  [37.64850594645158]
# Next generation fitness :  [37.64850594645158, 30.341390871217488, 30.341390871217488, 26.762100067072463, 20.659138413786767, 20.659138413786767, 20.659138413786767, 20.659138413786767, 13.807244475274565, 13.807244475274565]
# Generation  21  completed
# ----------------------------------
# ----------------------------------
# Generation:  22  started
# Fitness of this generation:  [37.64850594645158, 30.341390871217488, 30.341390871217488, 26.762100067072463, 20.659138413786767, 20.659138413786767, 20.659138413786767, 20.659138413786767, 13.807244475274565, 13.807244475274565]
# total sum:  235.34443036165518
# Roulette - Selected Individuals Fitness:  [30.341390871217488, 13.807244475274565, 20.659138413786767, 20.659138413786767, 30.341390871217488, 26.762100067072463, 30.341390871217488, 30.341390871217488, 13.807244475274565]
# Mutated population fitness:  [19.177069640588993, 26.053982421119425, 16.51332795047685, 16.51332795047685, 19.177069640588993, 23.268003782017914, 19.177069640588993, 19.177069640588993, 26.053982421119425]
# elite fitness:  [37.64850594645158]
# Next generation fitness :  [37.64850594645158, 26.053982421119425, 26.053982421119425, 23.268003782017914, 19.177069640588993, 19.177069640588993, 19.177069640588993, 19.177069640588993, 16.51332795047685, 16.51332795047685]
# Generation  22  completed
# ----------------------------------
# ----------------------------------
# Generation:  23  started
# Fitness of this generation:  [37.64850594645158, 26.053982421119425, 26.053982421119425, 23.268003782017914, 19.177069640588993, 19.177069640588993, 19.177069640588993, 19.177069640588993, 16.51332795047685, 16.51332795047685]
# total sum:  222.75940903401803
# Roulette - Selected Individuals Fitness:  [37.64850594645158, 19.177069640588993, 19.177069640588993, 19.177069640588993, 26.053982421119425, 16.51332795047685, 19.177069640588993, 37.64850594645158, 26.053982421119425]
# Mutated population fitness:  [32.28250300085172, 26.053022857242496, 26.053022857242496, 26.053022857242496, 24.566033460858105, 12.242957159118053, 26.053022857242496, 32.28250300085172, 24.566033460858105]
# elite fitness:  [37.64850594645158]
# Next generation fitness :  [37.64850594645158, 32.28250300085172, 32.28250300085172, 26.053022857242496, 26.053022857242496, 26.053022857242496, 26.053022857242496, 24.566033460858105, 24.566033460858105, 12.242957159118053]
# Generation  23  completed
# ----------------------------------
# ----------------------------------
# Generation:  24  started
# Fitness of this generation:  [37.64850594645158, 32.28250300085172, 32.28250300085172, 26.053022857242496, 26.053022857242496, 26.053022857242496, 26.053022857242496, 24.566033460858105, 24.566033460858105, 12.242957159118053]
# total sum:  267.80062745795925
# Roulette - Selected Individuals Fitness:  [26.053022857242496, 24.566033460858105, 24.566033460858105, 32.28250300085172, 37.64850594645158, 26.053022857242496, 37.64850594645158, 26.053022857242496, 26.053022857242496]
# Mutated population fitness:  [17.649079296099274, 24.289092202056462, 24.289092202056462, 34.35753192532898, 36.95794907729594, 17.649079296099274, 36.95794907729594, 17.649079296099274, 17.649079296099274]
# elite fitness:  [37.64850594645158]
# Next generation fitness :  [37.64850594645158, 36.95794907729594, 36.95794907729594, 34.35753192532898, 24.289092202056462, 24.289092202056462, 17.649079296099274, 17.649079296099274, 17.649079296099274, 17.649079296099274]
# Generation  24  completed
# ----------------------------------
# ----------------------------------
# Generation:  25  started
# Fitness of this generation:  [37.64850594645158, 36.95794907729594, 36.95794907729594, 34.35753192532898, 24.289092202056462, 24.289092202056462, 17.649079296099274, 17.649079296099274, 17.649079296099274, 17.649079296099274]
# total sum:  265.09643761488246
# Roulette - Selected Individuals Fitness:  [36.95794907729594, 36.95794907729594, 17.649079296099274, 24.289092202056462, 17.649079296099274, 24.289092202056462, 24.289092202056462, 36.95794907729594, 17.649079296099274]
# Mutated population fitness:  [29.009653565666724, 29.009653565666724, 23.130283180281214, 20.610919436065924, 23.130283180281214, 20.610919436065924, 20.610919436065924, 29.009653565666724, 23.130283180281214]
# elite fitness:  [37.64850594645158]
# Next generation fitness :  [37.64850594645158, 29.009653565666724, 29.009653565666724, 29.009653565666724, 23.130283180281214, 23.130283180281214, 23.130283180281214, 20.610919436065924, 20.610919436065924, 20.610919436065924]
# Generation  25  completed
# ----------------------------------
# ----------------------------------
# Generation:  26  started
# Fitness of this generation:  [37.64850594645158, 29.009653565666724, 29.009653565666724, 29.009653565666724, 23.130283180281214, 23.130283180281214, 23.130283180281214, 20.610919436065924, 20.610919436065924, 20.610919436065924]
# total sum:  255.9010744924932
# Roulette - Selected Individuals Fitness:  [20.610919436065924, 23.130283180281214, 29.009653565666724, 37.64850594645158, 29.009653565666724, 23.130283180281214, 20.610919436065924, 29.009653565666724, 23.130283180281214]
# Mutated population fitness:  [22.637358503146963, 13.087780560507575, 20.243764472054103, 44.026810013899485, 20.243764472054103, 13.087780560507575, 22.637358503146963, 20.243764472054103, 13.087780560507575]
# elite fitness:  [37.64850594645158]
# Next generation fitness :  [44.026810013899485, 37.64850594645158, 22.637358503146963, 22.637358503146963, 20.243764472054103, 20.243764472054103, 20.243764472054103, 13.087780560507575, 13.087780560507575, 13.087780560507575]
# Generation  26  completed
# ----------------------------------
# ----------------------------------
# Generation:  27  started
# Fitness of this generation:  [44.026810013899485, 37.64850594645158, 22.637358503146963, 22.637358503146963, 20.243764472054103, 20.243764472054103, 20.243764472054103, 13.087780560507575, 13.087780560507575, 13.087780560507575]
# total sum:  226.94466806433005
# Roulette - Selected Individuals Fitness:  [20.243764472054103, 44.026810013899485, 20.243764472054103, 22.637358503146963, 37.64850594645158, 13.087780560507575, 37.64850594645158, 22.637358503146963, 20.243764472054103]
# Mutated population fitness:  [9.672641831474998, 35.42612030691478, 9.672641831474998, 19.55632889885011, 35.86641883433583, 14.092906016858269, 35.86641883433583, 19.55632889885011, 9.672641831474998]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 35.86641883433583, 35.86641883433583, 35.42612030691478, 19.55632889885011, 19.55632889885011, 14.092906016858269, 9.672641831474998, 9.672641831474998, 9.672641831474998]
# Generation  27  completed
# ----------------------------------
# ----------------------------------
# Generation:  28  started
# Fitness of this generation:  [44.026810013899485, 35.86641883433583, 35.86641883433583, 35.42612030691478, 19.55632889885011, 19.55632889885011, 14.092906016858269, 9.672641831474998, 9.672641831474998, 9.672641831474998]
# total sum:  233.40925729846944
# Roulette - Selected Individuals Fitness:  [14.092906016858269, 35.86641883433583, 35.42612030691478, 35.86641883433583, 35.86641883433583, 35.42612030691478, 14.092906016858269, 35.86641883433583, 9.672641831474998]
# Mutated population fitness:  [14.611296999240006, 22.551274908527898, 30.76751533679637, 22.551274908527898, 22.551274908527898, 30.76751533679637, 14.611296999240006, 22.551274908527898, 15.09337603056387]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 30.76751533679637, 30.76751533679637, 22.551274908527898, 22.551274908527898, 22.551274908527898, 22.551274908527898, 15.09337603056387, 14.611296999240006, 14.611296999240006]
# Generation  28  completed
# ----------------------------------
# ----------------------------------
# Generation:  29  started
# Fitness of this generation:  [44.026810013899485, 30.76751533679637, 30.76751533679637, 22.551274908527898, 22.551274908527898, 22.551274908527898, 22.551274908527898, 15.09337603056387, 14.611296999240006, 14.611296999240006]
# total sum:  240.08291035064767
# Roulette - Selected Individuals Fitness:  [22.551274908527898, 22.551274908527898, 14.611296999240006, 22.551274908527898, 30.76751533679637, 14.611296999240006, 22.551274908527898, 30.76751533679637, 22.551274908527898]
# Mutated population fitness:  [17.89441253576099, 17.89441253576099, 21.94652592097437, 17.89441253576099, 27.71642112539063, 21.94652592097437, 17.89441253576099, 27.71642112539063, 17.89441253576099]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 27.71642112539063, 27.71642112539063, 21.94652592097437, 21.94652592097437, 17.89441253576099, 17.89441253576099, 17.89441253576099, 17.89441253576099, 17.89441253576099]
# Generation  29  completed
# ----------------------------------
# ----------------------------------
# Generation:  30  started
# Fitness of this generation:  [44.026810013899485, 27.71642112539063, 27.71642112539063, 21.94652592097437, 21.94652592097437, 17.89441253576099, 17.89441253576099, 17.89441253576099, 17.89441253576099, 17.89441253576099]
# total sum:  232.82476678543438
# Roulette - Selected Individuals Fitness:  [17.89441253576099, 21.94652592097437, 21.94652592097437, 21.94652592097437, 17.89441253576099, 17.89441253576099, 17.89441253576099, 44.026810013899485, 44.026810013899485]
# Mutated population fitness:  [15.302287410710857, 18.04438970982394, 18.04438970982394, 18.04438970982394, 15.302287410710857, 15.302287410710857, 15.302287410710857, 29.966814979239953, 29.966814979239953]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 29.966814979239953, 29.966814979239953, 18.04438970982394, 18.04438970982394, 18.04438970982394, 15.302287410710857, 15.302287410710857, 15.302287410710857, 15.302287410710857]
# Generation  30  completed
# ----------------------------------
# ----------------------------------
# Generation:  31  started
# Fitness of this generation:  [44.026810013899485, 29.966814979239953, 29.966814979239953, 18.04438970982394, 18.04438970982394, 18.04438970982394, 15.302287410710857, 15.302287410710857, 15.302287410710857, 15.302287410710857]
# total sum:  219.30275874469461
# Roulette - Selected Individuals Fitness:  [44.026810013899485, 44.026810013899485, 44.026810013899485, 29.966814979239953, 18.04438970982394, 29.966814979239953, 15.302287410710857, 15.302287410710857, 18.04438970982394]
# Mutated population fitness:  [39.17920366725184, 39.17920366725184, 39.17920366725184, 36.76683287964847, 21.392522057952867, 36.76683287964847, 11.377609590770813, 11.377609590770813, 21.392522057952867]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 39.17920366725184, 39.17920366725184, 39.17920366725184, 36.76683287964847, 36.76683287964847, 21.392522057952867, 21.392522057952867, 11.377609590770813, 11.377609590770813]
# Generation  31  completed
# ----------------------------------
# ----------------------------------
# Generation:  32  started
# Fitness of this generation:  [44.026810013899485, 39.17920366725184, 39.17920366725184, 39.17920366725184, 36.76683287964847, 36.76683287964847, 21.392522057952867, 21.392522057952867, 11.377609590770813, 11.377609590770813]
# total sum:  300.6383500723993
# Roulette - Selected Individuals Fitness:  [36.76683287964847, 39.17920366725184, 36.76683287964847, 39.17920366725184, 39.17920366725184, 39.17920366725184, 39.17920366725184, 39.17920366725184, 21.392522057952867]
# Mutated population fitness:  [36.598360619022266, 14.24956139675885, 36.598360619022266, 14.24956139675885, 14.24956139675885, 14.24956139675885, 14.24956139675885, 14.24956139675885, 18.33684814792335]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 36.598360619022266, 36.598360619022266, 18.33684814792335, 14.24956139675885, 14.24956139675885, 14.24956139675885, 14.24956139675885, 14.24956139675885, 14.24956139675885]
# Generation  32  completed
# ----------------------------------
# ----------------------------------
# Generation:  33  started
# Fitness of this generation:  [44.026810013899485, 36.598360619022266, 36.598360619022266, 18.33684814792335, 14.24956139675885, 14.24956139675885, 14.24956139675885, 14.24956139675885, 14.24956139675885, 14.24956139675885]
# total sum:  221.05774778042047
# Roulette - Selected Individuals Fitness:  [14.24956139675885, 18.33684814792335, 36.598360619022266, 36.598360619022266, 44.026810013899485, 44.026810013899485, 14.24956139675885, 36.598360619022266, 36.598360619022266]
# Mutated population fitness:  [13.013838787997951, 18.230743265155155, 26.717784339274843, 26.717784339274843, 35.01156951637558, 35.01156951637558, 13.013838787997951, 26.717784339274843, 26.717784339274843]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 35.01156951637558, 35.01156951637558, 26.717784339274843, 26.717784339274843, 26.717784339274843, 26.717784339274843, 18.230743265155155, 13.013838787997951, 13.013838787997951]
# Generation  33  completed
# ----------------------------------
# ----------------------------------
# Generation:  34  started
# Fitness of this generation:  [44.026810013899485, 35.01156951637558, 35.01156951637558, 26.717784339274843, 26.717784339274843, 26.717784339274843, 26.717784339274843, 18.230743265155155, 13.013838787997951, 13.013838787997951]
# total sum:  265.17950724490106
# Roulette - Selected Individuals Fitness:  [26.717784339274843, 26.717784339274843, 35.01156951637558, 26.717784339274843, 35.01156951637558, 26.717784339274843, 13.013838787997951, 35.01156951637558, 26.717784339274843]
# Mutated population fitness:  [31.36941185295, 31.36941185295, 35.126770418015944, 31.36941185295, 35.126770418015944, 31.36941185295, 10.979981785048643, 35.126770418015944, 31.36941185295]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 35.126770418015944, 35.126770418015944, 35.126770418015944, 31.36941185295, 31.36941185295, 31.36941185295, 31.36941185295, 31.36941185295, 10.979981785048643]
# Generation  34  completed
# ----------------------------------
# ----------------------------------
# Generation:  35  started
# Fitness of this generation:  [44.026810013899485, 35.126770418015944, 35.126770418015944, 35.126770418015944, 31.36941185295, 31.36941185295, 31.36941185295, 31.36941185295, 31.36941185295, 10.979981785048643]
# total sum:  317.23416231774604
# Roulette - Selected Individuals Fitness:  [35.126770418015944, 44.026810013899485, 31.36941185295, 44.026810013899485, 31.36941185295, 35.126770418015944, 31.36941185295, 35.126770418015944, 35.126770418015944]
# Mutated population fitness:  [21.16246677492962, 36.315836765796824, 17.35770722186545, 36.315836765796824, 17.35770722186545, 21.16246677492962, 17.35770722186545, 21.16246677492962, 21.16246677492962]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 36.315836765796824, 36.315836765796824, 21.16246677492962, 21.16246677492962, 21.16246677492962, 21.16246677492962, 17.35770722186545, 17.35770722186545, 17.35770722186545]
# Generation  35  completed
# ----------------------------------
# ----------------------------------
# Generation:  36  started
# Fitness of this generation:  [44.026810013899485, 36.315836765796824, 36.315836765796824, 21.16246677492962, 21.16246677492962, 21.16246677492962, 21.16246677492962, 17.35770722186545, 17.35770722186545, 17.35770722186545]
# total sum:  253.3814723108079
# Roulette - Selected Individuals Fitness:  [36.315836765796824, 17.35770722186545, 21.16246677492962, 17.35770722186545, 21.16246677492962, 36.315836765796824, 36.315836765796824, 21.16246677492962, 17.35770722186545]
# Mutated population fitness:  [30.07922871351591, 16.923652088128023, 9.99799979995999, 16.923652088128023, 9.99799979995999, 30.07922871351591, 30.07922871351591, 9.99799979995999, 16.923652088128023]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 30.07922871351591, 30.07922871351591, 30.07922871351591, 16.923652088128023, 16.923652088128023, 16.923652088128023, 9.99799979995999, 9.99799979995999, 9.99799979995999]
# Generation  36  completed
# ----------------------------------
# ----------------------------------
# Generation:  37  started
# Fitness of this generation:  [44.026810013899485, 30.07922871351591, 30.07922871351591, 30.07922871351591, 16.923652088128023, 16.923652088128023, 16.923652088128023, 9.99799979995999, 9.99799979995999, 9.99799979995999]
# total sum:  215.02945181871124
# Roulette - Selected Individuals Fitness:  [30.07922871351591, 16.923652088128023, 30.07922871351591, 30.07922871351591, 30.07922871351591, 9.99799979995999, 30.07922871351591, 44.026810013899485, 30.07922871351591]
# Mutated population fitness:  [18.482694608741443, 9.436100889668358, 18.482694608741443, 18.482694608741443, 18.482694608741443, 9.413288479590966, 18.482694608741443, 38.58237939785466, 18.482694608741443]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [44.026810013899485, 38.58237939785466, 18.482694608741443, 18.482694608741443, 18.482694608741443, 18.482694608741443, 18.482694608741443, 18.482694608741443, 9.436100889668358, 9.413288479590966]
# Generation  37  completed
# ----------------------------------
# ----------------------------------
# Generation:  38  started
# Fitness of this generation:  [44.026810013899485, 38.58237939785466, 18.482694608741443, 18.482694608741443, 18.482694608741443, 18.482694608741443, 18.482694608741443, 18.482694608741443, 9.436100889668358, 9.413288479590966]
# total sum:  212.3547464334621
# Roulette - Selected Individuals Fitness:  [18.482694608741443, 18.482694608741443, 9.436100889668358, 18.482694608741443, 44.026810013899485, 18.482694608741443, 9.413288479590966, 18.482694608741443, 18.482694608741443]
# Mutated population fitness:  [35.8503835404867, 35.8503835404867, 14.028898745090435, 35.8503835404867, 49.49636350278675, 35.8503835404867, 10.952625256074453, 35.8503835404867, 35.8503835404867]
# elite fitness:  [44.026810013899485]
# Next generation fitness :  [49.49636350278675, 44.026810013899485, 35.8503835404867, 35.8503835404867, 35.8503835404867, 35.8503835404867, 35.8503835404867, 35.8503835404867, 14.028898745090435, 10.952625256074453]
# Generation  38  completed
# ----------------------------------
# ----------------------------------
# Generation:  39  started
# Fitness of this generation:  [49.49636350278675, 44.026810013899485, 35.8503835404867, 35.8503835404867, 35.8503835404867, 35.8503835404867, 35.8503835404867, 35.8503835404867, 14.028898745090435, 10.952625256074453]
# total sum:  333.60699876077126
# Roulette - Selected Individuals Fitness:  [35.8503835404867, 35.8503835404867, 35.8503835404867, 44.026810013899485, 35.8503835404867, 49.49636350278675, 35.8503835404867, 35.8503835404867, 49.49636350278675]
# Mutated population fitness:  [17.0985379491932, 17.0985379491932, 17.0985379491932, 41.141827864109295, 17.0985379491932, 40.455531142230726, 17.0985379491932, 17.0985379491932, 40.455531142230726]
# elite fitness:  [49.49636350278675]
# Next generation fitness :  [49.49636350278675, 41.141827864109295, 40.455531142230726, 40.455531142230726, 17.0985379491932, 17.0985379491932, 17.0985379491932, 17.0985379491932, 17.0985379491932, 17.0985379491932]
# Generation  39  completed
# ----------------------------------
# ----------------------------------
# Generation:  40  started
# Fitness of this generation:  [49.49636350278675, 41.141827864109295, 40.455531142230726, 40.455531142230726, 17.0985379491932, 17.0985379491932, 17.0985379491932, 17.0985379491932, 17.0985379491932, 17.0985379491932]
# total sum:  274.1404813465167
# Roulette - Selected Individuals Fitness:  [17.0985379491932, 49.49636350278675, 17.0985379491932, 41.141827864109295, 49.49636350278675, 49.49636350278675, 17.0985379491932, 17.0985379491932, 17.0985379491932]
# Mutated population fitness:  [13.780058055030102, 42.35091498421256, 13.780058055030102, 31.113341189914017, 42.35091498421256, 42.35091498421256, 13.780058055030102, 13.780058055030102, 13.780058055030102]
# elite fitness:  [49.49636350278675]
# Next generation fitness :  [49.49636350278675, 42.35091498421256, 42.35091498421256, 42.35091498421256, 31.113341189914017, 13.780058055030102, 13.780058055030102, 13.780058055030102, 13.780058055030102, 13.780058055030102]
# Generation  40  completed
# ----------------------------------
# ----------------------------------
# Generation:  41  started
# Fitness of this generation:  [49.49636350278675, 42.35091498421256, 42.35091498421256, 42.35091498421256, 31.113341189914017, 13.780058055030102, 13.780058055030102, 13.780058055030102, 13.780058055030102, 13.780058055030102]
# total sum:  276.562739920489
# Roulette - Selected Individuals Fitness:  [31.113341189914017, 13.780058055030102, 42.35091498421256, 42.35091498421256, 42.35091498421256, 13.780058055030102, 31.113341189914017, 49.49636350278675, 31.113341189914017]
# Mutated population fitness:  [30.082553083141065, 15.782585339544342, 38.611008792830056, 38.611008792830056, 38.611008792830056, 15.782585339544342, 30.082553083141065, 44.640340500493494, 30.082553083141065]
# elite fitness:  [49.49636350278675]
# Next generation fitness :  [49.49636350278675, 44.640340500493494, 38.611008792830056, 38.611008792830056, 38.611008792830056, 30.082553083141065, 30.082553083141065, 30.082553083141065, 15.782585339544342, 15.782585339544342]
# Generation  41  completed
# ----------------------------------
# ----------------------------------
# Generation:  42  started
# Fitness of this generation:  [49.49636350278675, 44.640340500493494, 38.611008792830056, 38.611008792830056, 38.611008792830056, 30.082553083141065, 30.082553083141065, 30.082553083141065, 15.782585339544342, 15.782585339544342]
# total sum:  331.7825603102824
# Roulette - Selected Individuals Fitness:  [44.640340500493494, 38.611008792830056, 38.611008792830056, 30.082553083141065, 44.640340500493494, 49.49636350278675, 15.782585339544342, 49.49636350278675, 38.611008792830056]
