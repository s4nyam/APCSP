# %% [markdown]
# # 1. Creating 'n' random (using random kernels) lenia images "meaningful" Dataset for AutoEncoder training procedure

# %% [markdown]
# ### For example generating 100 frames each gif, let us just save 10000 images by calling 100 random kernels. As we generate 100 frames each simulation, we just need 100 random simulations for 100 random kernels which produces 100*100=10000 images

# %%
# Datset creation which is used by autoencoder

dataset_size = 10
# Imports
# https://chakazul.github.io/Lenia/JavaScript/Lenia.html
import numpy as np
from matplotlib import pyplot as plt
import time
import warnings
warnings.simplefilter("ignore", UserWarning)
#Imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
import scipy.signal
import os.path
import os
from datetime import datetime
from json import JSONEncoder
import json
from pathlib import Path
                

OUTPUT_PATH = './outputs'

mu = 0.31
sigma = 0.057
dt = 0.1


frames = 100



class Lenia:
    def __init__(self, kernel, board):
        self.sigma = sigma
        self.mu = mu
        self.dt = dt
        self.kernel = kernel
        self.normalise_kernel()
        self.frames = frames
        self.anim = None
        self.lenia_board_state = {}
        self.frame_intervals = 10
        # For random initialisation
        self.board = board
        self.cmap = 'viridis'
        self.fig, self.img = self.show_board()
        

    # FLEXIBLITY TO CHANGE GROWTH FUNCTION
    def growth_function1(self, U:np.array):
        gaussian = lambda x, m, s: np.exp(-( (x-m)**2 / (2*s**2) ))
        return gaussian(U, self.mu, self.sigma)*2-1


    def show_board(self, 
                   display:bool=False,
                   ):
        dpi = 50 # Using a higher dpi will result in higher quality graphics but will significantly affect computation

        self.fig = plt.figure(figsize=(10*np.shape(self.board)[1]/dpi, 10*np.shape(self.board)[0]/dpi), dpi=dpi)

        ax = self.fig.add_axes([0, 0, 1, 1])
        ax.axis('off')
        
        self.img = ax.imshow(self.board, cmap=self.cmap, interpolation='none', aspect=1, vmin=0) #  vmax=vmax
        
        if display:
            plt.show()
        else: # Do not show intermediate figures when creating animations (very slow)
            plt.close()

        return self.fig, self.img
    
    
    def animate(self):
        
        self.anim =  matplotlib.animation.FuncAnimation(self.fig, self.animate_step, 
                                            frames=self.frames, interval=self.frame_intervals, blit=True)

    
    def animate_step(self, i:int) -> plt.imshow:
        neighbours = scipy.signal.convolve2d(self.board, self.kernel, mode='same', boundary='wrap')
        self.board = np.clip(self.board + self.dt * self.growth_function1(neighbours), 0, 1)
        if (i+1) % 10 == 0:
            self.record_board_state(i)
        self.img.set_array(self.board) # render the updated state 
        return self.img,

    def save_animation(self, dir, 
                       filename:str,
                       ):
        if not self.anim:
            raise Exception('ERROR: Run animation before attempting to save')
            return 
        output_path = OUTPUT_PATH+"/"+dir
        Path(output_path).mkdir(parents=True, exist_ok=True)
        fmt = os.path.splitext(filename)[1] # isolate the file extension
        
        if fmt == '.gif':
            f = os.path.join(output_path, filename) 
            writer = matplotlib.animation.PillowWriter(fps=30) 
            self.anim.save(f, writer=writer)
        else:
            raise Exception('ERROR: Unknown save format. Must be .gif or .mp4')
        # writer.close()

    
    def normalise_kernel(self) -> np.array:

        kernel_norm = self.kernel / (1*np.sum(self.kernel))
        self.norm_factor = 1/ (1*np.sum(self.kernel))
        self.kernel = kernel_norm 
        return kernel_norm
        
        
    def plot_kernel_info(self,
                         dir,
                         cmap:str='viridis', 
                         bar:bool=False,
                         save:str=None,
                         ) -> None:

        
        k_xsection = self.kernel[self.kernel.shape[0] // 2, :]
        k_sum = np.sum(self.kernel)
        
        fig, ax = plt.subplots(1, 3, figsize=(14,2), gridspec_kw={'width_ratios': [1,1,2]})
        
        # Show kernel as heatmap
        ax[0].imshow(self.kernel, cmap=cmap, vmin=0)
        ax[0].title.set_text('Kernel')
        
        # Show kernel cross-section
        ax[1].title.set_text('Kernel Cross-section')
        if bar==True:
            ax[1].bar(range(0,len(k_xsection)), k_xsection, width=1)
        else:
            ax[1].plot(k_xsection)
        
        # Growth function
        ax[2].title.set_text('Growth Function')
        x = np.linspace(0, k_sum, 1000)
        ax[2].plot(x, self.growth_function1(x))
        
        if save:
            output_path = OUTPUT_PATH+"/"+dir
            Path(output_path).mkdir(parents=True, exist_ok=True)
            print('Saving kernel and growth function info to', os.path.join(output_path, 'kernel_info'))
            
            plt.savefig(os.path.join(output_path, 'kernel_info.png') )


    def run_simulation(self, generation) -> None:
        self.animate()
        sub_dir = generation+"/"+str(datetime.now())
        outfile = "output"+str(datetime.now())+".gif"   
        print('./folder/{}...)'.format(sub_dir))
        
        self.save_animation(sub_dir, outfile)
        self.plot_kernel_info(dir=sub_dir, save=True)
        return self.lenia_board_state


    def record_board_state(self, i):
        board_arr = self.board.flatten()
        board_val_greater_than_point_five = list(board_arr[board_arr > 0.5])
        self.lenia_board_state["frame_"+str(i+1)] = len(board_val_greater_than_point_five)

# %%
kernel_size = 16
board_size = 64
def random_kernel_generator():
    grid = np.random.rand(kernel_size, kernel_size)
    grid = np.round(grid, 3)
    return grid
def random_board_generator():
    board = np.random.rand(board_size, board_size)
    board = np.round(board, 3)
    return board

# %%
# !rm -rf outputs
# !rm -rf sample_data
# !rm *.png
# !rm *.gif
for i in range(dataset_size):
  board = random_board_generator()
  lenia = Lenia(random_kernel_generator(), random_board_generator())
  board_alive_cell = lenia.run_simulation("certain_files")
# Out:
# rm: cannot remove '*.png': No such file or directory
# rm: cannot remove '*.gif': No such file or directory
# ./folder/certain_files/2023-04-10 08:43:37.912527...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-04-10 08:43:37.912527/kernel_info
# ./folder/certain_files/2023-04-10 08:43:47.508363...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-04-10 08:43:47.508363/kernel_info
# ./folder/certain_files/2023-04-10 08:43:55.789007...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-04-10 08:43:55.789007/kernel_info
# ./folder/certain_files/2023-04-10 08:44:03.208605...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-04-10 08:44:03.208605/kernel_info
# ./folder/certain_files/2023-04-10 08:44:11.058635...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-04-10 08:44:11.058635/kernel_info
# ./folder/certain_files/2023-04-10 08:44:19.299416...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-04-10 08:44:19.299416/kernel_info
# ./folder/certain_files/2023-04-10 08:44:26.592352...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-04-10 08:44:26.592352/kernel_info
# ./folder/certain_files/2023-04-10 08:44:37.568370...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-04-10 08:44:37.568370/kernel_info
# ./folder/certain_files/2023-04-10 08:44:45.747346...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-04-10 08:44:45.747346/kernel_info
# ./folder/certain_files/2023-04-10 08:44:52.944963...)
# Saving kernel and growth function info to ./outputs/certain_files/2023-04-10 08:44:52.944963/kernel_info

# %%
# !mv /content/outputs/*/*/*.gif /content/

# %%
# !rm -rf outputs

# %%
# !i=1; for file in *; do mv "$file" "$(printf '%d' $i).${file##*.}"; ((i++)); done

# %%
# !ffmpeg
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Hyper fast Audio and Video encoder
# usage: ffmpeg [options] [[infile options] -i infile]... {[outfile options] outfile}...
#
# Use -h to get full help or, even better, run 'man ffmpeg'

# %%
# !for file in *.gif; do ffmpeg -i "$file" "${file%.*}-%d.jpg"; done
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '10.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5559 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5575a2881f80] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '10-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps= 68 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=2.05x
# video:3714kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '1.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5402 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55e7a010e800] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '1-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps= 75 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=2.25x
# video:3599kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '2.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 8077 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55bfc93c40c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '2-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.44x
# video:3293kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '3.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5425 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x56346e750780] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '3-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.53x
# video:3620kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '4.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 4592 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x564c6eec7cc0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '4-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed= 3.5x
# video:3269kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '5.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 4970 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x560f50dbc3c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '5-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.32x
# video:3496kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '6.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 4721 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5585024c0000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '6-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed= 3.5x
# video:3395kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '7.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 5389 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55cf317a0a40] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '7-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed= 3.2x
# video:3620kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '8.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 6565 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55964aff3540] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '8-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.34x
# video:3472kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from '9.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 4823 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5557e1ac1200] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to '9-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed=3.52x
# video:3467kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
# !rm *.gif
# !rm *.png
# Out:
# rm: cannot remove '*.png': No such file or directory

# %%
# !i=1; for file in *; do mv "$file" "$(printf '%d' $i).${file##*.}"; ((i++)); done

# %%
# !mkdir dataset
# !mv *.jpg dataset

# %%
# !ls /content/dataset | wc -l
# Out:
# 1000

# %% [markdown]
# # 2. AutoEncoder procedure

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "/content/dataset/"

# Initialize lists to hold the image data and labels
data = []

# Loop over the files in the folder
for filename in os.listdir(folder_path):
    # Load the image using OpenCV
    img = cv2.imread(os.path.join(folder_path, filename))
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Resize the image to a fixed size
    resized = cv2.resize(gray, (28, 28))
    # Add the image data to the list
    data.append(resized)
    # Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)

# Split the data into training and testing sets

# %%
xtrain, xtest = train_test_split(data, test_size=0.3, random_state=2)

     

X_train = xtrain.reshape(xtrain.shape[0], 28, 28, 1)
X_test = xtest.reshape(xtest.shape[0], 28, 28, 1)

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.layers import Layer
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, add
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras import regularizers
from keras.regularizers import l2
from keras.layers.convolutional import Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D
from keras.utils import np_utils

# %%
X_train = X_train.astype("float32")/255.
X_test = X_test.astype("float32")/255.

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (700, 28, 28, 1)
# 700 train samples
# 300 test samples

# %%
X_train = X_train.reshape((len(X_train), np.prod(X_train.shape[1:])))
X_test = X_test.reshape((len(X_test), np.prod(X_test.shape[1:])))

# %%
input_size = 784
hidden_size = 36
output_size = 784

# %%
x = Input(shape=(input_size,))
h = Dense(hidden_size, activation='relu')(x)
r = Dense(output_size, activation='sigmoid')(h)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adam', loss='mse')
     

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(autoencoder).create(prog='dot', format='svg'))

# %%
epochs = 300
batch_size = 128

history = autoencoder.fit(X_train, X_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test, X_test))
# Out:
# Epoch 1/300
# 6/6 [==============================] - 1s 70ms/step - loss: 0.1083 - val_loss: 0.1061
# Epoch 2/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.1025 - val_loss: 0.0983
# Epoch 3/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0928 - val_loss: 0.0881
# Epoch 4/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0813 - val_loss: 0.0774
# Epoch 5/300
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0705 - val_loss: 0.0684
# Epoch 6/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0616 - val_loss: 0.0614
# Epoch 7/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0549 - val_loss: 0.0559
# Epoch 8/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0499 - val_loss: 0.0516
# Epoch 9/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0458 - val_loss: 0.0478
# Epoch 10/300
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0423 - val_loss: 0.0444
# Epoch 11/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0391 - val_loss: 0.0413
# Epoch 12/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0363 - val_loss: 0.0385
# Epoch 13/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0338 - val_loss: 0.0361
# Epoch 14/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0316 - val_loss: 0.0338
# Epoch 15/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0296 - val_loss: 0.0318
# Epoch 16/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0277 - val_loss: 0.0299
# Epoch 17/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0260 - val_loss: 0.0281
# Epoch 18/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0244 - val_loss: 0.0263
# Epoch 19/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0247
# Epoch 20/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0215 - val_loss: 0.0231
# Epoch 21/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0202 - val_loss: 0.0217
# Epoch 22/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0190 - val_loss: 0.0204
# Epoch 23/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0181 - val_loss: 0.0192
# Epoch 24/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 25/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0164 - val_loss: 0.0174
# Epoch 26/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0157 - val_loss: 0.0166
# Epoch 27/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0152 - val_loss: 0.0160
# Epoch 28/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0146 - val_loss: 0.0155
# Epoch 29/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0142 - val_loss: 0.0150
# Epoch 30/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0138 - val_loss: 0.0145
# Epoch 31/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0135 - val_loss: 0.0142
# Epoch 32/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0132 - val_loss: 0.0138
# Epoch 33/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0129 - val_loss: 0.0135
# Epoch 34/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0126 - val_loss: 0.0132
# Epoch 35/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0123 - val_loss: 0.0129
# Epoch 36/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0121 - val_loss: 0.0126
# Epoch 37/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0119 - val_loss: 0.0124
# Epoch 38/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0116 - val_loss: 0.0122
# Epoch 39/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0114 - val_loss: 0.0120
# Epoch 40/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0113 - val_loss: 0.0118
# Epoch 41/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0111 - val_loss: 0.0116
# Epoch 42/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0109 - val_loss: 0.0114
# Epoch 43/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0107 - val_loss: 0.0112
# Epoch 44/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0106 - val_loss: 0.0111
# Epoch 45/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0104 - val_loss: 0.0109
# Epoch 46/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0103 - val_loss: 0.0108
# Epoch 47/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0102 - val_loss: 0.0107
# Epoch 48/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 49/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 50/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 51/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0097 - val_loss: 0.0102
# Epoch 52/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0096 - val_loss: 0.0101
# Epoch 53/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0095 - val_loss: 0.0099
# Epoch 54/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0094 - val_loss: 0.0099
# Epoch 55/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0093 - val_loss: 0.0098
# Epoch 56/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0092 - val_loss: 0.0096
# Epoch 57/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0091 - val_loss: 0.0096
# Epoch 58/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0090 - val_loss: 0.0095
# Epoch 59/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0094
# Epoch 60/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.0093
# Epoch 61/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 62/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 63/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0086 - val_loss: 0.0090
# Epoch 64/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0085 - val_loss: 0.0090
# Epoch 65/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0084 - val_loss: 0.0089
# Epoch 66/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0083 - val_loss: 0.0088
# Epoch 67/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0083 - val_loss: 0.0087
# Epoch 68/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 69/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0081 - val_loss: 0.0086
# Epoch 70/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0080 - val_loss: 0.0085
# Epoch 71/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 72/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 0.0084
# Epoch 73/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 74/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 75/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0077 - val_loss: 0.0081
# Epoch 76/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0081
# Epoch 77/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0080
# Epoch 78/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0075 - val_loss: 0.0079
# Epoch 79/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 80/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0073 - val_loss: 0.0078
# Epoch 81/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0073 - val_loss: 0.0078
# Epoch 82/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 83/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0076
# Epoch 84/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0076
# Epoch 85/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0070 - val_loss: 0.0075
# Epoch 86/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0070 - val_loss: 0.0074
# Epoch 87/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0074
# Epoch 88/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0069 - val_loss: 0.0073
# Epoch 89/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 90/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 91/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 92/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0072
# Epoch 93/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 94/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0065 - val_loss: 0.0071
# Epoch 95/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 96/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0064 - val_loss: 0.0070
# Epoch 97/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0069
# Epoch 98/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 99/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 100/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0068
# Epoch 101/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 102/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 103/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 104/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 105/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 106/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 107/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0059 - val_loss: 0.0064
# Epoch 108/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0059 - val_loss: 0.0064
# Epoch 109/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0058 - val_loss: 0.0064
# Epoch 110/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 111/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 112/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0063
# Epoch 113/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 114/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 115/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 116/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 117/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 118/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 119/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 120/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 121/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 122/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 123/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 124/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 125/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 126/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0058
# Epoch 127/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0052 - val_loss: 0.0058
# Epoch 128/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 129/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 130/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0057
# Epoch 131/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0057
# Epoch 132/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 133/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0056
# Epoch 134/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0056
# Epoch 135/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 136/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 137/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 138/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 139/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 140/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 141/300
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 142/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 143/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 144/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 145/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0053
# Epoch 146/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0053
# Epoch 147/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0052
# Epoch 148/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0047 - val_loss: 0.0052
# Epoch 149/300
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0047 - val_loss: 0.0052
# Epoch 150/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 151/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 152/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 153/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 154/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 155/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 156/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 157/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 158/300
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 159/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 160/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 161/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 162/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 163/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 164/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 165/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0044 - val_loss: 0.0049
# Epoch 166/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 167/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 168/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 169/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 170/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 171/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 172/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0042 - val_loss: 0.0048
# Epoch 173/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0048
# Epoch 174/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0042 - val_loss: 0.0048
# Epoch 175/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0048
# Epoch 176/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 0.0047
# Epoch 177/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0047
# Epoch 178/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0047
# Epoch 179/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 180/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 181/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 182/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 183/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 184/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 185/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 186/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 187/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 188/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 189/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 190/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 191/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 192/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 193/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 194/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 195/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 196/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 197/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 198/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 199/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 200/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 201/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 202/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 203/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 204/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 205/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 206/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 207/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 208/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 209/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 210/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 211/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 212/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 213/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 214/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 215/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 216/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 217/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 218/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 219/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 220/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 221/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 222/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 223/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 224/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 225/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 226/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 227/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 228/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 229/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 230/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 231/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 232/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 233/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 234/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 235/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 236/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 237/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 238/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 239/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 240/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 241/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 242/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 243/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 244/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 245/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 246/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 247/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 248/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 249/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 250/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 251/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 252/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 253/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 254/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 255/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 256/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 257/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 258/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 259/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 260/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 261/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 262/300
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 263/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 264/300
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 265/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 266/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 267/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 268/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 269/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 270/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 271/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 272/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 273/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 274/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 275/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 276/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 277/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 278/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 279/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 280/300
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 281/300
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 282/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 283/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 284/300
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 285/300
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 286/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 287/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 288/300
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 289/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 290/300
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 291/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 292/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 293/300
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 294/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 295/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 296/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 297/300
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 298/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 299/300
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 300/300
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0035 - val_loss: 0.0040

# %%
conv_encoder = Model(x, h)
encoded_imgs = conv_encoder.predict(X_test)

n = 1
plt.figure(figsize=(28, 10))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(encoded_imgs[i].reshape(6, 6).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
decoded_imgs = autoencoder.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %%
n = 1
plt.figure(figsize=(28, 28))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i+1)
    plt.imshow(X_test[i].reshape(28, 28),cmap="gist_earth")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
plt.figure(figsize=(28,28))
for i in range(n):    
    # display reconstruction
    ax = plt.subplot(3, n, i+n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap="gist_earth")
    # plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %%
print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
import tensorflow as tf
i=99
print("Error or loss for the image "+str(i))
print(tf.math.reduce_mean(tf.square(decoded_imgs[i].reshape(28, 28)-X_test[i].reshape(28, 28))))
print("------------------------------------------------------------------")
# Out:
# Error or loss for the image 99
# tf.Tensor(0.0024834343, shape=(), dtype=float32)
# ------------------------------------------------------------------

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 36)                28260
#
#  dense_1 (Dense)             (None, 784)               29008
#
# =================================================================
# Total params: 57,268
# Trainable params: 57,268
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Test the model with any random lenia board state

# %%
# Check for orderly image reconstruction loss
# !wget https://dl3.pushbulletusercontent.com/pVIOI0eH0xLUqrczqileIhK0fUO5n0OL/order.jpg
# !wget https://dl3.pushbulletusercontent.com/r8r00OkVim4UwQEyqEG5diLnZWNni1e4/order.jpg
from IPython.display import Image
Image("order.jpg",width = 256, height = 256)
# Out:
# --2023-04-10 08:46:14--  https://dl3.pushbulletusercontent.com/r8r00OkVim4UwQEyqEG5diLnZWNni1e4/order.jpg
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71152 (69K) [image/jpeg]
# Saving to: ‘order.jpg’
#
# order.jpg           100%[===================>]  69.48K  --.-KB/s    in 0.07s
#
# 2023-04-10 08:46:14 (1.01 MB/s) - ‘order.jpg’ saved [71152/71152]

# %%
# Check for orderly image reconstruction loss
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "./"

# Initialize lists to hold the image data and labels
data = []

filename = "order.jpg"
# Load the image using OpenCV
img = cv2.imread(os.path.join(folder_path, filename))
# Resize the image to a fixed size
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
# Add the image data to the list
data.append(resized)
# Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)
data.shape
# Out:
# (1, 28, 28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_order_image = autoencoder.predict(data[0].reshape(1,784))
print(predicted_order_image.shape)
# Out:
# 1/1 [==============================] - 0s 65ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_order_image.reshape(28,28))

# %%
# # RECONSTRUCTION LOSS
# import tensorflow as tf
# print(tf.math.reduce_mean(predicted_order_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
import tensorflow as tf
print("recon loss MSE")
import numpy as np

# assuming original_img and reconstructed_img are numpy arrays of shape (28, 28)
mse = np.mean((-data[0].reshape(28,28) + predicted_order_image.reshape(28,28))**2)
print(mse)
# Out:
# recon loss MSE
# 28311.086

# %%
# Check for chaotic image reconstruction loss
# !wget https://dl3.pushbulletusercontent.com/JMja0JFwu2M2r1A2XFKJUhj2d049mh28/chaotic.jpg
# !wget https://dl3.pushbulletusercontent.com/HiHs0WSO0K8cEiYGfeWPeW0Q5MDGkmCs/chaotic.jpg
from IPython.display import Image
Image("chaotic.jpg",width = 256, height = 256)
# Out:
# --2023-04-10 08:46:15--  https://dl3.pushbulletusercontent.com/HiHs0WSO0K8cEiYGfeWPeW0Q5MDGkmCs/chaotic.jpg
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 202671 (198K) [image/jpeg]
# Saving to: ‘chaotic.jpg’
#
# chaotic.jpg         100%[===================>] 197.92K  --.-KB/s    in 0.1s
#
# 2023-04-10 08:46:15 (1.64 MB/s) - ‘chaotic.jpg’ saved [202671/202671]

# %%
# Check for orderly image reconstruction loss
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "./"

# Initialize lists to hold the image data and labels
data = []

filename = "chaotic.jpg"
# Load the image using OpenCV
img = cv2.imread(os.path.join(folder_path, filename))
# Resize the image to a fixed size
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
# Add the image data to the list
data.append(resized)
# Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)

# %%
data.shape
# Out:
# (1, 28, 28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_chaotic_image = autoencoder.predict(data[0].reshape(1,784))
print(predicted_chaotic_image.shape)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_chaotic_image.reshape(28,28))

# %%
# # RECONSTRUCTION LOSS
# import tensorflow as tf
# print(tf.math.reduce_mean(predicted_chaotic_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
import tensorflow as tf
print("recon loss MSE")
import numpy as np

# assuming original_img and reconstructed_img are numpy arrays of shape (28, 28)
mse = np.mean((-data[0].reshape(28,28) + predicted_chaotic_image.reshape(28,28))**2)
print(mse)
# Out:
# recon loss MSE
# 26423.516

# %% [markdown]
# # 4. Picking random image from test dataset and result reconstructed loss

# %%
import random
data = X_test[random.randint(1,len(X_test))].reshape(1,28,28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_chaotic_image = autoencoder.predict(data[0].reshape(1,784))
print(predicted_chaotic_image.shape)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_chaotic_image.reshape(28,28))

# %%
# # RECONSTRUCTION LOSS
# import tensorflow as tf
# print(tf.math.reduce_mean(predicted_chaotic_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
import tensorflow as tf
print("recon loss MSE")
import numpy as np

# assuming original_img and reconstructed_img are numpy arrays of shape (28, 28)
mse = np.mean((-data[0].reshape(28,28) + predicted_chaotic_image.reshape(28,28))**2)
print(mse)
# Out:
# recon loss MSE
# 0.0035995417

# %% [markdown]
# # 4. Picking 10 random images from test dataset and result reconstructed loss

# %%
import random

images_10 = []
for i in range(10):
  data = X_test[random.randint(1,len(X_test))].reshape(1,28,28)
  # plt.imshow(data[0])
  images_10.append(data[0])
fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(20, 4))

# display each image in a separate subplot

for i in range(10):
  axes[i].imshow(images_10[i].reshape(28,28))
  axes[i].axis('off')
# plt.title("Ground Truth Images",fontsize=16, loc='center')
fig.suptitle('Ground Truth Images', fontsize=16, fontweight='bold')
fig.tight_layout()

plt.show()

# %%
predicted_images = []
for i in range(10):
  predicted_chaotic_image = autoencoder.predict(images_10[i].reshape(1,784))
  predicted_images.append(predicted_chaotic_image)
fig, axes = plt.subplots(nrows=1, ncols=10, figsize=(20, 4))

# display each image in a separate subplot

for i in range(10):
  axes[i].imshow(predicted_images[i].reshape(28,28))
  axes[i].axis('off')
# plt.title("Ground Truth Images",fontsize=16, loc='center')
fig.suptitle('Predicted Images', fontsize=16, fontweight='bold')
fig.tight_layout()

plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
predicted_images = []
for i in range(10):
  predicted_chaotic_image = autoencoder.predict(images_10[i].reshape(1,784))
  predicted_images.append(predicted_chaotic_image)
fig, axes = plt.subplots(nrows=2, ncols=10, figsize=(40, 8))

# display each image in a separate subplot
for j in range(2):
  for i in range(10):
    if(j==1):
      axes[j][i].imshow(predicted_images[i].reshape(28,28))
      axes[j][i].axis('off')
      # axes[j].set_title('Predicted Images')
      axes[j][i].set_title('Predicted Image '+str(i))
      mse = np.mean((-images_10[i].reshape(28,28) + predicted_images[i].reshape(28,28))**2)
      # print(mse)
      string = "Reconstruction Loss: "+str(round(mse,8))
      axes[j][i].text(0.5, -0.1,string, fontsize=10, ha='center',transform=axes[j][i].transAxes)
    else:
      axes[j][i].imshow(images_10[i].reshape(28,28))
      axes[j][i].axis('off')
      axes[j][i].set_title('Ground Truth Image '+str(i))
      # axes[j].set_title('Ground Truth Images')
# plt.title("Ground Truth Images",fontsize=16, loc='center')
fig.suptitle('Ground Truth Images 1st row, Predicted Images 2nd row', fontsize=16, fontweight='bold')
fig.tight_layout()

plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step

# %% [markdown]
# #From the last meeting Stefano suggested to use:
#
# ### ⛳Bottleneck = Shrink Size (have shrinked from 64 to 32)
#
# ### ⛳Meaningful Dataset = As of now I am generating 'n' random gifs and saving their frames and putting them as dataset
#
# ### ⛳ Stefano suggested to use deviation as measure of emerging pattern rather than reconstruction loss.
# ##### ==> so the idea is to maximise the deviation of reconstruction. The more the pixels are deviated over time in a reconstructed animation (so let say we have 100 frames of original rule set. those 100 frames vs same frames reconstructed through Autoencoder. The hypothesis is, if we have deviation in reconstruction of those 100 frames, that means there should be some non-boring behaviour)
#
# ✅
# Theory: Autoencoder is a type of neural network that can be used for dimensionality reduction and feature extraction. One way it can help in measuring complexity is by using reconstruction error.
#
# The basic idea of an autoencoder is to learn a compressed representation of the input data, and then use that representation to reconstruct the original data. The input data is first encoded into a compressed representation, which is then decoded back into the original data. The goal is to minimize the difference between the input data and the reconstructed output.
#
# If the autoencoder is successful in reconstructing the input data accurately, then the reconstruction error will be low. However, if the input data is complex and has a lot of variability, it may be difficult for the autoencoder to reconstruct the data accurately, resulting in a higher reconstruction error.
#
# Therefore, the reconstruction error can be used as a measure of complexity, where higher reconstruction error indicates higher complexity. This is because complex data is more difficult to accurately represent and reconstruct using a compressed representation.
#
# In summary, autoencoder can help in measuring complexity using reconstruction error, where the higher reconstruction error indicates higher complexity of the input data.

# %% [markdown]
# ### ⭐ How variation over time can be thought:
# To use an autoencoder for time series data, you can treat each time step as a separate input and train the autoencoder to reconstruct the original sequence of data. The reconstruction loss, which is the difference between the input and the reconstructed output, can then be used to measure the complexity of the time series data.
#
# By analyzing the variation in the reconstruction loss over time, you can gain insights into the complexity of the time series. For example, if the reconstruction loss is relatively constant over time, it may indicate that the time series is relatively simple or predictable. However, if the reconstruction loss varies widely over time, it may indicate that the time series is more complex and difficult to predict.
#
# Additionally, you can use techniques such as spectral analysis or wavelet analysis to further analyze the variation in the reconstruction loss over time. These techniques can help identify patterns and correlations in the data that may not be immediately apparent from the reconstruction loss alone.
#
# In summary, using an autoencoder for time series data and analyzing the variation over time in the reconstruction loss can be a useful approach for measuring the complexity of the time series data.

# %% [markdown]
# # Let us analyse for one case:
# ### step1: generate one random pattern, save first 100 frames
# ### step2: generate reconstruction of those 100 frames using trained auto-encoder
# ### step3: check for variation in reconstruction loss over time between both the frame-sets.

# %%
lenia.run_simulation("outputs") # saving one animation
# Out:
# ./folder/outputs/2023-04-10 08:46:22.869770...)
# Saving kernel and growth function info to ./outputs/outputs/2023-04-10 08:46:22.869770/kernel_info
# {'frame_10': 1699,
#  'frame_20': 1697,
#  'frame_30': 1698,
#  'frame_40': 1707,
#  'frame_50': 1692,
#  'frame_60': 1692,
#  'frame_70': 1705,
#  'frame_80': 1697,
#  'frame_90': 1693,
#  'frame_100': 1700}

# %%
# !mv /content/outputs/outputs/*/*.gif /content/

# %%
# !rm -rf /content/outputs

# %%
# !mkdir original100
# !mv *.gif original100
# %cd original100
# !for file in *.gif; do ffmpeg -i "$file" "${file%.*}-%d.jpg"; done
# %cd /content/
# Out:
# /content/original100
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, gif, from 'output2023-04-10 08:46:22.869792.gif':
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 2839 kb/s
#     Stream #0:0: Video: gif, bgra, 640x640, 33.33 fps, 33.33 tbr, 100 tbn, 100 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (gif (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x564a321c85c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'output2023-04-10 08:46:22.869792-%d.jpg':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mjpeg, yuvj444p(pc), 640x640, q=2-31, 200 kb/s, 33.33 fps, 33.33 tbn, 33.33 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  100 fps=0.0 q=24.8 Lsize=N/A time=00:00:03.00 bitrate=N/A speed= 3.6x
# video:2331kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /content

# %%
# %cd /content/original100
# !i=1; for file in *; do mv "$file" "$(printf '%d' $i).${file##*.}"; ((i++)); done
# %cd /content/
# Out:
# /content/original100
# /content

# %%
# %cd /content/original100/
# !rm *.gif
# %cd /content/
# Out:
# /content/original100
# /content

# %%
# !mkdir recon100
# %cd recon100
# Out:
# /content/recon100

# %%
reconloss_list = []

# Loop over the files in the folder and save predicted outputs as image in another folder recon100
for filename in os.listdir("/content/original100/"):
    print("saving ",filename)
    data = []
    # Load the image using OpenCV
    img = cv2.imread(os.path.join("/content/original100/", filename))
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Resize the image to a fixed size
    resized = cv2.resize(gray, (28, 28))
    # Add the image data to the list
    data.append(resized)
    # Add the label to the list
    data = np.array(data)
    predicted_data = autoencoder.predict(data.reshape(1,784))
    plt.imshow(predicted_data.reshape(28,28), cmap='gist_earth')
    plt.savefig("/content/recon100/"+str(filename))
    mse = np.mean((-data.reshape(28,28) + predicted_data.reshape(28,28))**2)
    reconloss_list.append(mse)
    # plt.show()
# Out:
# saving  81.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  14.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  52.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  55.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  65.jpg
# 1/1 [==============================] - 0s 33ms/step
# saving  69.jpg
# 1/1 [==============================] - 0s 39ms/step
# saving  22.jpg
# 1/1 [==============================] - 0s 34ms/step
# saving  25.jpg
# 1/1 [==============================] - 0s 35ms/step
# saving  41.jpg
# 1/1 [==============================] - 0s 33ms/step
# saving  94.jpg
# 1/1 [==============================] - 0s 32ms/step
# saving  76.jpg
# 1/1 [==============================] - 0s 31ms/step
# saving  96.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  56.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  77.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  91.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  7.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  27.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  45.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  88.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  86.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  59.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  5.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  87.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  83.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  79.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  75.jpg
# 1/1 [==============================] - 0s 27ms/step
# saving  4.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  62.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  37.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  39.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  16.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  19.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  28.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  72.jpg
# 1/1 [==============================] - 0s 38ms/step
# saving  49.jpg
# 1/1 [==============================] - 0s 36ms/step
# saving  35.jpg
# 1/1 [==============================] - 0s 32ms/step
# saving  12.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  80.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  98.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  18.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  73.jpg
# 1/1 [==============================] - 0s 27ms/step
# saving  43.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  30.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  57.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  78.jpg
# 1/1 [==============================] - 0s 20ms/step
# saving  24.jpg
# 1/1 [==============================] - 0s 37ms/step
# saving  9.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  70.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  82.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  84.jpg
# 1/1 [==============================] - 0s 31ms/step
# saving  85.jpg
# 1/1 [==============================] - 0s 31ms/step
# saving  40.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  48.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  60.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  90.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  1.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  89.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  2.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  47.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  23.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  21.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  54.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  20.jpg
# 1/1 [==============================] - 0s 34ms/step
# saving  10.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  38.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  51.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  97.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  67.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  68.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  29.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  50.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  15.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  100.jpg
# 1/1 [==============================] - 0s 37ms/step
# saving  33.jpg
# 1/1 [==============================] - 0s 32ms/step
# saving  63.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  71.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  26.jpg
# 1/1 [==============================] - 0s 30ms/step
# saving  58.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  11.jpg
# 1/1 [==============================] - 0s 23ms/step
# saving  13.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  44.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  74.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  34.jpg
# 1/1 [==============================] - 0s 36ms/step
# saving  53.jpg
# 1/1 [==============================] - 0s 26ms/step
# saving  36.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  3.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  92.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  99.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  66.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  61.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  17.jpg
# 1/1 [==============================] - 0s 46ms/step
# saving  46.jpg
# 1/1 [==============================] - 0s 35ms/step
# saving  95.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  64.jpg
# 1/1 [==============================] - 0s 21ms/step
# saving  32.jpg
# 1/1 [==============================] - 0s 25ms/step
# saving  6.jpg
# 1/1 [==============================] - 0s 28ms/step
# saving  31.jpg
# 1/1 [==============================] - 0s 22ms/step
# saving  42.jpg
# 1/1 [==============================] - 0s 24ms/step
# saving  8.jpg
# 1/1 [==============================] - 0s 40ms/step
# saving  93.jpg
# 1/1 [==============================] - 0s 33ms/step

# %%
print("The reconstruction loss between original data and the predicted or reconstructued data for 100 frames is:")
print(reconloss_list)
# Out:
# The reconstruction loss between original data and the predicted or reconstructued data for 100 frames is:
# [29969.51, 30570.244, 29641.234, 29751.258, 29946.066, 30026.127, 30416.861, 30360.55, 29780.45, 29598.715, 30034.467, 29500.072, 29873.525, 29999.908, 29681.832, 30277.127, 30274.857, 29858.348, 29758.63, 29842.95, 29839.75, 30194.44, 29801.459, 29979.027, 29992.107, 30066.99, 30168.777, 29914.818, 29847.928, 29791.168, 30603.883, 30581.219, 30228.215, 30035.959, 29618.76, 29958.36, 29775.01, 29953.547, 29410.38, 30592.87, 30034.959, 29727.908, 30185.107, 29768.156, 30007.086, 30419.398, 30401.79, 30022.389, 29975.275, 29955.492, 29931.057, 29808.4, 29608.592, 29879.678, 29693.49, 29397.434, 30039.994, 30108.523, 29638.592, 29771.332, 30478.928, 29737.453, 30549.742, 30483.041, 29844.7, 29608.86, 29470.275, 29982.035, 30012.123, 30180.117, 29598.293, 30565.05, 30036.303, 29965.393, 29941.506, 30007.424, 30284.926, 29826.586, 30500.781, 30568.56, 29709.322, 30053.797, 29834.89, 29713.523, 29853.402, 30140.81, 29636.7, 29430.578, 29968.982, 29899.467, 30608.258, 29662.408, 29552.748, 29920.309, 30055.566, 30224.033, 30140.066, 29747.89, 30337.105, 29628.26]

# %% [markdown]
# # By analyzing the variation in the reconstruction loss over time, you can gain insights into the complexity of the time series. For example, if the reconstruction loss is relatively constant over time, it may indicate that the time series is relatively simple or predictable. However, if the reconstruction loss varies widely over time, it may indicate that the time series is more complex and difficult to predict.

# %%
import numpy as np
std_dev = np.std(reconloss_list)

# Print the standard deviation of the list
print("Standard Deviation of the Reconstruction list is % s" % (std_dev))
# Out:
# Standard Deviation of the Reconstruction list is 301.88837

# %%
# def reconstruct_and_error(board):
#     data = []
#     # Load the image using OpenCV
#     img = np.array(board)
#     # Convert the image to grayscale
#     # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     # Resize the image to a fixed size
#     resized = cv2.resize(img, (28, 28))
#     # Add the image data to the list
#     data.append(resized)
#     # Add the label to the list
#     data = np.array(data)
#     predicted_data = autoencoder.predict(data.reshape(1,784), verbose=0)
#     plt.ioff()
#     # plt.imshow(predicted_data.reshape(28,28), cmap='gist_earth')
#     # plt.savefig("/content/recon100/"+str(filename))
#     mse = np.mean((-data.reshape(28,28) + predicted_data.reshape(28,28))**2)
#     # reconloss_list.append(mse)
#     # std_dev = np.std(reconloss_list)
#     return mse
#     # plt.show()

# # board = np.random.rand(100, 100)
# # # print(board.shape)
# # # print(board)
# # reco_loss = reconstruct_and_error(board)

# %%
# def calc_fitness(self, boards_list, gen):
#   errors = []
#   for i in range(len(boards_list)):
#     board_error = reconstruct_and_error(boards_list[i])
#     errors.append(board_error)
#   board_stddev = np.std(errors)
#   self.fitness = board_stddev
#   return self.fitness

# %%
# %cd /content/
# Out:
# /content

# %%
# Lenia for genetic Algorithm

# Imports
# https://chakazul.github.io/Lenia/JavaScript/Lenia.html
import numpy as np
from matplotlib import pyplot as plt
import time
import warnings
warnings.simplefilter("ignore", UserWarning)
#Imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
import scipy.signal
import os.path
import os
from datetime import datetime
from json import JSONEncoder
import json
from pathlib import Path
                

OUTPUT_PATH = './outputs'
MAX_FRAMES = 3000

mu = 0.31
sigma = 0.057
dt = 0.1


frames = 100
frame_intervals = float(50)



class LeniaForGA:
    def __init__(self, kernel, board):
        self.sigma = sigma
        self.mu = mu
        self.dt = dt
        self.kernel = kernel
        self.normalise_kernel()
        self.frames = frames
        self.frame_intervals = frame_intervals
        self.anim = None
        self.lenia_board_state = {}
        # For random initialisation
        self.board = board
        self.cmap = 'viridis'
        self.fig, self.img = self.show_board()
        

    # FLEXIBLITY TO CHANGE GROWTH FUNCTION
    def growth_function1(self, U:np.array):
        gaussian = lambda x, m, s: np.exp(-( (x-m)**2 / (2*s**2) ))
        return gaussian(U, self.mu, self.sigma)*2-1


    def show_board(self, 
                   display:bool=False,
                   ):
        dpi = 50 # Using a higher dpi will result in higher quality graphics but will significantly affect computation

        self.fig = plt.figure(figsize=(10*np.shape(self.board)[1]/dpi, 10*np.shape(self.board)[0]/dpi), dpi=dpi)

        ax = self.fig.add_axes([0, 0, 1, 1])
        ax.axis('off')
        
        self.img = ax.imshow(self.board, cmap=self.cmap, interpolation='none', aspect=1, vmin=0) #  vmax=vmax
        
        if display:
            plt.show()
        else: # Do not show intermediate figures when creating animations (very slow)
            plt.close()

        return self.fig, self.img
    
    
    def animate(self):
        self.anim =  matplotlib.animation.FuncAnimation(self.fig, self.animate_step, 
                                            frames=self.frames, interval=self.frame_intervals, save_count=MAX_FRAMES, blit=True)

    
    def animate_step(self, i:int) -> plt.imshow:
        neighbours = scipy.signal.convolve2d(self.board, self.kernel, mode='same', boundary='wrap')
        self.board = np.clip(self.board + self.dt * self.growth_function1(neighbours), 0, 1)
        # if (i+1) % 10 == 0:
        self.record_board_state(i)
        self.img.set_array(self.board) # render the updated state 
        return self.img,
    
    
    def save_animation(self, dir, 
                       filename:str,
                       ):
        if not self.anim:
            raise Exception('ERROR: Run animation before attempting to save')
            return 
        output_path = OUTPUT_PATH+"/"+dir
        Path(output_path).mkdir(parents=True, exist_ok=True)
        fmt = os.path.splitext(filename)[1] # isolate the file extension
        
        if fmt == '.gif':
            f = os.path.join(output_path, filename) 
            writer = matplotlib.animation.PillowWriter(fps=30) 
            self.anim.save(f, writer=writer)
        else:
            raise Exception('ERROR: Unknown save format. Must be .gif or .mp4')
        # writer.close()

    
    def normalise_kernel(self) -> np.array:

        kernel_norm = self.kernel / (1*np.sum(self.kernel))
        self.norm_factor = 1/ (1*np.sum(self.kernel))
        self.kernel = kernel_norm 
        return kernel_norm
        
        
    def plot_kernel_info(self,
                         dir,
                         cmap:str='viridis', 
                         bar:bool=False,
                         save:str=None,
                         ) -> None:

        
        k_xsection = self.kernel[self.kernel.shape[0] // 2, :]
        k_sum = np.sum(self.kernel)
        
        fig, ax = plt.subplots(1, 3, figsize=(14,2), gridspec_kw={'width_ratios': [1,1,2]})
        
        # Show kernel as heatmap
        ax[0].imshow(self.kernel, cmap=cmap, vmin=0)
        ax[0].title.set_text('Kernel')
        
        # Show kernel cross-section
        ax[1].title.set_text('Kernel Cross-section')
        if bar==True:
            ax[1].bar(range(0,len(k_xsection)), k_xsection, width=1)
        else:
            ax[1].plot(k_xsection)
        
        # Growth function
        ax[2].title.set_text('Growth Function')
        x = np.linspace(0, k_sum, 1000)
        ax[2].plot(x, self.growth_function1(x))
        
        if save:
            output_path = OUTPUT_PATH+"/"+dir
            Path(output_path).mkdir(parents=True, exist_ok=True)
            # print('Saving kernel and growth function info to', os.path.join(output_path, 'kernel_info'))
            
            plt.savefig(os.path.join(output_path, 'kernel_info.png') )


    def run_simulation(self, generation) -> None:
        self.animate()
        gif_dir = str(datetime.now())
        sub_dir = generation+"/"+gif_dir
        outfile = 'output.gif'   
        # print('./folder/{}...)'.format(sub_dir))
        
        self.save_animation(sub_dir, outfile)
        self.plot_kernel_info(dir=sub_dir, save=True)
        return self.lenia_board_state, sub_dir


    def record_board_state(self, i):
        # board_arr = self.board.flatten()
        # board_val_greater_than_point_five = list(board_arr[board_arr > 0.5])
        self.lenia_board_state["frame_"+str(i+1)] = self.board

# %% [markdown]
# # Merged VoT and AE

# %%
def reconstruct_and_error(board):
    data = []
    # Load the image using OpenCV
    img = np.array(board)
    # Convert the image to grayscale
    # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Resize the image to a fixed size
    resized = cv2.resize(img, (28, 28))
    # Add the image data to the list
    data.append(resized)
    # Add the label to the list
    data = np.array(data)
    predicted_data = autoencoder.predict(data.reshape(1,784), verbose=0)
    plt.ioff()
    # plt.imshow(predicted_data.reshape(28,28), cmap='gist_earth')
    # plt.savefig("/content/recon100/"+str(filename))
    mse = np.mean((-data.reshape(28,28) + predicted_data.reshape(28,28))**2)
    # reconloss_list.append(mse)
    # std_dev = np.std(reconloss_list)
    return predicted_data.reshape(28,28), mse
    # plt.show()

# board = np.random.rand(100, 100)
# # print(board.shape)
# # print(board)
# reco_loss = reconstruct_and_error(board)

# %%
# Updated with merged lenia-ae and vot

import random
import numpy as np
import shutil
import os
import statistics
from matplotlib import pyplot as plt
import sys
import copy
import multiprocessing


elite_filename = {}

kernel_size = 16
board_size = 64
mutation_rate = 0.1
population_size = 50
generation = 20
gen_best_fitness = {}
gen_average_fitness = {}
each_gen_fitness = []
no_of_elites = 1


OUTPUT_PATH = './outputs'

def random_kernel_generator():
  grid = np.random.rand(kernel_size, kernel_size)
  grid = np.round(grid, 3)
  return grid

def random_board_generator():
  board = np.random.rand(board_size, board_size)
  board = np.round(board, 3)
  return board

class Individual(multiprocessing.Process):

  def __init__(self):
    self.genes = random_kernel_generator()
    self.fitness = 0
    self.saved_dir = None

  def calc_fitness(self, board, gen):
    lenia = LeniaForGA(self.genes, board)
    board_frames_dict, dir = lenia.run_simulation("gen_"+str(gen))
    self.saved_dir = dir
    board_frames_val = list(board_frames_dict.values())
    errors = []
    frame_alive_cell_count_list = []
    for i in range(len(board_frames_val)):
      frame, board_error = reconstruct_and_error(board_frames_val[i])
      errors.append(board_error)
      board_arr = frame.flatten()
      alive_cell_count = list(board_arr[board_arr > 0.5])
      frame_alive_cell_count_list.append(len(alive_cell_count))

    every_10th_frames = frame_alive_cell_count_list[9::10]
    self.fitness = statistics.pstdev(every_10th_frames)
    # board_stddev = np.std(errors)
    # self.fitness = board_stddev
    
    return self.fitness


class Population:
  def __init__(self, size):
    self.individuals = []
    self.board = random_board_generator()
    for _ in range(0, size):
        self.individuals.append(Individual())


class GeneticAlgorithm:

  @staticmethod
  def mutate_individuals(individuals):
    mutated_individuals = []
    for ind in individuals:
        mutated_ind = GeneticAlgorithm._mutate_individual(ind)
        mutated_individuals.append(mutated_ind)
    return mutated_individuals

  @staticmethod
  def _mutate_individual(ind):
    kernel = ind.genes
    for i in range(kernel.shape[0]):
        for j in range(kernel.shape[1]):
            if random.random() < mutation_rate:
                kernel[i][j] = np.round(np.random.rand(), 3)
    ind.genes = kernel
    return ind
    
  @staticmethod
  def select_roulette_wheel(individuals):
    original_individuals = individuals
    individual_length = len(original_individuals)
    new_individuals = []
    total_sum = 0
    total_sum = sum([(total_sum + ind.fitness) for ind in individuals])
    print("total sum: ", total_sum)
    # random_num = random.randrange(0,int(round(total_sum)))
    random_num = random.uniform(0,total_sum)
    partial_sum = 0
    while len(new_individuals) != individual_length - no_of_elites:
        for c in original_individuals:
            partial_sum += c.fitness
            if(partial_sum >= random_num):
                new_individuals.append(c)
                # random_num = random.randrange(0,int(round(total_sum)))
                random_num = random.uniform(0,total_sum)
                partial_sum = 0
                break
    print("Roulette - Selected Individuals Fitness: ",  [ind.fitness for ind in new_individuals])
    return new_individuals

def run_ga(pop_size, generation):
  population = Population(pop_size)
  board = population.board
  population.individuals.sort(key=lambda x: x.calc_fitness(board=board, gen=1), reverse= True)
  for gen in range(1, generation+1):
      print("Generation: ", gen, " started")
      gen_fitness_dict = {}
      gen_best_fitness["gen_"+str(gen)] = population.individuals[0].fitness
      all_fitness = [ind.fitness for ind in population.individuals]
      gen_fitness_dict["gen_"+str(gen)] = all_fitness
      print("Fitness of this generation: ", all_fitness)
      each_gen_fitness.append(gen_fitness_dict)
      gen_average_fitness["gen_"+str(gen)] = sum(all_fitness)/len(all_fitness)
      elite_individuals = [copy.deepcopy(population.individuals[i]) for i in range(0,no_of_elites)]
      for e in elite_individuals:
         elite_filename["gen_"+str(gen)] = e.saved_dir

      selected_individuals = GeneticAlgorithm.select_roulette_wheel(population.individuals)
      mutated_individuals = GeneticAlgorithm.mutate_individuals(selected_individuals)
      for ind in mutated_individuals:
        ind.calc_fitness(board, gen)
      print("Mutated population fitness: ",  [ind.fitness for ind in mutated_individuals])
      population.individuals = elite_individuals + mutated_individuals    
      population.individuals.sort(key=lambda x: x.fitness, reverse= True)
      print("elite fitness: ", [ind.fitness for ind in elite_individuals])
      print("Next generation fitness : ", [ind.fitness for ind in population.individuals])
      print("Generation ",gen, " completed")
      print("----------------------------------")
      print("----------------------------------")
      plot_figures(gen_best_fitness, "gen_best_fitness"+str(gen)+".png")

  print("gen_best_fitness: ", gen_best_fitness)
  plot_figures(gen_best_fitness, "gen_best_fitness.png")
  print("gen_average_fitness: ", gen_average_fitness)
  plot_figures(gen_average_fitness, "gen_average_fitness.png")


def plot_figures(data, name):
  plt.clf()
  labels = list(data.keys())
  values = list(data.values())
  plt.plot(labels, values)
  plt.xlabel('Generation')
  plt.ylabel('Fitness')
  plt.title('Fitness of Generations')
  plt.savefig(name) 

if __name__ == "__main__":
    
  if os.path.exists('outputs'):
    shutil.rmtree('outputs')
  run_ga(population_size, generation)
  print("Elite gif directory")
  print(elite_filename)
# Out:
# Generation:  1  started
# Fitness of this generation:  [37.37766712891536, 35.18295041635934, 34.24631367023318, 32.71406425377318, 31.727590516772622, 30.46785190984097, 30.318476215007905, 30.015995735607373, 28.457687889215457, 27.371518043396865, 26.74995327098722, 26.51867266663247, 26.138859959837575, 25.927012940174965, 25.388186229031803, 24.779225169484214, 24.741867350707384, 24.476315082136036, 22.850820554194545, 22.73851358378555, 22.64950330581225, 22.526650882898682, 22.48132558369279, 21.839413911549915, 21.17167919651155, 21.081745658270332, 21.010711553871754, 20.887556104053917, 20.280285994038646, 20.25364164786175, 18.915866356051474, 18.793615937333612, 18.497567407634982, 17.71327186038762, 17.325126262166172, 16.92808317559906, 16.783622970026464, 16.735889578985635, 16.722440013347335, 16.156732342896568, 16.137224048763777, 15.355780670483673, 15.175308893067053, 14.645477117526763, 14.621901381147392, 13.064838307457157, 12.1309521472966, 11.7, 11.393419153177856, 8.391066678319271]
# total sum:  1089.5602407263239
# Roulette - Selected Individuals Fitness:  [16.722440013347335, 30.015995735607373, 20.887556104053917, 22.48132558369279, 34.24631367023318, 24.476315082136036, 21.081745658270332, 30.46785190984097, 16.92808317559906, 22.850820554194545, 37.37766712891536, 20.280285994038646, 31.727590516772622, 20.280285994038646, 25.927012940174965, 22.64950330581225, 24.476315082136036, 34.24631367023318, 20.25364164786175, 27.371518043396865, 17.325126262166172, 25.927012940174965, 28.457687889215457, 24.741867350707384, 26.74995327098722, 22.64950330581225, 21.17167919651155, 22.48132558369279, 24.779225169484214, 30.46785190984097, 15.175308893067053, 21.17167919651155, 17.71327186038762, 21.081745658270332, 25.388186229031803, 30.46785190984097, 26.138859959837575, 26.74995327098722, 22.850820554194545, 20.25364164786175, 11.7, 25.388186229031803, 21.081745658270332, 30.46785190984097, 22.850820554194545, 30.46785190984097, 18.793615937333612, 24.741867350707384, 25.927012940174965]
# Mutated population fitness:  [22.495332849282313, 34.09824042381073, 23.332595226420914, 21.736835096213984, 27.15952871461506, 19.845402490249473, 26.609021026711975, 24.290738975996593, 16.02529250903084, 32.16224494652076, 28.319604517012593, 14.810806865258895, 17.85077029150283, 14.810806865258895, 18.847015678881366, 30.073908957766033, 19.845402490249473, 27.15952871461506, 17.26528308484978, 25.61952380509833, 22.607299706068392, 18.847015678881366, 24.932107813018938, 17.458808664969098, 17.98471573308847, 30.073908957766033, 15.002999700059986, 21.736835096213984, 18.521339044464362, 24.290738975996593, 12.619429464123963, 15.002999700059986, 20.16457289406349, 26.609021026711975, 23.138928237928393, 24.290738975996593, 23.706750093591488, 17.98471573308847, 32.16224494652076, 17.26528308484978, 24.9, 23.138928237928393, 26.609021026711975, 24.290738975996593, 32.16224494652076, 24.290738975996593, 25.076881783826312, 17.458808664969098, 18.847015678881366]
# elite fitness:  [37.37766712891536]
# Next generation fitness :  [37.37766712891536, 34.09824042381073, 32.16224494652076, 32.16224494652076, 32.16224494652076, 30.073908957766033, 30.073908957766033, 28.319604517012593, 27.15952871461506, 27.15952871461506, 26.609021026711975, 26.609021026711975, 26.609021026711975, 25.61952380509833, 25.076881783826312, 24.932107813018938, 24.9, 24.290738975996593, 24.290738975996593, 24.290738975996593, 24.290738975996593, 24.290738975996593, 23.706750093591488, 23.332595226420914, 23.138928237928393, 23.138928237928393, 22.607299706068392, 22.495332849282313, 21.736835096213984, 21.736835096213984, 20.16457289406349, 19.845402490249473, 19.845402490249473, 18.847015678881366, 18.847015678881366, 18.847015678881366, 18.521339044464362, 17.98471573308847, 17.98471573308847, 17.85077029150283, 17.458808664969098, 17.458808664969098, 17.26528308484978, 17.26528308484978, 16.02529250903084, 15.002999700059986, 15.002999700059986, 14.810806865258895, 14.810806865258895, 12.619429464123963]
# Generation  1  completed
# ----------------------------------
# ----------------------------------
# Generation:  2  started
# Fitness of this generation:  [37.37766712891536, 34.09824042381073, 32.16224494652076, 32.16224494652076, 32.16224494652076, 30.073908957766033, 30.073908957766033, 28.319604517012593, 27.15952871461506, 27.15952871461506, 26.609021026711975, 26.609021026711975, 26.609021026711975, 25.61952380509833, 25.076881783826312, 24.932107813018938, 24.9, 24.290738975996593, 24.290738975996593, 24.290738975996593, 24.290738975996593, 24.290738975996593, 23.706750093591488, 23.332595226420914, 23.138928237928393, 23.138928237928393, 22.607299706068392, 22.495332849282313, 21.736835096213984, 21.736835096213984, 20.16457289406349, 19.845402490249473, 19.845402490249473, 18.847015678881366, 18.847015678881366, 18.847015678881366, 18.521339044464362, 17.98471573308847, 17.98471573308847, 17.85077029150283, 17.458808664969098, 17.458808664969098, 17.26528308484978, 17.26528308484978, 16.02529250903084, 15.002999700059986, 15.002999700059986, 14.810806865258895, 14.810806865258895, 12.619429464123963]
# total sum:  1140.9103824765546
# Roulette - Selected Individuals Fitness:  [24.9, 24.290738975996593, 24.290738975996593, 24.9, 28.319604517012593, 32.16224494652076, 24.290738975996593, 26.609021026711975, 24.290738975996593, 17.26528308484978, 17.98471573308847, 17.98471573308847, 17.85077029150283, 22.495332849282313, 37.37766712891536, 23.138928237928393, 18.847015678881366, 23.138928237928393, 17.458808664969098, 32.16224494652076, 20.16457289406349, 18.847015678881366, 14.810806865258895, 27.15952871461506, 26.609021026711975, 24.290738975996593, 12.619429464123963, 19.845402490249473, 23.706750093591488, 22.495332849282313, 20.16457289406349, 21.736835096213984, 21.736835096213984, 26.609021026711975, 34.09824042381073, 23.332595226420914, 23.138928237928393, 17.458808664969098, 30.073908957766033, 23.138928237928393, 17.458808664969098, 18.521339044464362, 26.609021026711975, 26.609021026711975, 24.290738975996593, 32.16224494652076, 12.619429464123963, 23.706750093591488, 18.847015678881366]
# Mutated population fitness:  [23.059921942625913, 27.705775571169273, 27.705775571169273, 23.059921942625913, 40.77057762651886, 24.121359828998035, 27.705775571169273, 27.626798583983632, 27.705775571169273, 22.95844071360248, 27.777688888746667, 27.777688888746667, 18.07318455613177, 21.970207099615607, 29.724737172933928, 23.50935983815808, 15.820556248122251, 23.50935983815808, 16.870388258721256, 24.121359828998035, 25.242028444639708, 15.820556248122251, 14.53272169966796, 28.67333255831976, 27.626798583983632, 27.705775571169273, 15.792719841749868, 20.778835386036437, 23.04690868641606, 21.970207099615607, 25.242028444639708, 16.688019654830228, 16.688019654830228, 27.626798583983632, 32.756068140117186, 22.89628790874189, 23.50935983815808, 16.870388258721256, 27.74977477386078, 23.50935983815808, 16.870388258721256, 19.005525512334565, 27.626798583983632, 27.626798583983632, 27.705775571169273, 24.121359828998035, 15.792719841749868, 23.04690868641606, 15.820556248122251]
# elite fitness:  [37.37766712891536]
# Next generation fitness :  [40.77057762651886, 37.37766712891536, 32.756068140117186, 29.724737172933928, 28.67333255831976, 27.777688888746667, 27.777688888746667, 27.74977477386078, 27.705775571169273, 27.705775571169273, 27.705775571169273, 27.705775571169273, 27.705775571169273, 27.705775571169273, 27.626798583983632, 27.626798583983632, 27.626798583983632, 27.626798583983632, 27.626798583983632, 25.242028444639708, 25.242028444639708, 24.121359828998035, 24.121359828998035, 24.121359828998035, 23.50935983815808, 23.50935983815808, 23.50935983815808, 23.50935983815808, 23.059921942625913, 23.059921942625913, 23.04690868641606, 23.04690868641606, 22.95844071360248, 22.89628790874189, 21.970207099615607, 21.970207099615607, 20.778835386036437, 19.005525512334565, 18.07318455613177, 16.870388258721256, 16.870388258721256, 16.870388258721256, 16.688019654830228, 16.688019654830228, 15.820556248122251, 15.820556248122251, 15.820556248122251, 15.792719841749868, 15.792719841749868, 14.53272169966796]
# Generation  2  completed
# ----------------------------------
# ----------------------------------
# Generation:  3  started
# Fitness of this generation:  [40.77057762651886, 37.37766712891536, 32.756068140117186, 29.724737172933928, 28.67333255831976, 27.777688888746667, 27.777688888746667, 27.74977477386078, 27.705775571169273, 27.705775571169273, 27.705775571169273, 27.705775571169273, 27.705775571169273, 27.705775571169273, 27.626798583983632, 27.626798583983632, 27.626798583983632, 27.626798583983632, 27.626798583983632, 25.242028444639708, 25.242028444639708, 24.121359828998035, 24.121359828998035, 24.121359828998035, 23.50935983815808, 23.50935983815808, 23.50935983815808, 23.50935983815808, 23.059921942625913, 23.059921942625913, 23.04690868641606, 23.04690868641606, 22.95844071360248, 22.89628790874189, 21.970207099615607, 21.970207099615607, 20.778835386036437, 19.005525512334565, 18.07318455613177, 16.870388258721256, 16.870388258721256, 16.870388258721256, 16.688019654830228, 16.688019654830228, 15.820556248122251, 15.820556248122251, 15.820556248122251, 15.792719841749868, 15.792719841749868, 14.53272169966796]
# total sum:  1191.29514100152
# Roulette - Selected Individuals Fitness:  [23.50935983815808, 23.059921942625913, 27.705775571169273, 15.820556248122251, 15.792719841749868, 16.688019654830228, 27.705775571169273, 32.756068140117186, 37.37766712891536, 16.870388258721256, 15.820556248122251, 27.705775571169273, 27.705775571169273, 23.50935983815808, 27.74977477386078, 27.777688888746667, 23.059921942625913, 24.121359828998035, 27.626798583983632, 37.37766712891536, 16.870388258721256, 27.705775571169273, 19.005525512334565, 27.626798583983632, 16.870388258721256, 23.50935983815808, 16.870388258721256, 24.121359828998035, 28.67333255831976, 21.970207099615607, 20.778835386036437, 15.792719841749868, 23.50935983815808, 32.756068140117186, 23.50935983815808, 15.792719841749868, 27.705775571169273, 27.705775571169273, 29.724737172933928, 28.67333255831976, 23.50935983815808, 27.74977477386078, 23.50935983815808, 24.121359828998035, 23.059921942625913, 27.74977477386078, 16.688019654830228, 15.792719841749868, 27.705775571169273]
# Mutated population fitness:  [25.834086010540414, 26.544490953868376, 29.873734282811046, 17.771043863543863, 15.8, 17.31588865753069, 29.873734282811046, 23.28712090405338, 31.441374015777363, 12.773409881468613, 17.771043863543863, 29.873734282811046, 29.873734282811046, 25.834086010540414, 29.25679408274256, 23.364288989823766, 26.544490953868376, 28.88875213642846, 19.09869105462466, 31.441374015777363, 12.773409881468613, 29.873734282811046, 18.835073665903195, 19.09869105462466, 12.773409881468613, 25.834086010540414, 12.773409881468613, 28.88875213642846, 31.036913506339513, 22.987170334775875, 18.838524358346117, 15.8, 25.834086010540414, 23.28712090405338, 25.834086010540414, 15.8, 29.873734282811046, 29.873734282811046, 25.02578670092111, 31.036913506339513, 25.834086010540414, 29.25679408274256, 25.834086010540414, 28.88875213642846, 26.544490953868376, 29.25679408274256, 17.31588865753069, 15.8, 29.873734282811046]
# elite fitness:  [40.77057762651886]
# Next generation fitness :  [40.77057762651886, 31.441374015777363, 31.441374015777363, 31.036913506339513, 31.036913506339513, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.25679408274256, 29.25679408274256, 29.25679408274256, 28.88875213642846, 28.88875213642846, 28.88875213642846, 26.544490953868376, 26.544490953868376, 26.544490953868376, 25.834086010540414, 25.834086010540414, 25.834086010540414, 25.834086010540414, 25.834086010540414, 25.834086010540414, 25.834086010540414, 25.02578670092111, 23.364288989823766, 23.28712090405338, 23.28712090405338, 22.987170334775875, 19.09869105462466, 19.09869105462466, 18.838524358346117, 18.835073665903195, 17.771043863543863, 17.771043863543863, 17.31588865753069, 17.31588865753069, 15.8, 15.8, 15.8, 15.8, 12.773409881468613, 12.773409881468613, 12.773409881468613, 12.773409881468613]
# Generation  3  completed
# ----------------------------------
# ----------------------------------
# Generation:  4  started
# Fitness of this generation:  [40.77057762651886, 31.441374015777363, 31.441374015777363, 31.036913506339513, 31.036913506339513, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.873734282811046, 29.25679408274256, 29.25679408274256, 29.25679408274256, 28.88875213642846, 28.88875213642846, 28.88875213642846, 26.544490953868376, 26.544490953868376, 26.544490953868376, 25.834086010540414, 25.834086010540414, 25.834086010540414, 25.834086010540414, 25.834086010540414, 25.834086010540414, 25.834086010540414, 25.02578670092111, 23.364288989823766, 23.28712090405338, 23.28712090405338, 22.987170334775875, 19.09869105462466, 19.09869105462466, 18.838524358346117, 18.835073665903195, 17.771043863543863, 17.771043863543863, 17.31588865753069, 17.31588865753069, 15.8, 15.8, 15.8, 15.8, 12.773409881468613, 12.773409881468613, 12.773409881468613, 12.773409881468613]
# total sum:  1217.9157130612912
# Roulette - Selected Individuals Fitness:  [29.873734282811046, 25.834086010540414, 12.773409881468613, 28.88875213642846, 25.834086010540414, 29.873734282811046, 17.771043863543863, 29.873734282811046, 15.8, 40.77057762651886, 25.834086010540414, 26.544490953868376, 29.873734282811046, 28.88875213642846, 29.873734282811046, 26.544490953868376, 26.544490953868376, 28.88875213642846, 29.873734282811046, 17.771043863543863, 23.28712090405338, 18.835073665903195, 25.834086010540414, 15.8, 29.873734282811046, 17.771043863543863, 29.873734282811046, 29.873734282811046, 25.834086010540414, 17.771043863543863, 25.834086010540414, 22.987170334775875, 40.77057762651886, 28.88875213642846, 40.77057762651886, 25.02578670092111, 29.25679408274256, 25.834086010540414, 29.873734282811046, 25.834086010540414, 31.441374015777363, 23.28712090405338, 29.873734282811046, 25.834086010540414, 22.987170334775875, 29.873734282811046, 25.834086010540414, 12.773409881468613, 29.873734282811046]
# Mutated population fitness:  [22.601106167619317, 24.560944607241797, 13.820636743652587, 35.4604004489515, 24.560944607241797, 22.601106167619317, 18.96417675513493, 22.601106167619317, 20.66131651178114, 36.587429535292586, 24.560944607241797, 28.18173167142147, 22.601106167619317, 35.4604004489515, 22.601106167619317, 28.18173167142147, 28.18173167142147, 35.4604004489515, 22.601106167619317, 18.96417675513493, 20.294087809014723, 16.401524319403975, 24.560944607241797, 20.66131651178114, 22.601106167619317, 18.96417675513493, 22.601106167619317, 22.601106167619317, 24.560944607241797, 18.96417675513493, 24.560944607241797, 22.153103620034823, 36.587429535292586, 35.4604004489515, 36.587429535292586, 30.520321099228298, 29.194006234157037, 24.560944607241797, 22.601106167619317, 24.560944607241797, 29.63443942442644, 20.294087809014723, 22.601106167619317, 24.560944607241797, 22.153103620034823, 22.601106167619317, 24.560944607241797, 13.820636743652587, 22.601106167619317]
# elite fitness:  [40.77057762651886]
# Next generation fitness :  [40.77057762651886, 36.587429535292586, 36.587429535292586, 36.587429535292586, 35.4604004489515, 35.4604004489515, 35.4604004489515, 35.4604004489515, 30.520321099228298, 29.63443942442644, 29.194006234157037, 28.18173167142147, 28.18173167142147, 28.18173167142147, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.153103620034823, 22.153103620034823, 20.66131651178114, 20.66131651178114, 20.294087809014723, 20.294087809014723, 18.96417675513493, 18.96417675513493, 18.96417675513493, 18.96417675513493, 16.401524319403975, 13.820636743652587, 13.820636743652587]
# Generation  4  completed
# ----------------------------------
# ----------------------------------
# Generation:  5  started
# Fitness of this generation:  [40.77057762651886, 36.587429535292586, 36.587429535292586, 36.587429535292586, 35.4604004489515, 35.4604004489515, 35.4604004489515, 35.4604004489515, 30.520321099228298, 29.63443942442644, 29.194006234157037, 28.18173167142147, 28.18173167142147, 28.18173167142147, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 24.560944607241797, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.153103620034823, 22.153103620034823, 20.66131651178114, 20.66131651178114, 20.294087809014723, 20.294087809014723, 18.96417675513493, 18.96417675513493, 18.96417675513493, 18.96417675513493, 16.401524319403975, 13.820636743652587, 13.820636743652587]
# total sum:  1251.808776760658
# Roulette - Selected Individuals Fitness:  [24.560944607241797, 24.560944607241797, 35.4604004489515, 35.4604004489515, 35.4604004489515, 22.601106167619317, 35.4604004489515, 24.560944607241797, 36.587429535292586, 28.18173167142147, 18.96417675513493, 29.63443942442644, 24.560944607241797, 20.294087809014723, 22.601106167619317, 22.601106167619317, 24.560944607241797, 22.601106167619317, 35.4604004489515, 22.601106167619317, 28.18173167142147, 24.560944607241797, 24.560944607241797, 36.587429535292586, 30.520321099228298, 28.18173167142147, 20.66131651178114, 24.560944607241797, 13.820636743652587, 28.18173167142147, 36.587429535292586, 20.294087809014723, 20.294087809014723, 22.601106167619317, 36.587429535292586, 22.601106167619317, 22.601106167619317, 22.601106167619317, 22.601106167619317, 24.560944607241797, 29.194006234157037, 18.96417675513493, 24.560944607241797, 35.4604004489515, 22.601106167619317, 20.66131651178114, 22.153103620034823, 13.820636743652587, 22.601106167619317]
# Mutated population fitness:  [14.98966310495336, 14.98966310495336, 33.77809941367335, 33.77809941367335, 33.77809941367335, 17.13359273474189, 33.77809941367335, 14.98966310495336, 31.349003173944784, 26.511318337645903, 16.788091017146648, 25.616400996236766, 14.98966310495336, 14.807092894960848, 17.13359273474189, 17.13359273474189, 14.98966310495336, 17.13359273474189, 33.77809941367335, 17.13359273474189, 26.511318337645903, 14.98966310495336, 14.98966310495336, 31.349003173944784, 28.47525241327985, 26.511318337645903, 16.04400199451496, 14.98966310495336, 16.889049706836676, 26.511318337645903, 31.349003173944784, 14.807092894960848, 14.807092894960848, 17.13359273474189, 31.349003173944784, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 14.98966310495336, 31.472051092993606, 16.788091017146648, 14.98966310495336, 33.77809941367335, 17.13359273474189, 16.04400199451496, 25.579093025359597, 16.889049706836676, 17.13359273474189]
# elite fitness:  [40.77057762651886]
# Next generation fitness :  [40.77057762651886, 33.77809941367335, 33.77809941367335, 33.77809941367335, 33.77809941367335, 33.77809941367335, 33.77809941367335, 31.472051092993606, 31.349003173944784, 31.349003173944784, 31.349003173944784, 31.349003173944784, 28.47525241327985, 26.511318337645903, 26.511318337645903, 26.511318337645903, 26.511318337645903, 25.616400996236766, 25.579093025359597, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 16.889049706836676, 16.889049706836676, 16.788091017146648, 16.788091017146648, 16.04400199451496, 16.04400199451496, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.807092894960848, 14.807092894960848, 14.807092894960848]
# Generation  5  completed
# ----------------------------------
# ----------------------------------
# Generation:  6  started
# Fitness of this generation:  [40.77057762651886, 33.77809941367335, 33.77809941367335, 33.77809941367335, 33.77809941367335, 33.77809941367335, 33.77809941367335, 31.472051092993606, 31.349003173944784, 31.349003173944784, 31.349003173944784, 31.349003173944784, 28.47525241327985, 26.511318337645903, 26.511318337645903, 26.511318337645903, 26.511318337645903, 25.616400996236766, 25.579093025359597, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 17.13359273474189, 16.889049706836676, 16.889049706836676, 16.788091017146648, 16.788091017146648, 16.04400199451496, 16.04400199451496, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.98966310495336, 14.807092894960848, 14.807092894960848, 14.807092894960848]
# total sum:  1085.3865656711064
# Roulette - Selected Individuals Fitness:  [25.616400996236766, 26.511318337645903, 33.77809941367335, 33.77809941367335, 33.77809941367335, 31.349003173944784, 40.77057762651886, 31.472051092993606, 31.349003173944784, 17.13359273474189, 14.98966310495336, 16.889049706836676, 16.788091017146648, 26.511318337645903, 25.579093025359597, 17.13359273474189, 26.511318337645903, 26.511318337645903, 17.13359273474189, 31.349003173944784, 17.13359273474189, 33.77809941367335, 14.98966310495336, 33.77809941367335, 16.788091017146648, 17.13359273474189, 26.511318337645903, 14.98966310495336, 31.349003173944784, 17.13359273474189, 14.98966310495336, 16.04400199451496, 33.77809941367335, 31.349003173944784, 14.98966310495336, 31.349003173944784, 14.98966310495336, 33.77809941367335, 25.616400996236766, 26.511318337645903, 14.98966310495336, 17.13359273474189, 17.13359273474189, 17.13359273474189, 40.77057762651886, 31.349003173944784, 14.98966310495336, 25.616400996236766, 33.77809941367335]

# %%
current_dir = !pwd
output_dirs = current_dir[0]+'/outputs'
elite_folder = output_dirs+'/elites'
if not os.path.exists(elite_folder):
    os.makedirs(elite_folder)
print(output_dirs)
for key, val in elite_filename.items():
  output_gif = output_dirs+"/"+val+"/output.gif"
  kernel = output_dirs+"/"+val+"/kernel_info.png"
  shutil.copy(output_gif, elite_folder)
  shutil.copy(kernel, elite_folder)

  # Rename the copied file to the new name
  new_path = os.path.join(elite_folder, key+"_output.gif")
  os.rename(os.path.join(elite_folder, os.path.basename(output_gif)), new_path)

  new_path = os.path.join(elite_folder, key+"_kernel.png")
  os.rename(os.path.join(elite_folder, os.path.basename(kernel)), new_path)
# Out:
# /content/outputs
# gen_1
# gen_1/2023-04-10 09:54:44.514667
# gen_2
# gen_1/2023-04-10 09:54:44.514667
