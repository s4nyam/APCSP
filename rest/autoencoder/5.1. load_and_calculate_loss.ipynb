# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %cd /content/drive/MyDrive/lenia_model/
# !wget https://dl3.pushbulletusercontent.com/x9D1dBZKfE2nAbjHJO1hTbXqAPZHjXQ2/encoder.h5
# Out:
# --2023-03-09 21:42:24--  https://dl3.pushbulletusercontent.com/x9D1dBZKfE2nAbjHJO1hTbXqAPZHjXQ2/encoder.h5
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1241256 (1.2M) [application/octet-stream]
# Saving to: ‘encoder.h5’
#
# encoder.h5          100%[===================>]   1.18M  5.15MB/s    in 0.2s
#
# 2023-03-09 21:42:25 (5.15 MB/s) - ‘encoder.h5’ saved [1241256/1241256]

# %%
from keras.models import load_model
model_load = load_model('encoder.h5')

# %%
model_load.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 64)                50240
#
#  dense_1 (Dense)             (None, 784)               50960
#
# =================================================================
# Total params: 101,200
# Trainable params: 101,200
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # For Orderly image

# %%
# Check for orderly image reconstruction loss
# !wget https://dl3.pushbulletusercontent.com/pVIOI0eH0xLUqrczqileIhK0fUO5n0OL/order.jpg
from IPython.display import Image
Image("order.jpg",width = 256, height = 256)
# Out:
# --2023-03-09 21:42:33--  https://dl3.pushbulletusercontent.com/pVIOI0eH0xLUqrczqileIhK0fUO5n0OL/order.jpg
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70912 (69K) [image/jpeg]
# Saving to: ‘order.jpg’
#
# order.jpg           100%[===================>]  69.25K  --.-KB/s    in 0.08s
#
# 2023-03-09 21:42:34 (821 KB/s) - ‘order.jpg’ saved [70912/70912]

# %%
# Check for orderly image reconstruction loss
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "./"

# Initialize lists to hold the image data and labels
data = []

filename = "order.jpg"
# Load the image using OpenCV
img = cv2.imread(os.path.join(folder_path, filename))
# Resize the image to a fixed size
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
# Add the image data to the list
data.append(resized)
# Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)

# %%
data.shape
# Out:
# (1, 28, 28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_order_image = model_load.predict(data[0].reshape(1,784))
print(predicted_order_image.shape)
# Out:
# 1/1 [==============================] - 0s 425ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_order_image.reshape(28,28))

# %%
# RECONSTRUCTION LOSS
import tensorflow as tf
print(tf.math.reduce_mean(predicted_order_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
# Out:
# 114

# %% [markdown]
# # For Chaotic image

# %%
# Check for chaotic image reconstruction loss
# !wget https://dl3.pushbulletusercontent.com/JMja0JFwu2M2r1A2XFKJUhj2d049mh28/chaotic.jpg
from IPython.display import Image
Image("chaotic.jpg",width = 256, height = 256)
# Out:
# --2023-03-09 21:42:38--  https://dl3.pushbulletusercontent.com/JMja0JFwu2M2r1A2XFKJUhj2d049mh28/chaotic.jpg
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 218777 (214K) [image/jpeg]
# Saving to: ‘chaotic.jpg’
#
# chaotic.jpg         100%[===================>] 213.65K  --.-KB/s    in 0.1s
#
# 2023-03-09 21:42:39 (1.43 MB/s) - ‘chaotic.jpg’ saved [218777/218777]

# %%
# Check for orderly image reconstruction loss
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "./"

# Initialize lists to hold the image data and labels
data = []

filename = "chaotic.jpg"
# Load the image using OpenCV
img = cv2.imread(os.path.join(folder_path, filename))
# Resize the image to a fixed size
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
# Add the image data to the list
data.append(resized)
# Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)

# %%
data.shape
# Out:
# (1, 28, 28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_order_image = model_load.predict(data[0].reshape(1,784))
print(predicted_order_image.shape)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_order_image.reshape(28,28))

# %%
# RECONSTRUCTION LOSS
# RECONSTRUCTION LOSS
import tensorflow as tf
print(tf.math.reduce_mean(predicted_order_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
# Out:
# 121
