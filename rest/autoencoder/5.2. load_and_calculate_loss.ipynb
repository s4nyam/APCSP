# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %cd /content/drive/MyDrive/lenia_model/
# !wget https://dl3.pushbulletusercontent.com/x9D1dBZKfE2nAbjHJO1hTbXqAPZHjXQ2/encoder.h5
# Out:
# --2023-03-09 21:49:18--  https://dl3.pushbulletusercontent.com/x9D1dBZKfE2nAbjHJO1hTbXqAPZHjXQ2/encoder.h5
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1241256 (1.2M) [application/octet-stream]
# Saving to: ‘encoder.h5’
#
# encoder.h5          100%[===================>]   1.18M  7.70MB/s    in 0.2s
#
# 2023-03-09 21:49:18 (7.70 MB/s) - ‘encoder.h5’ saved [1241256/1241256]

# %%
from keras.models import load_model
model_load = load_model('encoder.h5')

# %%
model_load.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 64)                50240
#
#  dense_1 (Dense)             (None, 784)               50960
#
# =================================================================
# Total params: 101,200
# Trainable params: 101,200
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # For Orderly image

# %%
# Check for orderly image reconstruction loss
# !wget https://dl3.pushbulletusercontent.com/pVIOI0eH0xLUqrczqileIhK0fUO5n0OL/order.jpg
# !wget https://dl3.pushbulletusercontent.com/r8r00OkVim4UwQEyqEG5diLnZWNni1e4/order.jpg
from IPython.display import Image
Image("order.jpg",width = 256, height = 256)
# Out:
# --2023-03-09 21:49:26--  https://dl3.pushbulletusercontent.com/r8r00OkVim4UwQEyqEG5diLnZWNni1e4/order.jpg
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71152 (69K) [image/jpeg]
# Saving to: ‘order.jpg’
#
# order.jpg           100%[===================>]  69.48K  --.-KB/s    in 0.05s
#
# 2023-03-09 21:49:26 (1.29 MB/s) - ‘order.jpg’ saved [71152/71152]

# %%
# Check for orderly image reconstruction loss
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "./"

# Initialize lists to hold the image data and labels
data = []

filename = "order.jpg"
# Load the image using OpenCV
img = cv2.imread(os.path.join(folder_path, filename))
# Resize the image to a fixed size
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
# Add the image data to the list
data.append(resized)
# Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)

# %%
data.shape
# Out:
# (1, 28, 28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_order_image = model_load.predict(data[0].reshape(1,784))
print(predicted_order_image.shape)
# Out:
# 1/1 [==============================] - 0s 497ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_order_image.reshape(28,28))

# %%
# RECONSTRUCTION LOSS
import tensorflow as tf
print(tf.math.reduce_mean(predicted_order_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
# Out:
# 115

# %% [markdown]
# # For Chaotic image

# %%
# Check for chaotic image reconstruction loss
# !wget https://dl3.pushbulletusercontent.com/JMja0JFwu2M2r1A2XFKJUhj2d049mh28/chaotic.jpg
# !wget https://dl3.pushbulletusercontent.com/HiHs0WSO0K8cEiYGfeWPeW0Q5MDGkmCs/chaotic.jpg
from IPython.display import Image
Image("chaotic.jpg",width = 256, height = 256)
# Out:
# --2023-03-09 21:49:31--  https://dl3.pushbulletusercontent.com/HiHs0WSO0K8cEiYGfeWPeW0Q5MDGkmCs/chaotic.jpg
# Resolving dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)... 35.208.62.122
# Connecting to dl3.pushbulletusercontent.com (dl3.pushbulletusercontent.com)|35.208.62.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 202671 (198K) [image/jpeg]
# Saving to: ‘chaotic.jpg’
#
# chaotic.jpg         100%[===================>] 197.92K  --.-KB/s    in 0.09s
#
# 2023-03-09 21:49:31 (2.21 MB/s) - ‘chaotic.jpg’ saved [202671/202671]

# %%
# Check for orderly image reconstruction loss
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Set the path to the folder containing the images
folder_path = "./"

# Initialize lists to hold the image data and labels
data = []

filename = "chaotic.jpg"
# Load the image using OpenCV
img = cv2.imread(os.path.join(folder_path, filename))
# Resize the image to a fixed size
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(gray, (28, 28), interpolation=cv2.INTER_AREA)
# Add the image data to the list
data.append(resized)
# Add the label to the list

# Convert the lists to numpy arrays
data = np.array(data)

# %%
data.shape
# Out:
# (1, 28, 28)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(data[0])

# %%
predicted_order_image = model_load.predict(data[0].reshape(1,784))
print(predicted_order_image.shape)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# (1, 784)

# %%
# Image from loaded array
import matplotlib.pyplot as plt
plt.imshow(predicted_order_image.reshape(28,28))

# %%
# RECONSTRUCTION LOSS
# RECONSTRUCTION LOSS
import tensorflow as tf
print(tf.math.reduce_mean(predicted_order_image.reshape(28,28)-tf.square(data[0].reshape(28,28))).numpy())
# Out:
# 130
